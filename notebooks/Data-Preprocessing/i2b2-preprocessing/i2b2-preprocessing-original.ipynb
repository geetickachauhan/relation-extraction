# %% [markdown]
# # Preprocessing the i2b2 data without any blinding

# %%
# %load_ext autoreload

# %%
# %autoreload

import os, pandas as pd, numpy as np
import pickle
import re
import sys
import glob
from tqdm import tqdm
import ast
sys.path.append('../../../')
from relation_extraction.data import utils
import nltk
from ast import literal_eval
import itertools
RESOURCE_PATH = "/data/medg/misc/geeticka/relation_extraction/i2b2"
outdir = 'pre-processed/original/'
def res(path): return os.path.join(RESOURCE_PATH, path)
from relation_extraction.data.converters.converter_i2b2 import get_dataset_dataframe, read_dataframe
# from relation_extraction.data.converters.converter_i2b2 import get_filename_with_extension, \
# get_filename_without_extension, get_concept_dictionary, get_dataset_dataframe_classification, write_dataframe, read_dataframe,\
# check_equality_of_written_and_read_df, write_into_txt, combine, get_line_number_and_word_number, read_rel_line,\
# get_entity_replacement_dictionary, get_dataset_dataframe_extraction

# %% [markdown]
# TODO: figure out how to handle the experiments for the extraction vs classification case. Also need to update the eval script at this point.

# %% [markdown]
# # Read through the data

# %%
beth_training = res('concept_assertion_relation_training_data/beth/')
partners_training = res('concept_assertion_relation_training_data/partners/')
test_reference = res('reference_standard_for_test_data/')
test = res('test_data/')

# %%
df_train_beth = get_dataset_dataframe(beth_training + "concept/", beth_training + 'rel/', beth_training + 'txt/')
# Out:
#   4%|▍         | 3/73 [00:00<00:06, 11.11it/s]
# Message from append_existing_relations(): The relation pair  {'85:8;85:9', '85:5;85:5'} is not present in the artificial relations pair and their respective types are  treatment treatment
#  82%|████████▏ | 60/73 [00:02<00:00, 20.91it/s]
# Message from append_existing_relations(): The relation pair  {'74:15;74:15', '74:0;74:0'} is not present in the artificial relations pair and their respective types are  test test
# 100%|██████████| 73/73 [00:03<00:00, 21.74it/s]

# %%
df_train_partners = get_dataset_dataframe(partners_training + "concept/", partners_training + "rel/", partners_training + 'txt/')
# Out:
# 100%|██████████| 97/97 [00:02<00:00, 37.19it/s]

# %%
df_test = get_dataset_dataframe(test_reference + "concepts/", test_reference + "rel/", test)
# Out:
#  87%|████████▋ | 223/256 [00:08<00:01, 25.10it/s]
# Message from append_existing_relations(): The relation pair  {'158:0;158:4', '158:18;158:18'} is not present in the artificial relations pair and their respective types are  test treatment
# 100%|██████████| 256/256 [00:10<00:00, 25.39it/s]

# %%
len(df_train_beth)
# Out:
# 5796

# %%
len(df_train_partners)
# Out:
# 4435

# %%
len(df_test)
# Out:
# 19114

# %% [markdown]
# Train set is significantly smaller than test set - that may be a problem

# %% [markdown]
# ## Testing for empty entities

# %%
def get_empty_entity_rows(df):
    empty_entity_rows = []
    def find_empty_entity_number(row):
        metadata = row.metadata
        e1 = metadata['e1']['word_index']
        e2 = metadata['e2']['word_index']
        if not e1 or not e2:
            empty_entity_rows.append(row.row_num)
    temp_df = df.copy()
    temp_df.insert(0, 'row_num', range(0, len(temp_df)))
    temp_df.apply(find_empty_entity_number, axis=1)
    return empty_entity_rows

def get_empty_rows_array(empty_entity_rows, df):
    empty_rows_array = []
    for index in empty_entity_rows:
        e1 = df.iloc[index].e1
        e2 = df.iloc[index].e2
        original_sentence = df.iloc[index].original_sentence
        tokenized_sentence = df.iloc[index].tokenized_sentence
        metadata = df.iloc[index].metadata
        empty_rows_array.append([index, original_sentence, e1, e2, metadata, tokenized_sentence])
    new_df = pd.DataFrame(data=empty_rows_array,    # values
             columns=['index_original', 'original_sentence' , 'e1', 'e2', 'metadata', 'tokenized_sentence'])
    return empty_rows_array, new_df

# %%
def get_empty_vals(df):
    empty_entity_rows = get_empty_entity_rows(df)
    empty_rows_array, new_df = get_empty_rows_array(empty_entity_rows, df)
    return empty_rows_array, new_df

# %%
get_empty_vals(df_train_beth)
# Out:
# ([], Empty DataFrame
#  Columns: [index_original, original_sentence, e1, e2, metadata, tokenized_sentence]
#  Index: [])

# %%
get_empty_vals(df_train_partners)
# Out:
# ([], Empty DataFrame
#  Columns: [index_original, original_sentence, e1, e2, metadata, tokenized_sentence]
#  Index: [])

# %%
get_empty_vals(df_test)
# Out:
# ([], Empty DataFrame
#  Columns: [index_original, original_sentence, e1, e2, metadata, tokenized_sentence]
#  Index: [])

# %% [markdown]
# ## Write into CSV format

# %%
df_train_beth.iloc[0].metadata
# Out:
# {'e1': {'word': 'chest x-ray', 'word_index': [('0', '1')]},
#  'e2': {'word': 'left lower lobe infiltrate', 'word_index': [('7', '10')]},
#  'entity_replacement': {'0:1': 'test', '7:10': 'problem'},
#  'sentence_id': '16',
#  'filename': 'record-18'}

# %%
if not os.path.exists(res(outdir)):
    os.makedirs(res(outdir))

# %%
write_dataframe(df_train_beth, res(outdir + 'train_beth_original.csv'))

# %%
df_train_beth_copy = read_dataframe(res(outdir + 'train_beth_original.csv'))

# %%
# The first checks with the pd.equals method, and the other does a manual checking per column
check_equality_of_written_and_read_df(df_train_beth, df_train_beth_copy)
# Out:
# (True, True)

# %%
write_dataframe(df_train_partners, res(outdir + 'train_partners_original.csv'))

# %%
df_train_partners_copy = read_dataframe(res(outdir + 'train_partners_original.csv'))

# %%
check_equality_of_written_and_read_df(df_train_partners, df_train_partners_copy)
# Out:
# (True, True)

# %%
write_dataframe(df_test, res(outdir + 'test_original.csv'))

# %%
df_test_copy = read_dataframe(res(outdir + 'test_original.csv'))

# %%
check_equality_of_written_and_read_df(df_test, df_test_copy)
# Out:
# (True, True)

# %% [markdown]
# ## Write into txt format

# %%
write_into_txt(df_train_beth, res(outdir + 'train_beth_original.txt'))
# Out:
# Unique relations: 	 ['TeRP' 'TrAP' 'PIP' 'TrCP' 'TrWP' 'TrIP' 'PP-None' 'TrP-None' 'TeP-None'
#  'TeCP' 'TrNAP']

# %%
write_into_txt(df_train_partners, res(outdir + 'train_partners_original.txt'))
# Out:
# Unique relations: 	 ['TeRP' 'TrAP' 'PP-None' 'TeP-None' 'PIP' 'TeCP' 'TrP-None' 'TrCP' 'TrNAP'
#  'TrIP' 'TrWP']

# %%
write_into_txt(df_test, res(outdir + 'test_original.txt'))
# Out:
# Unique relations: 	 ['TrCP' 'TeRP' 'TrAP' 'PIP' 'TrWP' 'PP-None' 'TrP-None' 'TrNAP' 'TrIP'
#  'TeP-None' 'TeCP']

# %% [markdown]
# ## Combine the train data of beth and partners

# %%
combine(res, outdir, 'train_beth_original', 'train_partners_original', 'train_original.txt')

# %% [markdown]
# ## Get some statistics on the data

# %%
train_beth_relation_distr = df_train_beth.groupby(['relation_type']).count()[['original_sentence']]

# %%
train_partners_relation_distr = df_train_partners.groupby(['relation_type']).count()[['original_sentence']]

# %%
test_relation_distr = df_test.groupby(['relation_type']).count()[['original_sentence']]

# %%
train_beth_relation_distr + train_partners_relation_distr + test_relation_distr
# Out:
#                original_sentence
# relation_type
# PIP                         2203
# PP-None                    12506
# TeCP                         504
# TeP-None                    2964
# TeRP                        3053
# TrAP                        2617
# TrCP                         526
# TrIP                         203
# TrNAP                        174
# TrP-None                    4462
# TrWP                         133

# %%
train_beth_relation_distr
# Out:
#                original_sentence
# relation_type
# PIP                          519
# PP-None                     2464
# TeCP                          98
# TeP-None                     527
# TeRP                         564
# TrAP                         583
# TrCP                         117
# TrIP                          34
# TrNAP                         41
# TrP-None                     832
# TrWP                          17

# %%
train_partners_relation_distr
# Out:
#                original_sentence
# relation_type
# PIP                          236
# PP-None                     1954
# TeCP                          68
# TeP-None                     464
# TeRP                         429
# TrAP                         302
# TrCP                          67
# TrIP                          17
# TrNAP                         21
# TrP-None                     870
# TrWP                           7

# %%
train_beth_relation_distr + train_partners_relation_distr
# Out:
#                original_sentence
# relation_type
# PIP                          755
# PP-None                     4418
# TeCP                         166
# TeP-None                     991
# TeRP                         993
# TrAP                         885
# TrCP                         184
# TrIP                          51
# TrNAP                         62
# TrP-None                    1702
# TrWP                          24

# %%
test_relation_distr
# Out:
#                original_sentence
# relation_type
# PIP                         1448
# PP-None                     8088
# TeCP                         338
# TeP-None                    1973
# TeRP                        2060
# TrAP                        1732
# TrCP                         342
# TrIP                         152
# TrNAP                        112
# TrP-None                    2760
# TrWP                         109

# %% [markdown]
# ## Checking how much entity overlap exists between train and test

# %%
df_train_beth = read_dataframe(res(outdir + 'train_beth_original.csv'))

# %%
df_train_partners = read_dataframe(res(outdir + 'train_partners_original.csv'))

# %%
df_test = read_dataframe(res(outdir + 'test_original.csv'))

# %%
df_test
# Out:
#                                        original_sentence  \
# 0      The patient is a 69 year-old white gentleman w...
# 1      Cardiac catheterization demonstrates severe tr...
# 2      Cardiac catheterization demonstrates severe tr...
# 3      Cardiac catheterization demonstrates severe tr...
# 4      Cardiac catheterization demonstrates severe tr...
# 5      The patient &apos;s heparin induced thrombocyt...
# 6      The patient &apos;s lower extremities began to...
# 7      Subsequent exercise treadmill test demonstrate...
# 8      The patient &apos;s heparin induced thrombocyt...
# 9      Subsequent exercise treadmill test demonstrate...
# 10     2 ) Coronary artery disease , status post coro...
# 11     Two years after this operation , he required a...
# 12     2 ) Coronary artery disease , status post coro...
# 13     Cardiac catheterization demonstrates severe tr...
# 14     2 ) Coronary artery disease , status post coro...
# 15     2 ) Coronary artery disease , status post coro...
# 16     2 ) Coronary artery disease , status post coro...
# 17     2 ) Coronary artery disease , status post coro...
# 18     2 ) Coronary artery disease , status post coro...
# 19     2 ) Coronary artery disease , status post coro...
# 20     2 ) Coronary artery disease , status post coro...
# 21     Cardiac catheterization demonstrates severe tr...
# 22     Cardiac catheterization demonstrates severe tr...
# 23     Cardiac catheterization demonstrates severe tr...
# 24     Cardiac catheterization demonstrates severe tr...
# 25     Cardiac catheterization demonstrates severe tr...
# 26     Cardiac catheterization demonstrates severe tr...
# 27     Cardiac catheterization demonstrates severe tr...
# 28     Cardiac catheterization demonstrates severe tr...
# 29     Cardiac catheterization demonstrates severe tr...
# ...                                                  ...
# 19084  At the hospital , she was started on Rocephin ...
# 19085  She was started on a regimen of MS Contin with...
# 19086  At the hospital , she was started on Rocephin ...
# 19087  B12 was noted to be low and the patient was gi...
# 19088  B12 was noted to be low and the patient was gi...
# 19089  The patient was continued on Synthroid for her...
# 19090  On admission , the patient had what appeared t...
# 19091  Chest x-ray shows right middle lobe , right lo...
# 19092  EKG shows normal sinus rhythm at 70 beats per ...
# 19093  She is also to call her PCP if she has increas...
# 19094  LFTs show an elevated ALT of 52 and AST of 101...
# 19095  LFTs show an elevated ALT of 52 and AST of 101...
# 19096  Iron studies showed a mixed picture with decre...
# 19097  Iron studies showed a mixed picture with decre...
# 19098  Iron studies showed a mixed picture with decre...
# 19099  Iron studies showed a mixed picture with decre...
# 19100  Iron studies showed a mixed picture with decre...
# 19101  As there was no identified bacterial pathogen ...
# 19102  She did continue to have a persistent fairly s...
# 19103  She did continue to have a persistent fairly s...
# 19104  She did continue to have a persistent fairly s...
# 19105  She did continue to have a persistent fairly s...
# 19106  She did continue to have a persistent fairly s...
# 19107  She did continue to have a persistent fairly s...
# 19108  She did continue to have a persistent fairly s...
# 19109  She did continue to have a persistent fairly s...
# 19110  At this time , repeat chest x-ray showed bilat...
# 19111  The patient originally presented to her PCP ap...
# 19112  The patient originally presented to her PCP ap...
# 19113  The patient originally presented to her PCP ap...
#
#                                                       e1  \
# 0                         a coronary artery bypass graft
# 1                                cardiac catheterization
# 2                                cardiac catheterization
# 3                                cardiac catheterization
# 4                                cardiac catheterization
# 5                                                heparin
# 6                                                hirudin
# 7                                                    ekg
# 8      the patient &apos;s heparin induced thrombocyt...
# 9                     subsequent exercise treadmill test
# 10                                 a vvi pacer placement
# 11                                  a pacer implantation
# 12                          coronary artery bypass graft
# 13                                             om1 graft
# 14                        anterior myocardial infarction
# 15                          coronary artery bypass graft
# 16                               coronary artery disease
# 17                                 a vvi pacer placement
# 18                                 a vvi pacer placement
# 19                          coronary artery bypass graft
# 20                               coronary artery disease
# 21          severe triple vessel coronary artery disease
# 22          severe triple vessel coronary artery disease
# 23          severe triple vessel coronary artery disease
# 24                                             om1 graft
# 25                                  saphenous vein graft
# 26                                     rca 100% occluded
# 27                                     rca 100% occluded
# 28                                             om1 graft
# 29                                  saphenous vein graft
# ...                                                  ...
# 19084                                           rocephin
# 19085                                          oxycodone
# 19086                                        chest x-ray
# 19087                                                b12
# 19088                                             im b12
# 19089                                          synthroid
# 19090                acute respiratory distress syndrome
# 19091                                        chest x-ray
# 19092                                                ekg
# 19093                     increasing shortness of breath
# 19094                                                ast
# 19095                                    total bilirubin
# 19096                       decreased iron to tibc ratio
# 19097                             iron-deficiency anemia
# 19098                                     decreased iron
# 19099                                     decreased iron
# 19100                                       iron studies
# 19101                             the triple antibiotics
# 19102                   a persistent fairly severe cough
# 19103                   a persistent fairly severe cough
# 19104                   a persistent fairly severe cough
# 19105                   a persistent fairly severe cough
# 19106                              abdominal muscle pain
# 19107                                          her cough
# 19108                                          her cough
# 19109                                          her cough
# 19110                                 repeat chest x-ray
# 19111                                   increasing cough
# 19112                                   increasing cough
# 19113                                            dyspnea
#
#                                                       e2 relation_type  \
# 0          a large anterior septal myocardial infarction          TrCP
# 1           severe triple vessel coronary artery disease          TeRP
# 2                                      rca 100% occluded          TeRP
# 3                                  severely diseased lad          TeRP
# 4                                          100% occluded          TeRP
# 5                                               allergic          TrCP
# 6                                 deep venous thrombosis          TrAP
# 7                                               ischemia          TeRP
# 8                                               allergic           PIP
# 9                                               ischemia          TeRP
# 10                                   sick sinus syndrome          TrAP
# 11                                   sick sinus syndrome          TrAP
# 12                               coronary artery disease          TrAP
# 13                                         100% occluded          TrWP
# 14                                   sick sinus syndrome       PP-None
# 15                                   sick sinus syndrome      TrP-None
# 16                                   sick sinus syndrome       PP-None
# 17                        anterior myocardial infarction      TrP-None
# 18                               coronary artery disease      TrP-None
# 19                        anterior myocardial infarction      TrP-None
# 20                        anterior myocardial infarction       PP-None
# 21                                     rca 100% occluded       PP-None
# 22                                 severely diseased lad       PP-None
# 23                                         100% occluded       PP-None
# 24          severe triple vessel coronary artery disease      TrP-None
# 25          severe triple vessel coronary artery disease      TrP-None
# 26                                 severely diseased lad       PP-None
# 27                                         100% occluded       PP-None
# 28                                     rca 100% occluded      TrP-None
# 29                                     rca 100% occluded      TrP-None
# ...                                                  ...           ...
# 19084                       a right lower lobe pneumonia          TrAP
# 19085                                  breakthrough pain          TrAP
# 19086                       a right lower lobe pneumonia          TeRP
# 19087                                                low          TeRP
# 19088                                                low          TrAP
# 19089                         her chronic hypothyroidism          TrAP
# 19090                     community - acquired pneumonia           PIP
# 19091  right middle lobe , right lower lobe , and lef...          TeRP
# 19092                                     borderline lvh          TeRP
# 19093                                             fevers       PP-None
# 19094                                    an elevated alt      TeP-None
# 19095                                    an elevated alt      TeP-None
# 19096                                           high mcv       PP-None
# 19097                                           high mcv       PP-None
# 19098                                           high mcv       PP-None
# 19099                       decreased iron to tibc ratio       PP-None
# 19100                             iron-deficiency anemia      TeP-None
# 19101                      identified bacterial pathogen      TrP-None
# 19102                                  repeated coughing       PP-None
# 19103                              abdominal muscle pain       PP-None
# 19104                                               weak       PP-None
# 19105                                          her cough       PP-None
# 19106                                  repeated coughing       PP-None
# 19107                                  repeated coughing       PP-None
# 19108                              abdominal muscle pain       PP-None
# 19109                                               weak       PP-None
# 19110                                               ards      TeP-None
# 19111                                            dyspnea       PP-None
# 19112                                            fatigue       PP-None
# 19113                                            fatigue       PP-None
#
#                                                 metadata  \
# 0      {'e1': {'word': 'a coronary artery bypass graf...
# 1      {'e1': {'word': 'cardiac catheterization', 'wo...
# 2      {'e1': {'word': 'cardiac catheterization', 'wo...
# 3      {'e1': {'word': 'cardiac catheterization', 'wo...
# 4      {'e1': {'word': 'cardiac catheterization', 'wo...
# 5      {'e1': {'word': 'heparin', 'word_index': [('14...
# 6      {'e1': {'word': 'hirudin', 'word_index': [('14...
# 7      {'e1': {'word': 'ekg', 'word_index': [('10', '...
# 8      {'e1': {'word': 'the patient &apos;s heparin i...
# 9      {'e1': {'word': 'subsequent exercise treadmill...
# 10     {'e1': {'word': 'a vvi pacer placement', 'word...
# 11     {'e1': {'word': 'a pacer implantation', 'word_...
# 12     {'e1': {'word': 'coronary artery bypass graft'...
# 13     {'e1': {'word': 'om1 graft', 'word_index': [('...
# 14     {'e1': {'word': 'anterior myocardial infarctio...
# 15     {'e1': {'word': 'coronary artery bypass graft'...
# 16     {'e1': {'word': 'coronary artery disease', 'wo...
# 17     {'e1': {'word': 'a vvi pacer placement', 'word...
# 18     {'e1': {'word': 'a vvi pacer placement', 'word...
# 19     {'e1': {'word': 'coronary artery bypass graft'...
# 20     {'e1': {'word': 'coronary artery disease', 'wo...
# 21     {'e1': {'word': 'severe triple vessel coronary...
# 22     {'e1': {'word': 'severe triple vessel coronary...
# 23     {'e1': {'word': 'severe triple vessel coronary...
# 24     {'e1': {'word': 'om1 graft', 'word_index': [('...
# 25     {'e1': {'word': 'saphenous vein graft', 'word_...
# 26     {'e1': {'word': 'rca 100% occluded', 'word_ind...
# 27     {'e1': {'word': 'rca 100% occluded', 'word_ind...
# 28     {'e1': {'word': 'om1 graft', 'word_index': [('...
# 29     {'e1': {'word': 'saphenous vein graft', 'word_...
# ...                                                  ...
# 19084  {'e1': {'word': 'rocephin', 'word_index': [('8...
# 19085  {'e1': {'word': 'oxycodone', 'word_index': [('...
# 19086  {'e1': {'word': 'chest x-ray', 'word_index': [...
# 19087  {'e1': {'word': 'b12', 'word_index': [('0', '0...
# 19088  {'e1': {'word': 'im b12', 'word_index': [('14'...
# 19089  {'e1': {'word': 'synthroid', 'word_index': [('...
# 19090  {'e1': {'word': 'acute respiratory distress sy...
# 19091  {'e1': {'word': 'chest x-ray', 'word_index': [...
# 19092  {'e1': {'word': 'ekg', 'word_index': [('0', '0...
# 19093  {'e1': {'word': 'increasing shortness of breat...
# 19094  {'e1': {'word': 'ast', 'word_index': [('8', '8...
# 19095  {'e1': {'word': 'total bilirubin', 'word_index...
# 19096  {'e1': {'word': 'decreased iron to tibc ratio'...
# 19097  {'e1': {'word': 'iron-deficiency anemia', 'wor...
# 19098  {'e1': {'word': 'decreased iron', 'word_index'...
# 19099  {'e1': {'word': 'decreased iron', 'word_index'...
# 19100  {'e1': {'word': 'iron studies', 'word_index': ...
# 19101  {'e1': {'word': 'the triple antibiotics', 'wor...
# 19102  {'e1': {'word': 'a persistent fairly severe co...
# 19103  {'e1': {'word': 'a persistent fairly severe co...
# 19104  {'e1': {'word': 'a persistent fairly severe co...
# 19105  {'e1': {'word': 'a persistent fairly severe co...
# 19106  {'e1': {'word': 'abdominal muscle pain', 'word...
# 19107  {'e1': {'word': 'her cough', 'word_index': [('...
# 19108  {'e1': {'word': 'her cough', 'word_index': [('...
# 19109  {'e1': {'word': 'her cough', 'word_index': [('...
# 19110  {'e1': {'word': 'repeat chest x-ray', 'word_in...
# 19111  {'e1': {'word': 'increasing cough', 'word_inde...
# 19112  {'e1': {'word': 'increasing cough', 'word_inde...
# 19113  {'e1': {'word': 'dyspnea', 'word_index': [('18...
#
#                                       tokenized_sentence
# 0      The patient is a 69 year-old white gentleman w...
# 1      Cardiac catheterization demonstrates severe tr...
# 2      Cardiac catheterization demonstrates severe tr...
# 3      Cardiac catheterization demonstrates severe tr...
# 4      Cardiac catheterization demonstrates severe tr...
# 5      The patient &apos;s heparin induced thrombocyt...
# 6      The patient &apos;s lower extremities began to...
# 7      Subsequent exercise treadmill test demonstrate...
# 8      The patient &apos;s heparin induced thrombocyt...
# 9      Subsequent exercise treadmill test demonstrate...
# 10     2 ) Coronary artery disease , status post coro...
# 11     Two years after this operation , he required a...
# 12     2 ) Coronary artery disease , status post coro...
# 13     Cardiac catheterization demonstrates severe tr...
# 14     2 ) Coronary artery disease , status post coro...
# 15     2 ) Coronary artery disease , status post coro...
# 16     2 ) Coronary artery disease , status post coro...
# 17     2 ) Coronary artery disease , status post coro...
# 18     2 ) Coronary artery disease , status post coro...
# 19     2 ) Coronary artery disease , status post coro...
# 20     2 ) Coronary artery disease , status post coro...
# 21     Cardiac catheterization demonstrates severe tr...
# 22     Cardiac catheterization demonstrates severe tr...
# 23     Cardiac catheterization demonstrates severe tr...
# 24     Cardiac catheterization demonstrates severe tr...
# 25     Cardiac catheterization demonstrates severe tr...
# 26     Cardiac catheterization demonstrates severe tr...
# 27     Cardiac catheterization demonstrates severe tr...
# 28     Cardiac catheterization demonstrates severe tr...
# 29     Cardiac catheterization demonstrates severe tr...
# ...                                                  ...
# 19084  At the hospital , she was started on Rocephin ...
# 19085  She was started on a regimen of MS Contin with...
# 19086  At the hospital , she was started on Rocephin ...
# 19087  B12 was noted to be low and the patient was gi...
# 19088  B12 was noted to be low and the patient was gi...
# 19089  The patient was continued on Synthroid for her...
# 19090  On admission , the patient had what appeared t...
# 19091  Chest x-ray shows right middle lobe , right lo...
# 19092  EKG shows normal sinus rhythm at 70 beats per ...
# 19093  She is also to call her PCP if she has increas...
# 19094  LFTs show an elevated ALT of 52 and AST of 101...
# 19095  LFTs show an elevated ALT of 52 and AST of 101...
# 19096  Iron studies showed a mixed picture with decre...
# 19097  Iron studies showed a mixed picture with decre...
# 19098  Iron studies showed a mixed picture with decre...
# 19099  Iron studies showed a mixed picture with decre...
# 19100  Iron studies showed a mixed picture with decre...
# 19101  As there was no identified bacterial pathogen ...
# 19102  She did continue to have a persistent fairly s...
# 19103  She did continue to have a persistent fairly s...
# 19104  She did continue to have a persistent fairly s...
# 19105  She did continue to have a persistent fairly s...
# 19106  She did continue to have a persistent fairly s...
# 19107  She did continue to have a persistent fairly s...
# 19108  She did continue to have a persistent fairly s...
# 19109  She did continue to have a persistent fairly s...
# 19110  At this time , repeat chest x-ray showed bilat...
# 19111  The patient originally presented to her PCP ap...
# 19112  The patient originally presented to her PCP ap...
# 19113  The patient originally presented to her PCP ap...
#
# [19114 rows x 6 columns]
