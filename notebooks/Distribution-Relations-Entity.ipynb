# %% [markdown]
# # Explore entity mentions in the data

# %%
import os, pandas as pd, numpy as np

RESOURCE_PATH = "/data/medg/misc/semeval_2010"
from collections import Counter
def res(path): return os.path.join(RESOURCE_PATH, path)
import matplotlib.pyplot as plt
import math

# %%
relation_dictionary = {0:'Component-Whole(e2,e1)', 1:'Instrument-Agency(e2,e1)', 2:'Member-Collection(e1,e2)', 
3:'Cause-Effect(e2,e1)', 4:'Entity-Destination(e1,e2)', 5:'Content-Container(e1,e2)', 
6:'Message-Topic(e1,e2)', 7:'Product-Producer(e2,e1)', 8:'Member-Collection(e2,e1)', 
9:'Entity-Origin(e1,e2)', 10:'Cause-Effect(e1,e2)', 11:'Component-Whole(e1,e2)', 
12:'Message-Topic(e2,e1)', 13:'Product-Producer(e1,e2)', 14:'Entity-Origin(e2,e1)', 
15:'Content-Container(e2,e1)', 16:'Instrument-Agency(e1,e2)', 17:'Entity-Destination(e2,e1)',
18:'Other'}

type_of_relation = { 0: 'C-W', 1: 'I-A', 2: 'M-C', 3: 'C-E', 4: 'E-D', 5:'C-C',
                    6: 'M-T', 7:'P-P', 8: 'M-C', 9:'E-O', 10: 'C-E', 11:'C-W', 12:'M-T', 13:'P-P',
                    14:'E-O', 15:'C-C', 16:'I-A', 17:'E-D', 18:'O'
}
relation_dictionary_short = {0:'C-W2', 1:'I-A2', 2:'M-C1', 3:'C-E2', 4:'E-D1', 5:'C-C1', 
6:'M-T1', 7:'P-P2', 8:'M-C2', 9:'E-O1', 10:'C-E1', 11:'C-W1', 12:'M-T2', 13:'P-P1', 14:'E-O2', 
15:'C-C2', 16:'I-A1', 17:'E-D2',18:'_O'}

# %% [markdown]
# Is it possible for left entity to not be before right entity?

# %%
def left_after_right(filename):
    with open(res(filename)) as file:
        for line in file:
            line = line.split()
            relation = int(line[0])
            left_start = int(line[1])
            left_end = int(line[2])
            right_start = int(line[3])
            right_end = int(line[4])
            sentence = " ".join(str(x) for x in line[5:])
            list_sentence = line[5:]
            left = " ".join(str(x) for x in list_sentence[left_start:left_end+1])
            right = " ".join(str(x) for x in list_sentence[right_start:right_end+1])
            if left_start > right_start or left_end > right_end or left_start > right_end or left_end > right_start:
                print(
                    'Left: {}\n'
                    'Right: {}\n'
                    'Label: {}\n'
                    'Sentence: {}\n'\
                    .format(left, right, relation_dictionary[relation], sentence)
                )

# %%
left_after_right('train.txt')

# %%
left_after_right('test.txt')

# %% [markdown]
# ## Create a pandas dataframe with Left Entity, Right Entity, Relation, Relation_Type, Sentence

# %%
def get_dataframe(filename):
    columns = ['Left Entity', 'Right Entity', 'Relation', 'Relation Type', 'Sentence']
    data = []
    num = 0
    with open(res(filename)) as file:
        for line in file:
            num += 1
            line = line.split()
            relation = int(line[0])
            left_start = int(line[1])
            left_end = int(line[2])
            right_start = int(line[3])
            right_end = int(line[4])
            sentence = " ".join(str(x) for x in line[5:])
            list_sentence = line[5:]
            left = " ".join(str(x) for x in list_sentence[left_start:left_end+1])
            right = " ".join(str(x) for x in list_sentence[right_start:right_end+1])
            data.append([left.lower(), right.lower(), relation_dictionary_short[relation], type_of_relation[relation],
                        sentence.lower()])
    df = pd.DataFrame(data, columns=columns)
    return df

# %%
train_data = get_dataframe('train.txt')

# %%
test_data = get_dataframe('test.txt')

# %% [markdown]
# # Methods to test entity mention commonalities

# %%
def group_and_get_relations(data, columns_duplicate):
    # columns can be ['Left Entity'] or ['Right Entity'] or ['Left Entity', 'Right Entity']
    data_len = len(data)
    data_copy = data.copy()
    data_copy = data_copy.reset_index()
    data_copy.rename(columns={'index': 'original data index'}, inplace=True)

    df_groupby = data_copy.groupby(columns_duplicate)
    df = df_groupby.size().reset_index(name='count') # get the counts after grouping
    df = df.loc[df['count'] > 1]
    df_len = len(df)
    print("Number of rows in data duplicated by ", columns_duplicate, " are", df_len)
    print("Out of the total ", data_len)
    print("This represents a percentage of %.2f"%(float(df_len)/data_len * 100))
    
    relation_list = df_groupby['Relation'].apply(list)
    relation_type_list = df_groupby['Relation Type'].apply(list)
    data_index = df_groupby['original data index'].apply(list)
    
    df.set_index(columns_duplicate, inplace=True)
    df = pd.concat([df, relation_list.rename('Relation'), relation_type_list.rename('Relation Type'), 
           train_data_index.rename('original data index')], axis=1, join='inner', sort=True)
    df.index.names = columns_duplicate
    df.reset_index(inplace=True)
    
    return df

# %%
# given a list like ['CE', 'CE'...] return a list like ['CE(2)']
def get_relation_num(relation):
    relation_count = Counter(relation)
    descending_order_relation_count = relation_count.most_common()
    rel_relnum = []
    most_common_relation_types = []
    most_common_relation_num = None
    max_count = 0
    for w in descending_order_relation_count:
        rel = w[0]
        count = w[1]
        rel_relnum.append(rel + "(" + str(count) + ")")
        if count > max_count:
            max_count = count
        if max_count == count:
            most_common_relation_types.append(rel)
            most_common_relation_num = count
    return rel_relnum, most_common_relation_types, most_common_relation_num

# %%
def get_relation_distributions(entity_duplicates, columns_duplicates):
    columns_df = []
    columns_df.extend(columns_duplicates)
    columns_df.extend(['count', 'Relation', 'Relation Type', 'Most common Relation Type', 
                       'Most common Relation Type num', 'original data index'])
    data = [] # Left Entity, count, Relation, Relation Type, 
    #Most common relation type, most common relation typenum, original data index
    # assume that you will get the input "columns"
    for index, row in entity_duplicates.iterrows():
        relation = row['Relation']
        relation_type = row['Relation Type']
        relation_and_count, _, _ = get_relation_num(relation)
        relation_type_and_count, most_common_relation_types,\
        most_common_relation_num = get_relation_num(relation_type)
        data_row = []
        for col in columns_duplicates: data_row.append(row[col])
        data_row.extend([row['count'], relation_and_count, relation_type_and_count,
                         most_common_relation_types, most_common_relation_num, row['original data index']])
        data.append(data_row)
    df = pd.DataFrame(data, columns=columns_df)
    return df

# %% [markdown]
# https://realpython.com/python-histograms/

# %%
def plot(columns, entity_relation_distributions):
    plt.style.use('ggplot')
    arr = entity_relation_distributions.hist(column='count', color='#6699cc', bins=30)
    # for i in range(10):
    #     plt.text(arr[0][i], arr[0][i],str(arr[0][i]))
    string = ""
    for col in columns: string += col + ", "
    plt.title('Counts for ' + string.strip())
    plt.xlabel('Number of duplicates')
    plt.ylabel('Counts')
    plt.grid(axis='y', alpha=0.75)

# %%
def get_relation_distributions_plot(data, columns, counts, percentage):
    # counts refers to printing those rows with counts greater than that value
    # percentage refers to printing the percentage of rows which have Most common rel type > percentage of count
    entity_duplicates = group_and_get_relations(data, columns)
    # get the relation distributions
    entity_relation_distributions = get_relation_distributions(entity_duplicates, columns)
    entity_relation_distributions = entity_relation_distributions.sort_values(by=['count'], ascending=False).reset_index(drop=True)
    # do the plotting
    plot(columns, entity_relation_distributions)
    
    entity_relation_dist_len = len(entity_relation_distributions)
    filtered_entit_rel_dist_len = len(entity_relation_distributions[entity_relation_distributions['Most common Relation Type num']
                                                                   > percentage * entity_relation_distributions['count']])
    percent_duplicate = float(filtered_entit_rel_dist_len) / entity_relation_dist_len * 100
      
    print("There are %.2f percent of entities with more than %.2f percent similar relations"%(percent_duplicate, 
                                                                                             percentage * 100))
    return entity_relation_distributions.loc[entity_relation_distributions['count'] > counts]

# %% [markdown]
# ## Test how many individual entity mentions are the same, get their most common relations

# %%
get_relation_distributions_plot(train_data, ['Left Entity'], 3, 0.6)
# Out:
# Number of rows in data duplicated by  ['Left Entity']  are 1395
# Out of the total  8000
# This represents a percentage of 17.44
# There are 52.19 percent of entities with more than 60.00 percent similar relations
#      Left Entity  count                                           Relation  \
# 0           book     65  [P-P1(22), M-T1(20), _O(10), C-W2(7), E-D1(3),...
# 1         bottle     46                       [C-C2(44), C-C1(1), E-D1(1)]
# 2         people     33  [_O(11), E-D1(9), P-P2(3), I-A2(3), E-O1(3), M...
# 3       suitcase     33                                [C-C2(31), C-C1(2)]
# 4            man     32  [I-A2(10), _O(10), E-O1(5), P-P2(3), C-E1(3), ...
# 5        company     31      [P-P2(17), _O(11), E-D1(1), P-P1(1), M-C2(1)]
# 6          water     29              [E-D1(15), E-O1(7), C-C1(5), C-E1(2)]
# 7          money     28                      [E-D1(17), C-C1(10), E-O1(1)]
# 8         damage     28                         [C-E2(25), _O(2), C-E1(1)]
# 9         author     27                [P-P2(14), _O(6), I-A2(5), E-O1(2)]
# 10       machine     23  [C-W2(14), P-P2(3), C-C1(2), _O(2), E-O1(1), C...
# 11       factory     22                         [P-P2(17), _O(3), C-W2(2)]
# 12        report     21                       [M-T1(13), P-P1(7), E-D1(1)]
# 13          body     21  [C-C1(13), M-C2(4), E-D1(1), I-A2(1), C-W1(1),...
# 14          fire     21                                  [C-E2(17), _O(4)]
# 15        system     20  [C-W2(8), _O(4), I-A2(3), P-P2(2), C-W1(2), I-...
# 16         train     19              [E-O1(11), C-W2(4), E-D1(3), M-C2(1)]
# 17        letter     19      [E-D1(5), C-C1(5), M-T1(5), E-O1(3), P-P1(1)]
# 18          team     18  [_O(8), E-D1(3), I-A2(2), P-P2(2), C-W1(1), E-...
# 19       student     17  [M-C1(4), _O(4), I-A2(4), E-O1(2), E-D1(2), P-...
# 20           box     16              [C-C2(10), C-C1(4), C-W2(1), E-D1(1)]
# 21          wine     16  [_O(6), E-D1(3), E-O1(3), P-P1(2), C-C1(1), P-...
# 22         plane     16                [E-O1(12), E-D1(2), C-C1(1), _O(1)]
# 23          fish     16  [C-W2(5), M-C1(4), E-D1(4), _O(1), P-P2(1), E-...
# 24      students     16                 [I-A2(6), _O(5), P-P2(4), E-D1(1)]
# 25       program     15  [M-T1(5), C-W2(4), _O(3), I-A1(1), P-P1(1), E-...
# 26        speech     15                         [M-T1(13), _O(1), P-P1(1)]
# 27      products     15        [E-D1(5), P-P1(3), C-C1(3), E-O1(2), _O(2)]
# 28          pain     15                       [C-E2(12), E-O1(2), M-T2(1)]
# 29   information     15  [C-C1(5), E-O1(3), _O(3), M-T1(2), M-T2(1), E-...
# ..           ...    ...                                                ...
# 470      passion      4                                 [E-D1(3), M-T2(1)]
# 471   passengers      4                 [I-A2(1), E-O1(1), _O(1), M-C1(1)]
# 472         disk      4                        [C-C1(2), P-P2(1), E-D1(1)]
# 473       clique      4                                          [M-C2(4)]
# 474      anxiety      4                                   [C-E2(3), _O(1)]
# 475         dish      4                          [C-W2(2), _O(1), E-D1(1)]
# 476      clutter      4                                   [M-C2(3), _O(1)]
# 477         skin      4                                 [C-W1(3), C-C1(1)]
# 478    particles      4                        [E-D1(2), C-E1(1), C-C1(1)]
# 479         king      4                        [P-P2(2), E-O1(1), E-O2(1)]
# 480    substance      4                          [E-D1(2), E-O1(1), _O(1)]
# 481      parents      4                          [_O(2), I-A2(1), P-P2(1)]
# 482      subject      4                          [_O(2), C-W2(1), M-T2(1)]
# 483          kit      4                 [C-W2(1), C-C1(1), M-C2(1), _O(1)]
# 484    paragraph      4                                          [M-T1(4)]
# 485        seeds      4                                   [E-D1(3), _O(1)]
# 486        timer      4                                          [C-W1(4)]
# 487      ratpack      4                                          [M-C2(4)]
# 488   sisterhood      4                                          [M-C2(4)]
# 489  documentary      4                                 [M-T1(3), P-P1(1)]
# 490         seed      4                        [E-O2(2), C-C1(1), P-P1(1)]
# 491     citizens      4                 [I-A2(1), E-D1(1), _O(1), P-P2(1)]
# 492    dizziness      4                                          [C-E2(4)]
# 493        panic      4                                   [_O(2), C-E2(2)]
# 494          toy      4                        [C-W2(2), C-C1(1), P-P1(1)]
# 495     division      4                                          [M-C2(4)]
# 496       jungle      4                                   [_O(2), M-C2(2)]
# 497       deputy      4                                          [M-C1(4)]
# 498         site      4                          [_O(2), C-W2(1), E-O2(1)]
# 499  description      4                                 [M-T1(3), M-T2(1)]
#
#                                          Relation Type  \
# 0    [P-P(22), M-T(21), O(10), C-W(7), E-D(3), I-A(...
# 1                                    [C-C(45), E-D(1)]
# 2    [O(11), E-D(9), E-O(4), P-P(3), I-A(3), M-T(2)...
# 3                                            [C-C(33)]
# 4     [I-A(10), O(10), E-O(5), P-P(3), C-E(3), E-D(1)]
# 5                     [P-P(18), O(11), E-D(1), M-C(1)]
# 6                    [E-D(15), E-O(7), C-C(5), C-E(2)]
# 7                           [E-D(17), C-C(10), E-O(1)]
# 8                                      [C-E(26), O(2)]
# 9                      [P-P(14), O(6), I-A(5), E-O(2)]
# 10     [C-W(14), P-P(3), C-C(2), O(2), E-O(1), C-E(1)]
# 11                             [P-P(17), O(3), C-W(2)]
# 12                           [M-T(13), P-P(7), E-D(1)]
# 13   [C-C(13), M-C(4), E-D(1), I-A(1), C-W(1), P-P(1)]
# 14                                     [C-E(17), O(4)]
# 15                     [C-W(10), O(4), I-A(4), P-P(2)]
# 16                   [E-O(11), C-W(4), E-D(3), M-C(1)]
# 17            [E-D(5), C-C(5), M-T(5), E-O(3), P-P(1)]
# 18   [O(8), E-D(3), I-A(2), P-P(2), C-W(1), E-O(1),...
# 19      [M-C(4), O(4), I-A(4), E-O(2), E-D(2), P-P(1)]
# 20                           [C-C(14), C-W(1), E-D(1)]
# 21              [O(6), E-D(3), E-O(3), P-P(3), C-C(1)]
# 22                     [E-O(12), E-D(2), C-C(1), O(1)]
# 23      [C-W(5), M-C(4), E-D(4), O(1), P-P(1), E-O(1)]
# 24                      [I-A(6), O(5), P-P(4), E-D(1)]
# 25      [M-T(5), C-W(4), O(3), I-A(1), P-P(1), E-O(1)]
# 26                             [M-T(13), O(1), P-P(1)]
# 27              [E-D(5), P-P(3), C-C(3), E-O(2), O(2)]
# 28                           [C-E(12), E-O(2), M-T(1)]
# 29              [C-C(5), M-T(3), E-O(3), O(3), E-D(1)]
# ..                                                 ...
# 470                                   [E-D(3), M-T(1)]
# 471                     [I-A(1), E-O(1), O(1), M-C(1)]
# 472                           [C-C(2), P-P(1), E-D(1)]
# 473                                           [M-C(4)]
# 474                                     [C-E(3), O(1)]
# 475                             [C-W(2), O(1), E-D(1)]
# 476                                     [M-C(3), O(1)]
# 477                                   [C-W(3), C-C(1)]
# 478                           [E-D(2), C-E(1), C-C(1)]
# 479                                   [E-O(2), P-P(2)]
# 480                             [E-D(2), E-O(1), O(1)]
# 481                             [O(2), I-A(1), P-P(1)]
# 482                             [O(2), C-W(1), M-T(1)]
# 483                     [C-W(1), C-C(1), M-C(1), O(1)]
# 484                                           [M-T(4)]
# 485                                     [E-D(3), O(1)]
# 486                                           [C-W(4)]
# 487                                           [M-C(4)]
# 488                                           [M-C(4)]
# 489                                   [M-T(3), P-P(1)]
# 490                           [E-O(2), C-C(1), P-P(1)]
# 491                     [I-A(1), E-D(1), O(1), P-P(1)]
# 492                                           [C-E(4)]
# 493                                     [O(2), C-E(2)]
# 494                           [C-W(2), C-C(1), P-P(1)]
# 495                                           [M-C(4)]
# 496                                     [O(2), M-C(2)]
# 497                                           [M-C(4)]
# 498                             [O(2), C-W(1), E-O(1)]
# 499                                           [M-T(4)]
#
#     Most common Relation Type  Most common Relation Type num  \
# 0                       [P-P]                             22
# 1                       [C-C]                             45
# 2                         [O]                             11
# 3                       [C-C]                             33
# 4                    [I-A, O]                             10
# 5                       [P-P]                             18
# 6                       [E-D]                             15
# 7                       [E-D]                             17
# 8                       [C-E]                             26
# 9                       [P-P]                             14
# 10                      [C-W]                             14
# 11                      [P-P]                             17
# 12                      [M-T]                             13
# 13                      [C-C]                             13
# 14                      [C-E]                             17
# 15                      [C-W]                             10
# 16                      [E-O]                             11
# 17            [E-D, C-C, M-T]                              5
# 18                        [O]                              8
# 19              [M-C, O, I-A]                              4
# 20                      [C-C]                             14
# 21                        [O]                              6
# 22                      [E-O]                             12
# 23                      [C-W]                              5
# 24                      [I-A]                              6
# 25                      [M-T]                              5
# 26                      [M-T]                             13
# 27                      [E-D]                              5
# 28                      [C-E]                             12
# 29                      [C-C]                              5
# ..                        ...                            ...
# 470                     [E-D]                              3
# 471        [I-A, E-O, O, M-C]                              1
# 472                     [C-C]                              2
# 473                     [M-C]                              4
# 474                     [C-E]                              3
# 475                     [C-W]                              2
# 476                     [M-C]                              3
# 477                     [C-W]                              3
# 478                     [E-D]                              2
# 479                [E-O, P-P]                              2
# 480                     [E-D]                              2
# 481                       [O]                              2
# 482                       [O]                              2
# 483        [C-W, C-C, M-C, O]                              1
# 484                     [M-T]                              4
# 485                     [E-D]                              3
# 486                     [C-W]                              4
# 487                     [M-C]                              4
# 488                     [M-C]                              4
# 489                     [M-T]                              3
# 490                     [E-O]                              2
# 491        [I-A, E-D, O, P-P]                              1
# 492                     [C-E]                              4
# 493                  [O, C-E]                              2
# 494                     [C-W]                              2
# 495                     [M-C]                              4
# 496                  [O, M-C]                              2
# 497                     [M-C]                              4
# 498                       [O]                              2
# 499                     [M-T]                              4
#
#                                    original data index
# 0    [198, 290, 397, 441, 696, 738, 776, 781, 959, ...
# 1    [266, 630, 732, 900, 1024, 1100, 1356, 1465, 1...
# 2    [7, 155, 556, 740, 1490, 1638, 1771, 2344, 246...
# 3    [660, 943, 1119, 1941, 1971, 2025, 2073, 2213,...
# 4    [227, 698, 842, 1175, 1508, 2113, 2329, 2453, ...
# 5    [409, 1228, 1754, 2263, 2297, 2574, 2734, 3058...
# 6    [151, 368, 665, 756, 1006, 1674, 1852, 2545, 2...
# 7    [244, 304, 567, 1240, 1680, 1683, 2702, 2813, ...
# 8    [87, 138, 624, 827, 977, 1182, 1675, 1827, 229...
# 9    [2, 477, 1337, 1419, 1737, 2343, 2852, 2935, 2...
# 10   [231, 554, 632, 858, 1678, 1839, 2543, 2772, 3...
# 11   [17, 401, 682, 1242, 1599, 1679, 2244, 2336, 2...
# 12   [218, 234, 590, 993, 1133, 1487, 1772, 2236, 2...
# 13   [298, 311, 413, 422, 1277, 1647, 1927, 2028, 3...
# 14   [72, 380, 703, 1005, 1069, 2149, 2700, 3013, 3...
# 15   [314, 867, 1226, 1655, 1884, 2518, 2541, 3103,...
# 16   [310, 1066, 1366, 1373, 1527, 1542, 1780, 2146...
# 17   [281, 1209, 1284, 1387, 1429, 2039, 2500, 2573...
# 18   [253, 594, 709, 715, 1198, 2032, 2433, 3229, 3...
# 19   [4, 43, 880, 902, 1099, 1115, 1451, 1973, 3217...
# 20   [374, 514, 752, 3856, 4227, 4641, 5173, 7217, ...
# 21   [887, 2526, 3916, 4788, 5424, 6430, 7226, 7359...
# 22   [215, 367, 730, 882, 2091, 2430, 2525, 3807, 3...
# 23   [251, 528, 1571, 2354, 2439, 3213, 3268, 3408,...
# 24   [272, 488, 537, 719, 1287, 1528, 2864, 3045, 3...
# 25   [503, 609, 905, 1155, 1433, 1496, 2675, 3329, ...
# 26   [881, 1137, 2195, 2338, 2510, 2562, 2656, 3470...
# 27   [84, 904, 1033, 1294, 1493, 2890, 3052, 3438, ...
# 28   [575, 916, 1260, 1609, 2721, 3098, 3376, 4312,...
# 29   [839, 1048, 1217, 2472, 2507, 2868, 3033, 4815...
# ..                                                 ...
# 470                            [783, 2040, 2644, 5192]
# 471                           [2162, 2323, 7200, 7369]
# 472                            [982, 2192, 2875, 4882]
# 473                           [1453, 2243, 3261, 4372]
# 474                           [4889, 5570, 7548, 7987]
# 475                           [1316, 3322, 6003, 6007]
# 476                           [1430, 4220, 7015, 7571]
# 477                           [2429, 3903, 4945, 6471]
# 478                           [3937, 4183, 4486, 5807]
# 479                            [845, 1870, 6268, 6786]
# 480                           [2460, 3081, 5477, 7484]
# 481                           [1548, 3884, 4327, 5029]
# 482                           [3285, 4366, 4991, 5252]
# 483                            [359, 1616, 4269, 7069]
# 484                           [4237, 4371, 5285, 6794]
# 485                             [417, 687, 3089, 4918]
# 486                             [29, 3118, 3718, 6850]
# 487                           [2520, 3412, 5457, 6443]
# 488                           [1108, 4305, 5453, 5635]
# 489                           [2129, 3755, 6596, 7244]
# 490                           [1756, 4318, 6531, 6567]
# 491                           [1745, 4206, 7460, 7991]
# 492                            [285, 3900, 4274, 7062]
# 493                           [3695, 7404, 7694, 7714]
# 494                           [1404, 2841, 5219, 5418]
# 495                           [1178, 3085, 4287, 6921]
# 496                           [3076, 3714, 6288, 6885]
# 497                           [1786, 2163, 3922, 6907]
# 498                            [636, 2837, 7550, 7682]
# 499                           [3829, 5042, 5172, 5743]
#
# [500 rows x 7 columns]

# %%
get_relation_distributions_plot(train_data, ['Right Entity'], 3, 0.6)
# Out:
# Number of rows in data duplicated by  ['Right Entity']  are 1410
# Out of the total  8000
# This represents a percentage of 17.62
# There are 49.25 percent of entities with more than 60.00 percent similar relations
#      Right Entity  count                                           Relation  \
# 0             box     47                [C-C1(40), E-D1(4), _O(2), C-C2(1)]
# 1         company     39      [P-P1(21), _O(12), E-D1(3), C-W1(2), E-O1(1)]
# 2            book     26  [P-P2(8), M-T2(6), C-W1(5), E-O1(3), _O(2), C-...
# 3             car     23       [_O(10), I-A2(4), C-W1(4), C-C1(3), E-O1(2)]
# 4           water     22  [C-C2(9), E-D1(4), _O(4), I-A2(3), C-E2(1), E-...
# 5           maker     20                                [P-P1(19), C-E1(1)]
# 6        suitcase     20                                [C-C1(19), C-W1(1)]
# 7        building     19                [C-W1(13), E-O1(2), _O(2), E-D1(2)]
# 8           books     19  [M-C2(5), C-C2(4), E-O1(3), M-T2(2), E-D1(1), ...
# 9      earthquake     18                                [C-E2(17), C-E1(1)]
# 10            oil     18       [E-O2(11), _O(4), P-P2(1), E-D1(1), E-O1(1)]
# 11         people     17  [M-C2(4), C-E2(3), P-P1(2), M-T1(2), _O(2), E-...
# 12         basket     17                 [C-C1(6), _O(6), E-D1(4), C-W1(1)]
# 13            bag     16                 [E-D1(6), C-C1(6), _O(3), C-W2(1)]
# 14            jar     16                       [C-C1(11), E-D1(4), E-O1(1)]
# 15          house     15        [C-W1(7), _O(3), E-D1(2), E-O1(2), M-T1(1)]
# 16           team     15                 [M-C1(8), P-P1(4), _O(2), E-O1(1)]
# 17           work     15        [P-P2(5), M-T1(5), _O(2), C-E2(2), E-O1(1)]
# 18        country     15                                 [E-D1(8), E-O1(7)]
# 19      countries     15                         [E-D1(12), _O(2), E-O1(1)]
# 20         system     15  [E-D1(4), I-A2(3), C-W2(3), C-E2(2), C-W1(2), ...
# 21        machine     14  [C-W1(4), E-D1(3), _O(3), P-P2(1), P-P1(1), C-...
# 22          paper     14  [_O(4), P-P2(3), I-A2(2), C-C1(2), E-O1(1), C-...
# 23          virus     14                                [C-E2(13), E-O1(1)]
# 24        factory     14        [P-P1(8), E-O1(2), _O(2), I-A1(1), E-D1(1)]
# 25          plant     14  [P-P1(5), E-O1(3), E-D1(2), _O(2), P-P2(1), C-...
# 26   manufacturer     14                                  [P-P1(13), _O(1)]
# 27           wine     14                 [E-O2(8), C-C2(3), C-E2(2), _O(1)]
# 28          trunk     14                [C-C1(11), C-W1(1), _O(1), E-D1(1)]
# 29     discussion     13                 [M-T2(9), C-W2(2), C-E2(1), _O(1)]
# ..            ...    ...                                                ...
# 316         crane      4                 [C-W1(1), P-P2(1), I-A2(1), _O(1)]
# 317         crash      4                                 [C-E2(2), C-E1(2)]
# 318         roots      4                          [C-W2(2), E-O1(1), _O(1)]
# 319       library      4                                 [E-O1(2), E-D1(2)]
# 320   coffeemaker      4                                   [C-W1(3), _O(1)]
# 321         hands      4                          [_O(2), E-O1(1), C-W1(1)]
# 322        drawer      4                                 [C-C1(2), E-D1(2)]
# 323   earthquakes      4                          [C-E2(2), P-P1(1), _O(1)]
# 324        carafe      4                                   [C-C1(3), _O(1)]
# 325        damage      4                                          [C-E1(4)]
# 326     engineers      4                                 [I-A1(3), M-C2(1)]
# 327          lamp      4                        [I-A2(2), E-O1(1), C-E2(1)]
# 328           end      4                                   [I-A2(2), _O(2)]
# 329      elements      4                                 [C-W2(3), M-C2(1)]
# 330        cattle      4                        [M-C2(2), E-D1(1), E-O2(1)]
# 331   electrician      4                                          [I-A1(4)]
# 332         staff      4                 [E-D1(1), I-A2(1), _O(1), M-C1(1)]
# 333      teachers      4                                   [_O(2), M-C2(2)]
# 334   perspective      4                                            [_O(4)]
# 335         sound      4                        [C-E1(2), C-E2(1), E-D1(1)]
# 336         drugs      4                          [I-A2(2), _O(1), C-E2(1)]
# 337           pen      4                        [C-W1(2), E-O1(1), I-A2(1)]
# 338         drill      4                                 [I-A2(3), C-E2(1)]
# 339      children      4                                   [E-D1(3), _O(1)]
# 340     mortality      4                                          [C-E1(4)]
# 341       tsunami      4                                   [C-E2(2), _O(2)]
# 342      location      4                                   [E-O1(3), _O(1)]
# 343         dryer      4                                 [C-W1(3), C-E2(1)]
# 344           ear      4                                 [C-W1(2), P-P2(2)]
# 345       chamber      4                        [C-W1(2), E-D1(1), E-O1(1)]
#
#                                          Relation Type  \
# 0                              [C-C(41), E-D(4), O(2)]
# 1             [P-P(21), O(12), E-D(3), C-W(2), E-O(1)]
# 2    [P-P(8), M-T(6), C-W(5), E-O(3), O(2), C-C(1),...
# 3              [O(10), I-A(4), C-W(4), C-C(3), E-O(2)]
# 4       [C-C(9), E-D(4), O(4), I-A(3), C-E(1), E-O(1)]
# 5                                    [P-P(19), C-E(1)]
# 6                                    [C-C(19), C-W(1)]
# 7                      [C-W(13), E-O(2), O(2), E-D(2)]
# 8    [M-C(5), C-C(4), E-O(3), M-T(2), E-D(1), P-P(1...
# 9                                            [C-E(18)]
# 10                     [E-O(12), O(4), P-P(1), E-D(1)]
# 11   [M-C(4), C-E(3), P-P(2), M-T(2), O(2), E-D(2),...
# 12                      [C-C(6), O(6), E-D(4), C-W(1)]
# 13                      [E-D(6), C-C(6), O(3), C-W(1)]
# 14                           [C-C(11), E-D(4), E-O(1)]
# 15              [C-W(7), O(3), E-D(2), E-O(2), M-T(1)]
# 16                      [M-C(8), P-P(4), O(2), E-O(1)]
# 17              [P-P(5), M-T(5), O(2), C-E(2), E-O(1)]
# 18                                    [E-D(8), E-O(7)]
# 19                             [E-D(12), O(2), E-O(1)]
# 20              [C-W(5), E-D(4), I-A(3), C-E(2), O(1)]
# 21      [C-W(4), E-D(3), O(3), P-P(2), C-C(1), I-A(1)]
# 22      [O(4), P-P(3), C-C(3), I-A(2), E-O(1), E-D(1)]
# 23                                   [C-E(13), E-O(1)]
# 24              [P-P(8), E-O(2), O(2), I-A(1), E-D(1)]
# 25              [P-P(6), E-O(3), E-D(2), O(2), C-W(1)]
# 26                                     [P-P(13), O(1)]
# 27                      [E-O(8), C-C(3), C-E(2), O(1)]
# 28                     [C-C(11), C-W(1), O(1), E-D(1)]
# 29                      [M-T(9), C-W(2), C-E(1), O(1)]
# ..                                                 ...
# 316                     [C-W(1), P-P(1), I-A(1), O(1)]
# 317                                           [C-E(4)]
# 318                             [C-W(2), E-O(1), O(1)]
# 319                                   [E-O(2), E-D(2)]
# 320                                     [C-W(3), O(1)]
# 321                             [O(2), E-O(1), C-W(1)]
# 322                                   [C-C(2), E-D(2)]
# 323                             [C-E(2), P-P(1), O(1)]
# 324                                     [C-C(3), O(1)]
# 325                                           [C-E(4)]
# 326                                   [I-A(3), M-C(1)]
# 327                           [I-A(2), E-O(1), C-E(1)]
# 328                                     [I-A(2), O(2)]
# 329                                   [C-W(3), M-C(1)]
# 330                           [M-C(2), E-D(1), E-O(1)]
# 331                                           [I-A(4)]
# 332                     [E-D(1), I-A(1), O(1), M-C(1)]
# 333                                     [O(2), M-C(2)]
# 334                                             [O(4)]
# 335                                   [C-E(3), E-D(1)]
# 336                             [I-A(2), O(1), C-E(1)]
# 337                           [C-W(2), E-O(1), I-A(1)]
# 338                                   [I-A(3), C-E(1)]
# 339                                     [E-D(3), O(1)]
# 340                                           [C-E(4)]
# 341                                     [C-E(2), O(2)]
# 342                                     [E-O(3), O(1)]
# 343                                   [C-W(3), C-E(1)]
# 344                                   [C-W(2), P-P(2)]
# 345                           [C-W(2), E-D(1), E-O(1)]
#
#     Most common Relation Type  Most common Relation Type num  \
# 0                       [C-C]                             41
# 1                       [P-P]                             21
# 2                       [P-P]                              8
# 3                         [O]                             10
# 4                       [C-C]                              9
# 5                       [P-P]                             19
# 6                       [C-C]                             19
# 7                       [C-W]                             13
# 8                       [M-C]                              5
# 9                       [C-E]                             18
# 10                      [E-O]                             12
# 11                      [M-C]                              4
# 12                   [C-C, O]                              6
# 13                 [E-D, C-C]                              6
# 14                      [C-C]                             11
# 15                      [C-W]                              7
# 16                      [M-C]                              8
# 17                 [P-P, M-T]                              5
# 18                      [E-D]                              8
# 19                      [E-D]                             12
# 20                      [C-W]                              5
# 21                      [C-W]                              4
# 22                        [O]                              4
# 23                      [C-E]                             13
# 24                      [P-P]                              8
# 25                      [P-P]                              6
# 26                      [P-P]                             13
# 27                      [E-O]                              8
# 28                      [C-C]                             11
# 29                      [M-T]                              9
# ..                        ...                            ...
# 316        [C-W, P-P, I-A, O]                              1
# 317                     [C-E]                              4
# 318                     [C-W]                              2
# 319                [E-O, E-D]                              2
# 320                     [C-W]                              3
# 321                       [O]                              2
# 322                [C-C, E-D]                              2
# 323                     [C-E]                              2
# 324                     [C-C]                              3
# 325                     [C-E]                              4
# 326                     [I-A]                              3
# 327                     [I-A]                              2
# 328                  [I-A, O]                              2
# 329                     [C-W]                              3
# 330                     [M-C]                              2
# 331                     [I-A]                              4
# 332        [E-D, I-A, O, M-C]                              1
# 333                  [O, M-C]                              2
# 334                       [O]                              4
# 335                     [C-E]                              3
# 336                     [I-A]                              2
# 337                     [C-W]                              2
# 338                     [I-A]                              3
# 339                     [E-D]                              3
# 340                     [C-E]                              4
# 341                  [C-E, O]                              2
# 342                     [E-O]                              3
# 343                     [C-W]                              3
# 344                [C-W, P-P]                              2
# 345                     [C-W]                              2
#
#                                    original data index
# 0    [374, 514, 752, 3856, 4227, 4641, 5173, 7217, ...
# 1    [409, 1228, 1754, 2263, 2297, 2574, 2734, 3058...
# 2    [198, 290, 397, 441, 696, 738, 776, 781, 959, ...
# 3    [174, 474, 1250, 2233, 3536, 3657, 4340, 4624,...
# 4    [151, 368, 665, 756, 1006, 1674, 1852, 2545, 2...
# 5                             [3452, 3580, 3668, 4288]
# 6    [660, 943, 1119, 1941, 1971, 2025, 2073, 2213,...
# 7    [4127, 4710, 4916, 6132, 6407, 6504, 7218, 722...
# 8                        [768, 4418, 4720, 5721, 7079]
# 9       [268, 428, 1572, 2735, 3809, 3926, 4037, 5114]
# 10   [468, 1708, 2125, 4404, 5006, 5264, 7091, 7391...
# 11   [7, 155, 556, 740, 1490, 1638, 1771, 2344, 246...
# 12                                    [496, 856, 2016]
# 13   [378, 568, 821, 1767, 2339, 3673, 3682, 5594, ...
# 14                                              [6366]
# 15   [908, 2052, 2298, 4387, 5341, 5416, 6982, 7278...
# 16   [253, 594, 709, 715, 1198, 2032, 2433, 3229, 3...
# 17   [1499, 1605, 1799, 2357, 3471, 5334, 5931, 595...
# 18   [32, 795, 3344, 3759, 5534, 5627, 6215, 7181, ...
# 19                                        [2855, 3979]
# 20   [314, 867, 1226, 1655, 1884, 2518, 2541, 3103,...
# 21   [231, 554, 632, 858, 1678, 1839, 2543, 2772, 3...
# 22   [193, 430, 662, 1845, 3116, 3464, 3702, 3957, ...
# 23                        [616, 699, 4205, 5659, 6454]
# 24   [17, 401, 682, 1242, 1599, 1679, 2244, 2336, 2...
# 25                             [373, 1597, 3927, 5551]
# 26                              [518, 863, 4088, 4398]
# 27   [887, 2526, 3916, 4788, 5424, 6430, 7226, 7359...
# 28                                        [1802, 4198]
# 29   [1020, 1473, 2112, 2160, 2379, 2891, 2980, 628...
# ..                                                 ...
# 316         [1649, 1858, 4660, 5446, 6577, 7187, 7574]
# 317                                  [666, 1687, 4556]
# 318                                       [5323, 6748]
# 319                                             [7428]
# 320                                             [5246]
# 321                                             [1014]
# 322                                       [1564, 4929]
# 323                                  [104, 5497, 6384]
# 324                                             [3771]
# 325  [87, 138, 624, 827, 977, 1182, 1675, 1827, 229...
# 326         [5188, 6311, 6402, 6937, 7310, 7379, 7415]
# 327                                       [4208, 7090]
# 328                                             [4626]
# 329                                              [825]
# 330                                             [2214]
# 331                                 [2424, 5130, 6065]
# 332                                    [74, 623, 2739]
# 333                                             [1558]
# 334                                             [1207]
# 335                                  [370, 3296, 7284]
# 336  [1208, 1642, 1810, 2004, 2749, 3446, 5632, 636...
# 337                                             [4819]
# 338                                             [7702]
# 339                                       [4171, 6568]
# 340                                             [2914]
# 341                 [78, 1970, 2143, 3211, 3940, 5121]
# 342                                             [4197]
# 343                                       [4516, 7620]
# 344                [160, 1189, 1798, 2030, 4525, 5097]
# 345                                       [1928, 6121]
#
# [346 rows x 7 columns]

# %% [markdown]
# also check how many are same across left and right entity

# %% [markdown]
# ## Number of duplicates across left and right entity (after removing duplicates within individual columns)

# %%
def get_df_without_duplicates(data, columns_duplicate):
    data = train_data
    data_len = len(data)
    data_copy = data.copy()
    data_copy = data_copy.reset_index()
    data_copy.rename(columns={'index': 'original data index'}, inplace=True)

    df_groupby = data_copy.groupby(columns_duplicate)
    df = df_groupby.size().reset_index(name='count') # get the counts after grouping
    df = df.loc[df['count'] == 1]
    df_len = len(df)

    # create a new dataframe with these filtered values
    relation_list = df_groupby['Relation'].apply(list)
    relation_type_list = df_groupby['Relation Type'].apply(list)
    data_index = df_groupby['original data index'].apply(list)

    df.set_index(columns_duplicate, inplace=True)
    df = pd.concat([df, relation_list.rename('Relation'), relation_type_list.rename('Relation Type'), 
           train_data_index.rename('original data index')], axis=1, join='inner', sort=True)
    df.index.names = columns_duplicate
    df.reset_index(inplace=True)

    new_data = []
    for index, row in df.iterrows():
        new_data_row = []
        for col in columns_duplicate: new_data_row.append(row[col])
        new_data_row.extend([row['Relation'][0], row['Relation Type'][0], row['original data index'][0]])
        new_data.append(new_data_row)
    columns_df = []
    columns_df.extend(columns_duplicate)
    columns_df.extend(['Relation', 'Relation Type', 'original data index'])
    new_df = pd.DataFrame(new_data, columns=columns_df)
    #also need to group by right entity 
    return new_df

# %%
left_entity_no_duplicates = get_df_without_duplicates(train_data, ['Left Entity'])
left_entity_no_duplicates.rename(columns={'Left Entity': 'Entity'}, inplace=True)

# %%
right_entity_no_duplicates = get_df_without_duplicates(train_data, ['Right Entity'])
right_entity_no_duplicates.rename(columns={'Right Entity': 'Entity'}, inplace=True)

# %%
concatenated_df = pd.concat([left_entity_no_duplicates, right_entity_no_duplicates])

# %%
get_relation_distributions_plot(concatenated_df, ['Entity'], 1, 0.7)
# Out:
# Number of rows in data duplicated by  ['Entity']  are 377
# Out of the total  3080
# This represents a percentage of 12.24
# There are 25.73 percent of entities with more than 70.00 percent similar relations
#                  Entity  count            Relation     Relation Type  \
# 0              academic      2  [P-P2(1), P-P1(1)]          [P-P(2)]
# 1                  pier      2    [_O(1), C-W1(1)]    [O(1), C-W(1)]
# 2                points      2             [_O(2)]            [O(2)]
# 3                poetry      2  [C-W1(1), E-D1(1)]  [C-W(1), E-D(1)]
# 4                plates      2  [C-W1(1), P-P2(1)]  [C-W(1), P-P(1)]
# 5               plastic      2    [_O(1), C-C1(1)]    [O(1), C-C(1)]
# 6                plasma      2    [_O(1), E-O1(1)]    [O(1), E-O(1)]
# 7                planet      2    [_O(1), C-W1(1)]    [O(1), C-W(1)]
# 8                 pilot      2             [_O(2)]            [O(2)]
# 9                 pills      2  [C-E1(1), I-A2(1)]  [C-E(1), I-A(1)]
# 10               pillow      2    [_O(1), E-O1(1)]    [O(1), E-O(1)]
# 11   physical geography      2    [_O(1), M-T1(1)]    [O(1), M-T(1)]
# 12          politicians      2  [E-O1(1), M-T1(1)]  [E-O(1), M-T(1)]
# 13               phrase      2    [_O(1), I-A2(1)]    [O(1), I-A(1)]
# 14         perpetrators      2  [I-A2(1), E-O1(1)]  [I-A(1), E-O(1)]
# 15              pendant      2  [C-C1(1), C-W1(1)]  [C-C(1), C-W(1)]
# 16               peeler      2             [_O(2)]            [O(2)]
# 17                  pay      2             [_O(2)]            [O(2)]
# 18             patriots      2  [C-E1(1), M-C2(1)]  [C-E(1), M-C(1)]
# 19                 path      2    [_O(1), M-T1(1)]    [O(1), M-T(1)]
# 20              passage      2  [M-T1(1), C-E2(1)]  [M-T(1), C-E(1)]
# 21           parameters      2  [E-O1(1), I-A2(1)]  [E-O(1), I-A(1)]
# 22               poison      2    [E-D1(1), _O(1)]    [E-D(1), O(1)]
# 23                ports      2    [_O(1), E-D1(1)]    [O(1), E-D(1)]
# 24               legacy      2    [_O(1), C-C2(1)]    [O(1), C-C(1)]
# 25      recommendations      2  [C-W2(1), P-P2(1)]  [C-W(1), P-P(1)]
# 26                 risk      2  [C-E2(1), M-T1(1)]  [C-E(1), M-T(1)]
# 27               rights      2    [_O(1), M-T1(1)]    [O(1), M-T(1)]
# 28              revenue      2  [E-O1(1), C-E1(1)]  [E-O(1), C-E(1)]
# 29            revellers      2    [_O(1), C-E2(1)]    [O(1), C-E(1)]
# ..                  ...    ...                 ...               ...
# 347               delay      2  [C-E2(1), C-E1(1)]          [C-E(2)]
# 348          definition      2    [E-O1(1), _O(1)]    [E-O(1), O(1)]
# 349             defects      2  [C-C2(1), C-E2(1)]  [C-C(1), C-E(1)]
# 350                debt      2    [C-E1(1), _O(1)]    [C-E(1), O(1)]
# 351              dealer      2  [I-A2(1), E-O1(1)]  [I-A(1), E-O(1)]
# 352            darkness      2    [C-E2(1), _O(1)]    [C-E(1), O(1)]
# 353             example      2  [M-T1(1), M-T2(1)]          [M-T(2)]
# 354          experiment      2  [C-E1(1), I-A2(1)]  [C-E(1), I-A(1)]
# 355            explorer      2    [E-D1(1), _O(1)]    [E-D(1), O(1)]
# 356           explosive      2  [C-C1(1), C-E2(1)]  [C-C(1), C-E(1)]
# 357                gang      2  [P-P2(1), M-C1(1)]  [P-P(1), M-C(1)]
# 358               games      2  [C-C1(1), M-T1(1)]  [C-C(1), M-T(1)]
# 359               fungi      2  [C-E1(1), C-E2(1)]          [C-E(2)]
# 360               fraud      2    [C-E2(1), _O(1)]    [C-E(1), O(1)]
# 361            fountain      2  [E-O1(1), E-D1(1)]  [E-O(1), E-D(1)]
# 362               forms      2    [I-A1(1), _O(1)]    [I-A(1), O(1)]
# 363                 flu      2           [C-E1(2)]          [C-E(2)]
# 364               flows      2           [C-E1(2)]          [C-E(2)]
# 365               flies      2  [E-O1(1), M-C2(1)]  [E-O(1), M-C(1)]
# 366         flexibility      2    [_O(1), C-E1(1)]    [O(1), C-E(1)]
# 367                flag      2  [E-O1(1), M-T1(1)]  [E-O(1), M-T(1)]
# 368           fishermen      2    [E-D1(1), _O(1)]    [E-D(1), O(1)]
# 369             firearm      2  [E-O1(1), C-W1(1)]  [E-O(1), C-W(1)]
# 370          filmmakers      2  [P-P2(1), P-P1(1)]          [P-P(2)]
# 371            filament      2  [C-E1(1), E-O1(1)]  [C-E(1), E-O(1)]
# 372             fiction      2  [P-P1(1), M-T2(1)]  [P-P(1), M-T(1)]
# 373              fibers      2  [C-W1(1), E-O1(1)]  [C-W(1), E-O(1)]
# 374             ferrets      2  [C-C1(1), M-C2(1)]  [C-C(1), M-C(1)]
# 375             eyebrow      2  [C-W1(1), E-O1(1)]  [C-W(1), E-O(1)]
# 376                zone      2    [_O(1), E-D1(1)]    [O(1), E-D(1)]
#
#     Most common Relation Type  Most common Relation Type num  \
# 0                       [P-P]                              2
# 1                    [O, C-W]                              1
# 2                         [O]                              2
# 3                  [C-W, E-D]                              1
# 4                  [C-W, P-P]                              1
# 5                    [O, C-C]                              1
# 6                    [O, E-O]                              1
# 7                    [O, C-W]                              1
# 8                         [O]                              2
# 9                  [C-E, I-A]                              1
# 10                   [O, E-O]                              1
# 11                   [O, M-T]                              1
# 12                 [E-O, M-T]                              1
# 13                   [O, I-A]                              1
# 14                 [I-A, E-O]                              1
# 15                 [C-C, C-W]                              1
# 16                        [O]                              2
# 17                        [O]                              2
# 18                 [C-E, M-C]                              1
# 19                   [O, M-T]                              1
# 20                 [M-T, C-E]                              1
# 21                 [E-O, I-A]                              1
# 22                   [E-D, O]                              1
# 23                   [O, E-D]                              1
# 24                   [O, C-C]                              1
# 25                 [C-W, P-P]                              1
# 26                 [C-E, M-T]                              1
# 27                   [O, M-T]                              1
# 28                 [E-O, C-E]                              1
# 29                   [O, C-E]                              1
# ..                        ...                            ...
# 347                     [C-E]                              2
# 348                  [E-O, O]                              1
# 349                [C-C, C-E]                              1
# 350                  [C-E, O]                              1
# 351                [I-A, E-O]                              1
# 352                  [C-E, O]                              1
# 353                     [M-T]                              2
# 354                [C-E, I-A]                              1
# 355                  [E-D, O]                              1
# 356                [C-C, C-E]                              1
# 357                [P-P, M-C]                              1
# 358                [C-C, M-T]                              1
# 359                     [C-E]                              2
# 360                  [C-E, O]                              1
# 361                [E-O, E-D]                              1
# 362                  [I-A, O]                              1
# 363                     [C-E]                              2
# 364                     [C-E]                              2
# 365                [E-O, M-C]                              1
# 366                  [O, C-E]                              1
# 367                [E-O, M-T]                              1
# 368                  [E-D, O]                              1
# 369                [E-O, C-W]                              1
# 370                     [P-P]                              2
# 371                [C-E, E-O]                              1
# 372                [P-P, M-T]                              1
# 373                [C-W, E-O]                              1
# 374                [C-C, M-C]                              1
# 375                [C-W, E-O]                              1
# 376                  [O, E-D]                              1
#
#     original data index
# 0                [3057]
# 1                 [815]
# 2                [3440]
# 3                [5712]
# 4                [2288]
# 5                [7577]
# 6                [1855]
# 7                [7647]
# 8                [2035]
# 9                [4646]
# 10               [6746]
# 11               [7003]
# 12               [5891]
# 13               [4667]
# 14               [3827]
# 15               [1809]
# 16               [7230]
# 17               [2615]
# 18               [7202]
# 19               [1442]
# 20                [963]
# 21               [5253]
# 22               [2497]
# 23               [2878]
# 24               [1535]
# 25               [7425]
# 26               [7492]
# 27               [6728]
# 28               [5098]
# 29                [960]
# ..                  ...
# 347              [6209]
# 348               [864]
# 349              [2121]
# 350              [5112]
# 351              [3724]
# 352              [6435]
# 353              [5268]
# 354              [7689]
# 355              [1957]
# 356              [6924]
# 357              [6253]
# 358              [2732]
# 359              [6993]
# 360              [2595]
# 361              [2483]
# 362              [5670]
# 363              [6410]
# 364              [4456]
# 365              [7082]
# 366              [5245]
# 367              [3231]
# 368              [1850]
# 369              [7283]
# 370               [217]
# 371              [7251]
# 372               [622]
# 373              [7916]
# 374              [2275]
# 375              [6182]
# 376              [4818]
#
# [377 rows x 7 columns]

# %% [markdown]
# ## How many entity pairs are the same, and what are their relation distributions?

# %%
def group_left_and_right_entity(data, columns_duplicate=['Left Entity', 'Right Entity']):
    data_len = len(data)
    data_copy = data.copy()
    data_copy = data_copy.reset_index()
    data_copy.rename(columns={'index': 'original data index'}, inplace=True)

    df_groupby = data_copy.groupby(columns_duplicate)
    df = df_groupby.size().reset_index(name='count') # get the counts after grouping
    df = df.loc[df['count'] > 1]
    df_len = len(df)
    print("Number of rows in data duplicated by ", columns_duplicate, " are", df_len)
    print("Out of the total ", data_len)
    print("This represents a percentage of %.2f"%(float(df_len)/data_len * 100))

# %%
group_left_and_right_entity(train_data)
# Out:
# Number of rows in data duplicated by  ['Left Entity', 'Right Entity']  are 237
# Out of the total  8000
# This represents a percentage of 2.96

# %% [markdown]
# It doesn't seem like seeing whether Right Entity, Left Entity duplicates are present at the moment because the numbers are so small anyway

# %% [markdown]
# The only way to tell if the coupling will help is to see if the examples the model is performing badly on are the ones that have duplicating entity mentions or entity pair mentions
