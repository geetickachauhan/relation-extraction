# %% [markdown]
# # Type of examples for which stop words predict the wrong relation vs the baseline which predicts the correct relations

# %%
# %load_ext autoreload

# %%
# %autoreload
import os
from sys import path
import re
import pandas as pd
path.append('../../..')
import numpy as np
from scipy.stats import ttest_rel
from relation_extraction.data.summarize import *
from relation_extraction.data.converters.converter_semeval2010 import relation_dict
from relation_extraction.data.utils import split_data_cut_sentence
output_path = '/scratch/geeticka/relation-extraction-result/semeval-analyze/'
def res(path): return os.path.join(output_path, path)
original_sentences_path = os.path.join('/scratch/geeticka/relation-extraction-result/semeval-analyze/test_original_for_stop_word_analysis.txt')
stop_words_sentences_path = os.path.join('/scratch/geeticka/relation-extraction-result/semeval-analyze/test_punct_stop_digit_for_stop_word_analysis.txt')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /afs/csail.mit.edu/u/g/geeticka/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
relation_dict
# Out:
# {0: 'Component-Whole(e2,e1)',
#  1: 'Instrument-Agency(e2,e1)',
#  2: 'Member-Collection(e1,e2)',
#  3: 'Cause-Effect(e2,e1)',
#  4: 'Entity-Destination(e1,e2)',
#  5: 'Content-Container(e1,e2)',
#  6: 'Message-Topic(e1,e2)',
#  7: 'Product-Producer(e2,e1)',
#  8: 'Member-Collection(e2,e1)',
#  9: 'Entity-Origin(e1,e2)',
#  10: 'Cause-Effect(e1,e2)',
#  11: 'Component-Whole(e1,e2)',
#  12: 'Message-Topic(e2,e1)',
#  13: 'Product-Producer(e1,e2)',
#  14: 'Entity-Origin(e2,e1)',
#  15: 'Content-Container(e2,e1)',
#  16: 'Instrument-Agency(e1,e2)',
#  17: 'Entity-Destination(e2,e1)',
#  18: 'Other'}

# %% [markdown]
# Semeval uses border size 50 as default and the method split_data_cut_sentence drops some. We need to find out which so that we can update the original sentences with the stop words sentences so that they can match line by line

# %%
# below is a modified version of the split_data_cut_sentence which prints the lines that are dropped
def print_dropped_sentences(stop_words_sentences_path):
    counter = 0
    with open(stop_words_sentences_path, 'r') as file:
        for line in file:
            counter += 1 # this counter starts from 1 and demonstrates the current line that you are at
            line = line.strip().lower().split()
            left_start_pos = int(line[1])
            right_end_pos = int(line[4])
            if left_start_pos >= right_end_pos:
                print("Dropping line (starting from 1) %d \n"%counter)

# %%
print_dropped_sentences("/crimea/geeticka/data/relation_extraction/semeval2010/pre-processed/punct_stop_digit/test_punct_stop_digit.txt")
# Out:
# Dropping line (starting from 1) 82
#
# Dropping line (starting from 1) 1129
#
# Dropping line (starting from 1) 1255

# %% [markdown]
# Now that we know which lines were dropped, we can do an exact match and drop the necessary lines from the train data. I am just going to manually do this and write the result for the original sentences in a separate folder, along with the deletion of the lines where the predictions were made for those lines. We only care about comparing for those lines where the stop words predicted wrong and so if there isnt even a prediction for a line, it makes no sense to keep it.

# %%
def read_answers_line(line):
    linenum, relation = line.strip().split()
    return linenum, relation

# %%
def asstring(list_of_strings):
    return " ".join(list_of_strings)

# %%
def read_sentence_and_entities(line):
    line = line.strip().split()
    sentence = line[5:]
    relation = relation_dict[int(line[0])]
    entity1_idx = (int(line[1]), int(line[2]))
    entity2_idx = (int(line[3]), int(line[4]))
    entity1 = sentence[entity1_idx[0] : entity1_idx[1] + 1]
    entity2 = sentence[entity2_idx[0] : entity2_idx[1] + 1]
    
    return relation, asstring(entity1), asstring(entity2), asstring(sentence)

# %%
needed_linenum_and_relation = {}

# %% [markdown]
# In this case our correct one is baseline, but the incorrect is stop words. Put incorrect on the left, correct on the right.

# %% [markdown]
# Error analysis here would not be accurate because the border size parameter cuts out a couple of sentences. Skip this analysis and mention that.

# %%
with open(res('answers_for_dev-stop-words.txt')) as textfile1, open(res("answers_for_dev-baseline_for_stop_word_analysis.txt")) as textfile2, \
open(res('answers_for_dev-stop-words_gold.txt')) as textfile3: 
    for x, y, z in zip(textfile1, textfile2, textfile3):
        linenum, stop_words_relation = read_answers_line(x)
        _, baseline_relation = read_answers_line(y)
        _, gold_relation = read_answers_line(z)
        if baseline_relation == gold_relation and stop_words_relation != gold_relation:
            needed_linenum_and_relation[int(linenum) - 1] = (baseline_relation, stop_words_relation)

# %%
len(list(needed_linenum_and_relation.keys()))
# Out:
# 364

# %%
len(list(needed_linenum_and_relation.keys()))/len(open(res('answers_for_dev-stop-words_gold.txt')).readlines()) * 100
# Out:
# 13.411938098747237

# %% [markdown]
# Note that we list baseline first and then the entity blinded version but the prediction of the entity blinded version is correct (gold) whereas the baseline is incorrect.

# %%
cw_e2e1 = 0; ia_e2e1 = 0; mc_e1e2 = 0; ce_e2e1 = 0; ed_e1e2 = 0; cc_e1e2 = 0; mt_e1e2 = 0; 
pp_e2e1 = 0; mc_e2e1 = 0; eo_e1e2 = 0; ce_e1e2 = 0; cw_e1e2 = 0; mt_e2e1 = 0; pp_e1e2 = 0; 
eo_e2e1 = 0; cc_e2e1 = 0; ia_e1e2 = 0; ed_e2e1 = 0; other = 0
# {0: 'Component-Whole(e2,e1)',
#  1: 'Instrument-Agency(e2,e1)',
#  2: 'Member-Collection(e1,e2)',
#  3: 'Cause-Effect(e2,e1)',
#  4: 'Entity-Destination(e1,e2)',
#  5: 'Content-Container(e1,e2)',
#  6: 'Message-Topic(e1,e2)',
#  7: 'Product-Producer(e2,e1)',
#  8: 'Member-Collection(e2,e1)',
#  9: 'Entity-Origin(e1,e2)',
#  10: 'Cause-Effect(e1,e2)',
#  11: 'Component-Whole(e1,e2)',
#  12: 'Message-Topic(e2,e1)',
#  13: 'Product-Producer(e1,e2)',
#  14: 'Entity-Origin(e2,e1)',
#  15: 'Content-Container(e2,e1)',
#  16: 'Instrument-Agency(e1,e2)',
#  17: 'Entity-Destination(e2,e1)',
#  18: 'Other'}

# %%
print('We print the baseline first and then the stop words version. Gold relation corresponds to baseline\n\n')
curr_linenum = 0
with open(original_sentences_path) as original_sentences, open(stop_words_sentences_path) as stop_words_sentences:
    for x, y in zip(original_sentences, stop_words_sentences):
        needed_linenums = list(needed_linenum_and_relation.keys())
        if curr_linenum in needed_linenums:
            _, e1_b, e2_b, s_b = read_sentence_and_entities(x.strip())
            _, e1_c, e2_c, s_c = read_sentence_and_entities(y.strip())
            r_b, r_c = needed_linenum_and_relation[curr_linenum]
            if r_b == 'Component-Whole(e2,e1)':
                cw_e2e1 += 1
            elif r_b == 'Instrument-Agency(e2,e1)':
                ia_e2e1 += 1
            elif r_b == 'Member-Collection(e1,e2)':
                mc_e1e2 += 1
            elif r_b == 'Cause-Effect(e2,e1)':
                ce_e2e1 += 1
            elif r_b == 'Entity-Destination(e1,e2)':
                ed_e1e2 += 1
            elif r_b == 'Content-Container(e1,e2)':
                cc_e1e2 += 1
            elif r_b == 'Message-Topic(e1,e2)':
                mt_e1e2 += 1
            elif r_b == 'Product-Producer(e2,e1)':
                pp_e2e1 += 1
            elif r_b == 'Member-Collection(e2,e1)':
                mc_e2e1 += 1
            elif r_b == 'Entity-Origin(e1,e2)':
                eo_e1e2 += 1
            elif r_b == 'Cause-Effect(e1,e2)':
                ce_e1e2 += 1
            elif r_b == 'Component-Whole(e1,e2)':
                cw_e1e2 += 1
            elif r_b == 'Message-Topic(e2,e1)':
                mt_e2e1 += 1
            elif r_b == 'Product-Producer(e1,e2)':
                pp_e1e2 += 1
            elif r_b == 'Entity-Origin(e2,e1)':
                eo_e2e1 += 1
            elif r_b == 'Content-Container(e2,e1)':
                cc_e2e1 += 1
            elif r_b == 'Instrument-Agency(e1,e2)':
                ia_e1e2 += 1 
            elif r_b == 'Entity-Destination(e2,e1)':
                ed_e2e1 += 1
            elif r_b == 'Other':
                other += 1
            print('Predicted Relation: \t {0}, {1} \nEntities: \t {2}, {3} \t {4}, {5} \nSentences: \n\t{6} \n\t {7}'.format(
                    r_b, r_c, e1_b, e1_c, e2_b, e2_c, s_b, s_c))
            print('\n')
        curr_linenum += 1
# Out:
# We print the baseline first and then the stop words version. Gold relation corresponds to baseline
#
#
# Predicted Relation: 	 Message-Topic(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 audits, audits 	 waste, waste
# Sentences:
# 	The most common audits were about waste and recycling .
# 	 common audits waste recycling
#
#
# Predicted Relation: 	 Instrument-Agency(e2,e1), Component-Whole(e2,e1)
# Entities: 	 master, master 	 stick, stick
# Sentences:
# 	The school master teaches the lesson with a stick .
# 	 school master teaches lesson stick
#
#
# Predicted Relation: 	 Component-Whole(e1,e2), Other
# Entities: 	 ear, ear 	 elephant, elephant
# Sentences:
# 	The ear of the African elephant is significantly larger -- measuring 183 cm by 114 cm in the bush elephant .
# 	 ear African elephant significantly larger measuring NUMBER cm NUMBER cm bush elephant
#
#
# Predicted Relation: 	 Cause-Effect(e1,e2), Cause-Effect(e2,e1)
# Entities: 	 viruses, viruses 	 infections, infections
# Sentences:
# 	Of the hundreds of strains of avian influenza A viruses , only four have caused human infections : H5N1 , H7N3 , H7N7 , and H9N2 .
# 	 hundreds strains avian influenza viruses caused human infections H5N1 H7N3 H7N7 H9N2
#
#
# Predicted Relation: 	 Cause-Effect(e1,e2), Message-Topic(e1,e2)
# Entities: 	 subject, subject 	 implication, implication
# Sentences:
# 	The subject of " imply " is the source of an implication while the subject of " infer " is the recipient of an implication .
# 	 subject imply source implication subject infer recipient implication
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Content-Container(e1,e2)
# Entities: 	 bottle, bottle 	 container, container
# Sentences:
# 	Then , the target PET bottle was put inside of a metal container , which was grounded .
# 	 target PET bottle inside metal container grounded
#
#
# Predicted Relation: 	 Other, Message-Topic(e2,e1)
# Entities: 	 opinions, opinions 	 blog, blog
# Sentences:
# 	People now post their opinions to this blog .
# 	 People post opinions blog
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Other
# Entities: 	 wine, wine 	 grapes, grapes
# Sentences:
# 	This grand cru wine is made from Pinot Noir grapes and is medium to full - bodied in style .
# 	 grand cru wine Pinot Noir grapes medium bodied style
#
#
# Predicted Relation: 	 Cause-Effect(e2,e1), Cause-Effect(e1,e2)
# Entities: 	 slide, slide 	 crew, crew
# Sentences:
# 	The slide , which was triggered by an avalanche - control crew , damaged one home and blocked the road for most of the day .
# 	 slide triggered avalanche control crew damaged home blocked road day
#
#
# Predicted Relation: 	 Product-Producer(e1,e2), Message-Topic(e1,e2)
# Entities: 	 questions, questions 	 press, press
# Sentences:
# 	Ambassador SUN Shuzhong answered the questions from the local press after his visit to the Memorial Center in Kigali on Dec. 28 , 2007 .
# 	 Ambassador SUN Shuzhong answered questions local press visit Memorial Center Kigali Dec. NUMBER NUMBER
#
#
# Predicted Relation: 	 Product-Producer(e2,e1), Other
# Entities: 	 student, student 	 application, application
# Sentences:
# 	The UBC graduate student spent his free time creating an application called ColorSplash that lets people play with the colour in their digital photos .
# 	 UBC graduate student spent free time creating application called ColorSplash lets people play colour digital photos
#
#
# Predicted Relation: 	 Component-Whole(e1,e2), Component-Whole(e2,e1)
# Entities: 	 bar, bar 	 seats, seats
# Sentences:
# 	The safety bar of the seats has to be folded down by the passenger and it has to be kept closed during the journey .
# 	 safety bar seats folded passenger kept closed journey
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 defendant, defendant 	 custody, custody
# Sentences:
# 	The defendant was released from custody on March 2 , 2001 .
# 	 defendant released custody March NUMBER NUMBER
#
#
# Predicted Relation: 	 Component-Whole(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 cheese, cheese 	 dish, dish
# Sentences:
# 	We used fried cheese as an element in a dish .
# 	 fried cheese element dish
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Instrument-Agency(e2,e1)
# Entities: 	 man, man 	 car, car
# Sentences:
# 	The man was carried into a waiting police car from Coleraine Times .
# 	 man carried waiting police car Coleraine Times
#
#
# Predicted Relation: 	 Message-Topic(e1,e2), Other
# Entities: 	 views, views 	 television, television
# Sentences:
# 	David Mamet took questions from the audience and shared his views on topics such as television , the democracy of culture and the English accent .
# 	 David Mamet took questions audience shared views topics television democracy culture English accent
#
#
# Predicted Relation: 	 Cause-Effect(e1,e2), Cause-Effect(e2,e1)
# Entities: 	 response, response 	 ripple, ripple
# Sentences:
# 	The pretexts offered were laughable , and the response caused scarcely a ripple on the flood of commentary on Washington 's noble " efforts to spread democracy " .
# 	 pretexts offered laughable response caused scarcely ripple flood commentary Washington 's noble efforts spread democracy
#
#
# Predicted Relation: 	 Content-Container(e1,e2), Content-Container(e2,e1)
# Entities: 	 cat, cat 	 trap, trap
# Sentences:
# 	The mummified cat was found in a live trap with an empty dish .
# 	 mummified cat found live trap dish
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Other
# Entities: 	 data, data 	 epochs, epochs
# Sentences:
# 	The GPS network adjustment of data from both epochs is accomplished using the Ski TM software with constrains network adjustment .
# 	 GPS network adjustment data epochs accomplished Ski TM software constrains network adjustment
#
#
# Predicted Relation: 	 Product-Producer(e2,e1), Other
# Entities: 	 fetus, fetus 	 insulin, insulin
# Sentences:
# 	The placenta fully functions at this time and the fetus makes insulin and urinates .
# 	 placenta fully functions time fetus makes insulin urinates
#
#
# Predicted Relation: 	 Component-Whole(e1,e2), Other
# Entities: 	 visit, visit 	 strategy, strategy
# Sentences:
# 	Our visit is part of the general strategy to engage the global community to benefit our economy , to enhance our national security and of course , to promote the welfare of our OFWs -- the biggest community of which is right here in the Kingdom of Saudi Arabia .
# 	 visit general strategy engage global community benefit economy enhance national security course promote welfare OFWs biggest community right Kingdom Saudi Arabia
#
#
# Predicted Relation: 	 Message-Topic(e1,e2), Other
# Entities: 	 document, document 	 drugs, drugs
# Sentences:
# 	The document is about illegal drugs , which , it claims , are illegal because they are harmful .
# 	 document illegal drugs claims illegal harmful
#
#
# Predicted Relation: 	 Content-Container(e1,e2), Other
# Entities: 	 motor, motor 	 canister, canister
# Sentences:
# 	A central vacuum is a vacuum motor and filtration system built inside a canister .
# 	 central vacuum vacuum motor filtration system built inside canister
#
#
# Predicted Relation: 	 Product-Producer(e1,e2), Other
# Entities: 	 posts, posts 	 writer, writer
# Sentences:
# 	When viewers ignore negative posts , the offending writer often leaves the site .
# 	 viewers ignore negative posts offending writer leaves site
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Component-Whole(e2,e1)
# Entities: 	 lithics, lithics 	 mountain ranges, mountain ranges
# Sentences:
# 	The main origin of the metamorphic lithics is from the mountain ranges located in the north - western .
# 	 main origin metamorphic lithics mountain ranges located north western
#
#
# Predicted Relation: 	 Content-Container(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 pollen, pollen 	 basket, basket
# Sentences:
# 	The bee carries pollen in a pollen basket back to the hive .
# 	 bee carries pollen pollen basket hive
#
#
# Predicted Relation: 	 Message-Topic(e2,e1), Message-Topic(e1,e2)
# Entities: 	 thesis, thesis 	 book, book
# Sentences:
# 	This thesis was asserted in a book , written by the police chief of OCRB .
# 	 thesis asserted book written police chief OCRB
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 society, society 	 trends, trends
# Sentences:
# 	Professional education is inevitably concerned with the future directions of the profession , and Technology and Society Magazine has published a number of articles about the implications for society of various trends and issues in engineering , computer science , and education .
# 	 Professional education inevitably concerned future directions profession Technology Society Magazine published number articles implications society trends issues engineering computer science education
#
#
# Predicted Relation: 	 Message-Topic(e2,e1), Other
# Entities: 	 theory, theory 	 science fiction, science fiction
# Sentences:
# 	The ancient astronaut theory has been addressed frequently in science fiction and horror fiction .
# 	 ancient astronaut theory addressed frequently science fiction horror fiction
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Other
# Entities: 	 staff, staff 	 employees, employees
# Sentences:
# 	An initial staff of 5 yields a net saving of 1 employee , whereas an initial staff of 50 employees is reduced by 10 .
# 	 initial staff NUMBER yields net saving NUMBER employee initial staff NUMBER employees reduced NUMBER
#
#
# Predicted Relation: 	 Cause-Effect(e2,e1), Cause-Effect(e1,e2)
# Entities: 	 crash, crash 	 attack, attack
# Sentences:
# 	The deadly train crash was caused by terrorist attack .
# 	 deadly train crash caused terrorist attack
#
#
# Predicted Relation: 	 Content-Container(e1,e2), Other
# Entities: 	 wine, wine 	 jeroboam, jeroboam
# Sentences:
# 	Veuve Clicquot 's Yellow Label wine in a jeroboam is aged for up to 15 years .
# 	 Veuve Clicquot 's Yellow Label wine jeroboam aged NUMBER years
#
#
# Predicted Relation: 	 Cause-Effect(e2,e1), Other
# Entities: 	 enjoyment, enjoyment 	 programming, programming
# Sentences:
# 	These types of scripts help visually impaired individuals to get more enjoyment from programming because the action on - screen is described for them .
# 	 types scripts help visually impaired individuals enjoyment programming action screen described
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Other
# Entities: 	 cases, cases 	 term, term
# Sentences:
# 	The article does a great job of tying the three procedural cases from last term with larger complex litigation issues .
# 	 article great job tying procedural cases term larger complex litigation issues
#
#
# Predicted Relation: 	 Component-Whole(e1,e2), Other
# Entities: 	 lungs, lungs 	 ferrets, ferrets
# Sentences:
# 	An increased expression of cyclin D1 was seen in our experiments in the lungs of the ferrets supplemented with high dose Beta - carotene .
# 	 increased expression cyclin D1 seen experiments lungs ferrets supplemented high dose Beta carotene
#
#
# Predicted Relation: 	 Other, Cause-Effect(e1,e2)
# Entities: 	 Barrages, Barrages 	 energy, energy
# Sentences:
# 	Barrages make use of the potential energy in the difference in height ( or head ) between high and low tides .
# 	 Barrages use potential energy difference height head high low tides
#
#
# Predicted Relation: 	 Product-Producer(e1,e2), Message-Topic(e1,e2)
# Entities: 	 report, report 	 commission, commission
# Sentences:
# 	A report by the commission forecasts that revenues of the nation 's post and telecommunications sector will grow 22.4 % year - on - year to 60 trillion dong ( $ 3.75b ) this year .
# 	 report commission forecasts revenues nation 's post telecommunications sector grow NUMBER year year NUMBER NUMBER dong $ 3.75b year
#
#
# Predicted Relation: 	 Component-Whole(e2,e1), Entity-Origin(e1,e2)
# Entities: 	 car, car 	 engine, engine
# Sentences:
# 	The competitor car achieved the top fuel efficiency using a small internal combustion engine .
# 	 competitor car achieved fuel efficiency small internal combustion engine
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Other
# Entities: 	 motives, motives 	 trial, trial
# Sentences:
# 	The prosecution seeks to enter motives into Gibbs trial .
# 	 prosecution seeks enter motives Gibbs trial
#
#
# Predicted Relation: 	 Other, Product-Producer(e1,e2)
# Entities: 	 compeers, compeers 	 profession, profession
# Sentences:
# 	Todd was quite as much on a level with his compeers of the profession , in that country , as was Marmaduke with his brethren on the bench .
# 	 Todd level compeers profession country Marmaduke brethren bench
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 spreads, spreads 	 book, book
# Sentences:
# 	Twelve double - page spreads from the book are enlarged and reproduced for hanging with the exhibit to illustrate some of the techniques used in the creation of the work in the exhibit .
# 	 double page spreads book enlarged reproduced hanging exhibit illustrate techniques creation work exhibit
#
#
# Predicted Relation: 	 Other, Cause-Effect(e2,e1)
# Entities: 	 activation, activation 	 source, source
# Sentences:
# 	The Meon activation was done with a light source by bouncing , splitting , and changing the color of the beams .
# 	 Meon activation light source bouncing splitting changing color beams
#
#
# Predicted Relation: 	 Other, Entity-Origin(e2,e1)
# Entities: 	 cartload, cartload 	 firewood, firewood
# Sentences:
# 	I used it to pay for a cartload of firewood I bought from a peasant .
# 	 pay cartload firewood bought peasant
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Other
# Entities: 	 clutch, clutch 	 conferences, conferences
# Sentences:
# 	Having completed my clutch of conferences for the time being at least , I 'm back in the office today ploughing through the usual pile of emails that always accompany any period of absence from the computer .
# 	 Having completed clutch conferences time 'm office today ploughing usual pile emails accompany period absence computer
#
#
# Predicted Relation: 	 Content-Container(e1,e2), Other
# Entities: 	 finger, finger 	 can,
# Sentences:
# 	A human finger was found in a can of menudo soup .
# 	 human finger found menudo soup
#
#
# Predicted Relation: 	 Other, Component-Whole(e2,e1)
# Entities: 	 Stone, Stone 	 grinding, grinding
# Sentences:
# 	Stone grinding flattens the ski base , removes burnt and damaged base material and provides important micro - structure .
# 	 Stone grinding flattens ski base removes burnt damaged base material provides important micro structure
#
#
# Predicted Relation: 	 Other, Content-Container(e1,e2)
# Entities: 	 opening, opening 	 cask, cask
# Sentences:
# 	A latching device removably secures and sealingly engages a closure around an opening in a cask .
# 	 latching device removably secures sealingly engages closure opening cask
#
#
# Predicted Relation: 	 Instrument-Agency(e2,e1), Other
# Entities: 	 family, family 	 taxi, taxi
# Sentences:
# 	Ansari allegdely bombed Jhaveri Bazaar and the family took the taxi to the Gateway of India .
# 	 Ansari allegdely bombed Jhaveri Bazaar family took taxi Gateway India
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Other
# Entities: 	 song, song 	 MP player, MP player
# Sentences:
# 	Rythmbox moves the song into the MP player .
# 	 Rythmbox moves song MP player
#
#
# Predicted Relation: 	 Other, Component-Whole(e1,e2)
# Entities: 	 transport, transport 	 mechanism, mechanism
# Sentences:
# 	Active transport is a mechanism evolved to mediate traffic across cellular membranes .
# 	 Active transport mechanism evolved mediate traffic cellular membranes
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Component-Whole(e2,e1)
# Entities: 	 cluster, cluster 	 computers, computers
# Sentences:
# 	This machine is a cluster of 3240 computers , each with 40 processing cores and includes both AMD and Cell processors .
# 	 machine cluster NUMBER computers NUMBER processing cores includes AMD Cell processors
#
#
# Predicted Relation: 	 Component-Whole(e2,e1), Other
# Entities: 	 earphones, earphones 	 cord, cord
# Sentences:
# 	These earphones have a short cord so as not to get tangled up or create drag while submerged in water .
# 	 earphones short cord tangled create drag submerged water
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 concerns, concerns 	 cases, cases
# Sentences:
# 	There are serious legal concerns in relation to cases of this kind and these are the factors we have to bear in mind when deciding what we publish or broadcast .
# 	 legal concerns relation cases kind factors bear mind deciding publish broadcast
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 turtles, turtles 	 shells, shells
# Sentences:
# 	After recovery , three rescued turtles come out of their shells .
# 	 recovery rescued turtles come shells
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Other
# Entities: 	 cadets, cadets 	 training, training
# Sentences:
# 	The cadets departed from training with smiles on their faces as they made the journey back to their schools .
# 	 cadets departed training smiles faces journey schools
#
#
# Predicted Relation: 	 Instrument-Agency(e2,e1), Other
# Entities: 	 associations, associations 	 receiverships, receiverships
# Sentences:
# 	Condo associations are turning to receiverships to collect rent on foreclosed units .
# 	 Condo associations turning receiverships collect rent foreclosed units
#
#
# Predicted Relation: 	 Cause-Effect(e2,e1), Other
# Entities: 	 satisfaction, satisfaction 	 playing, playing
# Sentences:
# 	As a guitarist I get so much satisfaction from the playing and performing of music .
# 	 guitarist satisfaction playing performing music
#
#
# Predicted Relation: 	 Other, Component-Whole(e2,e1)
# Entities: 	 hand, hand 	 gestures, gestures
# Sentences:
# 	In 2006 we reported on a robotic hand that formed rock , paper , scissors gestures by reading a human subject 's mind via an MRI scanner .
# 	 NUMBER reported robotic hand formed rock paper scissors gestures reading human subject 's mind MRI scanner
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Other
# Entities: 	 brotherhood, brotherhood 	 kings, kings
# Sentences:
# 	The boy ends up having to find a second and third pendant in order to save his family , following clues left by the followers of an ancient brotherhood of four forgotten British kings .
# 	 boy ends having find second pendant order save family following clues left followers ancient brotherhood forgotten British kings
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Component-Whole(e2,e1)
# Entities: 	 Plants, Plants 	 rooms, rooms
# Sentences:
# 	Plants from the tissue culture laboratory were brought into plant growth rooms .
# 	 Plants tissue culture laboratory brought plant growth rooms
#
#
# Predicted Relation: 	 Component-Whole(e1,e2), Other
# Entities: 	 arm, arm 	 government, government
# Sentences:
# 	The Maritime Administration of Latvia is the arm of the government , under the Ministry of Transport , which has the overall responsibility for overseeing maritime concerns .
# 	 Maritime Administration Latvia arm government Ministry Transport overall responsibility overseeing maritime concerns
#
#
# Predicted Relation: 	 Other, Instrument-Agency(e1,e2)
# Entities: 	 chivalry, chivalry 	 warrior - knights, warrior knights
# Sentences:
# 	The nobility , honor , and chivalry of the warrior - knights of medieval Europe disappeared with modern warfare 's machine guns , tanks , and nuclear bombs .
# 	 nobility honor chivalry warrior knights medieval Europe disappeared modern warfare 's machine guns tanks nuclear bombs
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Entity-Destination(e1,e2)
# Entities: 	 jam, jam 	 trucks, trucks
# Sentences:
# 	I realized then that the jam of trucks at the gate probably belonged to his young charges .
# 	 realized jam trucks gate probably belonged young charges
#
#
# Predicted Relation: 	 Message-Topic(e2,e1), Other
# Entities: 	 types, types 	 sections, sections
# Sentences:
# 	Three types of gesture features have been introduced in previous sections .
# 	 types gesture features introduced previous sections
#
#
# Predicted Relation: 	 Cause-Effect(e2,e1), Component-Whole(e1,e2)
# Entities: 	 flicker, flicker 	 candles, candles
# Sentences:
# 	I still shiver as I remember trying to page through economics texts by the flicker from candles while clad in overcoat , scarf , and little knitted gloves with the fingertips cut off , in the 4 p.m.
# 	 shiver remember trying page economics texts flicker candles clad overcoat scarf little knitted gloves fingertips cut NUMBER p.m.
#
#
# Predicted Relation: 	 Component-Whole(e2,e1), Component-Whole(e1,e2)
# Entities: 	 ear, ear 	 canal, canal
# Sentences:
# 	After sound waves enter the outer ear , they travel through the ear canal and make their way to the middle ear .
# 	 sound waves enter outer ear travel ear canal way middle ear
#
#
# Predicted Relation: 	 Cause-Effect(e1,e2), Cause-Effect(e2,e1)
# Entities: 	 distraction, distraction 	 incident, incident
# Sentences:
# 	The distraction caused by the students , coupled with limited vision down the track , caused the incident to occur .
# 	 distraction caused students coupled limited vision track caused incident occur
#
#
# Predicted Relation: 	 Member-Collection(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 members, members 	 gangs, gangs
# Sentences:
# 	Six members of one of Mexico 's most active drug gangs , including someone accused of being the organization 's bookkeeper , were arrested this week .
# 	 members Mexico 's active drug gangs including accused organization 's bookkeeper arrested week
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Other
# Entities: 	 app, app 	 newspaper, newspaper
# Sentences:
# 	An app from local newspaper the Manchester Evening News has topped the UK Palm Pre app store sales chart in its first week of release .
# 	 app local newspaper Manchester Evening News topped UK Palm Pre app store sales chart week release
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 cross, cross 	 site, site
# Sentences:
# 	The base in which it sits hides the damage which occurred when the cross was removed from its initial site on the Long Tan battlefield .
# 	 base sits hides damage occurred cross removed initial site Long Tan battlefield
#
#
# Predicted Relation: 	 Component-Whole(e2,e1), Other
# Entities: 	 pistil, pistil 	 carpels, carpels
# Sentences:
# 	The pistil , made up of one or more carpels , encloses an ovary that contains the ovules , or potential seeds .
# 	 pistil carpels encloses ovary contains ovules potential seeds
#
#
# Predicted Relation: 	 Other, Member-Collection(e1,e2)
# Entities: 	 concern, concern 	 economy, economy
# Sentences:
# 	There is great concern among voters over the economy .
# 	 great concern voters economy
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Content-Container(e1,e2)
# Entities: 	 artist, artist 	 can,
# Sentences:
# 	Finally , the escape artist was put inside a locked milk can filled with water at the Old Town Square in Fort Collins .
# 	 Finally escape artist inside locked milk filled water Old Town Square Fort Collins
#
#
# Predicted Relation: 	 Instrument-Agency(e2,e1), Product-Producer(e2,e1)
# Entities: 	 guy, guy 	 map, map
# Sentences:
# 	The first time , the guy hid the taximeter with a map and tried to get 35 euros instead of 12 .
# 	 time guy hid taximeter map tried NUMBER euros instead NUMBER
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Other
# Entities: 	 volery, volery 	 birds, birds
# Sentences:
# 	Your writer had a volery of birds in a large aviary in the back yard .
# 	 writer volery birds large aviary yard
#
#
# Predicted Relation: 	 Other, Message-Topic(e2,e1)
# Entities: 	 areas, areas 	 composition, composition
# Sentences:
# 	The two central areas of controversy have to do with composition and titles .
# 	 central areas controversy composition titles
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Other
# Entities: 	 audience, audience 	 kids, kids
# Sentences:
# 	The cast is appealing because they connect with the audience of young kids and their parents .
# 	 cast appealing connect audience young kids parents
#
#
# Predicted Relation: 	 Message-Topic(e1,e2), Other
# Entities: 	 information, information 	 employees, employees
# Sentences:
# 	The U.S. Transportation Security Administration ( TSA ) has lost a hard drive containing information about 100,000 former and current employees .
# 	 U.S. Transportation Security Administration TSA lost hard drive containing information NUMBER current employees
#
#
# Predicted Relation: 	 Message-Topic(e1,e2), Other
# Entities: 	 drama, drama 	 aftermath, aftermath
# Sentences:
# 	Robert Redford 's historical drama about the aftermath of the assassination of Abraham Lincoln looks set to get under way .
# 	 Robert Redford 's historical drama aftermath assassination Abraham Lincoln looks set way
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Content-Container(e1,e2)
# Entities: 	 server, server 	 cabinet, cabinet
# Sentences:
# 	The size of the hole meant that when the server was put inside the cabinet it was dead easy to put the power and network wires through the hole .
# 	 size hole meant server inside cabinet dead easy power network wires hole
#
#
# Predicted Relation: 	 Product-Producer(e1,e2), Product-Producer(e2,e1)
# Entities: 	 company, company 	 fireman, fireman
# Sentences:
# 	American Firehouse Brewing Supply , located in Arlington / Pantego , Texas , is a company established by a fireman who has a love of home brewing quality beer .
# 	 American Firehouse Brewing Supply located Arlington Pantego Texas company established fireman love home brewing quality beer
#
#
# Predicted Relation: 	 Cause-Effect(e2,e1), Other
# Entities: 	 joy, joy 	 animals, animals
# Sentences:
# 	Seniors get much joy from animals .
# 	 Seniors joy animals
#
#
# Predicted Relation: 	 Message-Topic(e1,e2), Other
# Entities: 	 essay, essay 	 literature, literature
# Sentences:
# 	The paper includes both an essay surveying the literature and a descriptor - indexed bibliography of over 200 papers and books .
# 	 paper includes essay surveying literature descriptor indexed bibliography NUMBER papers books
#
#
# Predicted Relation: 	 Other, Entity-Origin(e1,e2)
# Entities: 	 skills, skills 	 surgery, surgery
# Sentences:
# 	Over the past decade , robotics has driven forward the concept of minimally invasive surgery , building on the skills developed in keyhole surgery and moving away from open - body operations .
# 	 past decade robotics driven forward concept minimally invasive surgery building skills developed keyhole surgery moving away open body operations
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 taxes, taxes 	 years, years
# Sentences:
# 	I owed some back taxes from pervious years .
# 	 owed taxes pervious years
#
#
# Predicted Relation: 	 Other, Entity-Destination(e1,e2)
# Entities: 	 girl, girl 	 danger, danger
# Sentences:
# 	As the young girl journeyed into unbelievable danger , she did not have the faintest clue that she alone was destined to win , or to lose , this more - than - mortal battle .
# 	 young girl journeyed unbelievable danger faintest clue destined win lose mortal battle
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 symposium, symposium 	 physicians, physicians
# Sentences:
# 	For 31 years , the symposium has assembled international physicians and researchers from academic institutions and private organisations .
# 	 NUMBER years symposium assembled international physicians researchers academic institutions private organisations
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Other
# Entities: 	 ingredients, ingredients 	 mixing ball, mixing ball
# Sentences:
# 	We have put the ingredients into a big mixing ball long before we started baking the plain naan .
# 	 ingredients big mixing ball long started baking plain naan
#
#
# Predicted Relation: 	 Component-Whole(e2,e1), Product-Producer(e1,e2)
# Entities: 	 prostate, prostate 	 glands, glands
# Sentences:
# 	The normal prostate is composed of glands and stroma .
# 	 normal prostate composed glands stroma
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Other
# Entities: 	 heroes, heroes 	 literature, literature
# Sentences:
# 	This series is about a guy named Walter who shows what it 's like to replace famous heroes from literature , movies , television , etc . with himself .
# 	 series guy named Walter shows 's like replace famous heroes literature movies television etc
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Other
# Entities: 	 bed, bed 	 oysters, oysters
# Sentences:
# 	A polypropylene net , attached to the bottom of the fluidized bed section , acted as a flow distributor and a support for the static bed of oysters .
# 	 polypropylene net attached fluidized bed section acted flow distributor support static bed oysters
#
#
# Predicted Relation: 	 Product-Producer(e2,e1), Component-Whole(e2,e1)
# Entities: 	 kitchen, kitchen 	 meal, meal
# Sentences:
# 	There were no vegetarian entrees on the menu , but the kitchen quickly prepared a beautiful meal of 8 different steamed vegetables .
# 	 vegetarian entrees menu kitchen quickly prepared beautiful meal NUMBER different steamed vegetables
#
#
# Predicted Relation: 	 Product-Producer(e1,e2), Other
# Entities: 	 character, character 	 producers, producers
# Sentences:
# 	Actually , he is a cartoon character devised by the two producers to serve their blistering cocktail of dancehall reggae , hip - hop and electro .
# 	 Actually cartoon character devised producers serve blistering cocktail dancehall reggae hip hop electro
#
#
# Predicted Relation: 	 Product-Producer(e1,e2), Instrument-Agency(e1,e2)
# Entities: 	 barrels, barrels 	 coopers, coopers
# Sentences:
# 	The highest quality barrels are those hand - made by professional coopers .
# 	 highest quality barrels hand professional coopers
#
#
# Predicted Relation: 	 Component-Whole(e2,e1), Instrument-Agency(e2,e1)
# Entities: 	 man, man 	 thumb, thumb
# Sentences:
# 	He noticed a speck of blood on the man 's thumb and what he thought were several corresponding drops on the driver 's door of the truck .
# 	 noticed speck blood man 's thumb thought corresponding drops driver 's door truck
#
#
# Predicted Relation: 	 Component-Whole(e1,e2), Other
# Entities: 	 switch, switch 	 light, light
# Sentences:
# 	But even as she fumbled impatiently for the switch of the electric light , she knew that the voice had not come from the bed on the further side of the room .
# 	 fumbled impatiently switch electric light knew voice come bed room
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 comedy format, comedy format 	 sequences, sequences
# Sentences:
# 	TV total started as a comedy format mainly showing and commenting on funny and embarrassing sequences from other TV programs .
# 	 TV total started comedy format mainly showing commenting funny embarrassing sequences TV programs
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 Mail, Mail 	 city, city
# Sentences:
# 	Mail was delivered from the city once each week .
# 	 Mail delivered city week
#
#
# Predicted Relation: 	 Product-Producer(e2,e1), Instrument-Agency(e2,e1)
# Entities: 	 painter, painter 	 self - portrait, self portrait
# Sentences:
# 	The new pencil and graphite drawing is the painter 's first self - portrait in 35 years and took six years to complete .
# 	 new pencil graphite drawing painter 's self portrait NUMBER years took years complete
#
#
# Predicted Relation: 	 Component-Whole(e2,e1), Other
# Entities: 	 dowel, dowel 	 groove, groove
# Sentences:
# 	Picture 192 shows a completed dowel with a small groove running along its entire length .
# 	 Picture NUMBER shows completed dowel small groove running entire length
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Other
# Entities: 	 studies, studies 	 inquiry, inquiry
# Sentences:
# 	Critical audience studies are migrating into intellectual inquiry focused on participation developing the stress on processes of interactive engagement .
# 	 Critical audience studies migrating intellectual inquiry focused participation developing stress processes interactive engagement
#
#
# Predicted Relation: 	 Message-Topic(e1,e2), Component-Whole(e1,e2)
# Entities: 	 notes, notes 	 telephone call, telephone
# Sentences:
# 	You have been asked to make notes about a telephone call left by a colleague in the German office of the bank .
# 	 asked notes telephone left colleague German office bank
#
#
# Predicted Relation: 	 Other, Entity-Origin(e2,e1)
# Entities: 	 northeast, northeast 	 contention, contention
# Sentences:
# 	The northeast was the source of contention between these various rivaling groups .
# 	 northeast source contention rivaling groups
#
#
# Predicted Relation: 	 Product-Producer(e2,e1), Other
# Entities: 	 Technicians, Technicians 	 stage, stage
# Sentences:
# 	Technicians quickly prepared the stage for the headliner .
# 	 Technicians quickly prepared stage headliner
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Product-Producer(e1,e2)
# Entities: 	 audience, audience 	 readers, readers
# Sentences:
# 	Some articles are written for the widest audience of general readers .
# 	 articles written widest audience general readers
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Cause-Effect(e2,e1)
# Entities: 	 plague, plague 	 insects, insects
# Sentences:
# 	And with a flourish of her wand she unleashed a plague of biting insects , the sand fly .
# 	 flourish wand unleashed plague biting insects sand fly
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Content-Container(e1,e2)
# Entities: 	 specimens, specimens 	 jar, jar
# Sentences:
# 	He rolled up towel and dump specimens into the pint jar .
# 	 rolled towel dump specimens pint jar
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Product-Producer(e1,e2)
# Entities: 	 insulin, insulin 	 pancreas, pancreas
# Sentences:
# 	When the blood glucose levels are lowered , the insulin release from the pancreas is turned down .
# 	 blood glucose levels lowered insulin release pancreas turned
#
#
# Predicted Relation: 	 Product-Producer(e2,e1), Entity-Destination(e1,e2)
# Entities: 	 glass - blower, glass blower 	 vase, vase
# Sentences:
# 	Mouth blown by a glass - blower , each vase is slightly different .
# 	 Mouth blown glass blower vase slightly different
#
#
# Predicted Relation: 	 Cause-Effect(e1,e2), Cause-Effect(e2,e1)
# Entities: 	 crisis, crisis 	 jobless rate, jobless rate
# Sentences:
# 	A recent book by Carmen M. Reinhart and Kenneth S. Rogoff , two economists , found that over the last century the typical crisis had caused the jobless rate in the country where it occurred to rise for almost five years .
# 	 recent book Carmen M. Reinhart Kenneth S. Rogoff economists found century typical crisis caused jobless rate country occurred rise years
#
#
# Predicted Relation: 	 Instrument-Agency(e2,e1), Product-Producer(e2,e1)
# Entities: 	 staff, staff 	 tools, tools
# Sentences:
# 	Once the data is collected , an emissions inventory is completed by staff using calculation tools from the GHG Protocol .
# 	 data collected emissions inventory completed staff calculation tools GHG Protocol
#
#
# Predicted Relation: 	 Other, Component-Whole(e1,e2)
# Entities: 	 activities, activities 	 development, development
# Sentences:
# 	The target of those activities is development of meta - information systems , which enables record metadata of geodata .
# 	 target activities development meta information systems enables record metadata geodata
#
#
# Predicted Relation: 	 Other, Content-Container(e1,e2)
# Entities: 	 human, human 	 box, box
# Sentences:
# 	The human lies down in a sealed box and allows his mind to do nothing but operate the avatar .
# 	 human lies sealed box allows mind operate avatar
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 quote, quote 	 email, email
# Sentences:
# 	By the way , that quote was from an email to researchers , not the official Google blog post .
# 	 way quote email researchers official Google blog post
#
#
# Predicted Relation: 	 Instrument-Agency(e2,e1), Message-Topic(e1,e2)
# Entities: 	 biographer, biographer 	 minutiae, minutiae
# Sentences:
# 	In a poetic series of alternately charming , dry and sometimes tragic aphorisms the biographer constructs a personality from minutiae .
# 	 poetic series alternately charming dry tragic aphorisms biographer constructs personality minutiae
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Entity-Origin(e1,e2)
# Entities: 	 water, water 	 well,
# Sentences:
# 	Sterile distilled water was put inside the fifth well to serve as negative control while gentamicin was used as positive control in the fourth well .
# 	 Sterile distilled water inside fifth serve negative control gentamicin positive control fourth
#
#
# Predicted Relation: 	 Component-Whole(e1,e2), Member-Collection(e2,e1)
# Entities: 	 battalion, battalion 	 cavalry, cavalry
# Sentences:
# 	The 34th battalion was a part of the cavalry not surrendered by Gen. Robert .
# 	 34th battalion cavalry surrendered Gen. Robert
#
#
# Predicted Relation: 	 Instrument-Agency(e2,e1), Other
# Entities: 	 therapist, therapist 	 way, way
# Sentences:
# 	As I travelled the world and had facials in every corner , I have finally found a therapist with such a perfect way of touching my face .
# 	 travelled world facials corner finally found therapist perfect way touching face
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Other
# Entities: 	 paper, paper 	 thesis, thesis
# Sentences:
# 	This paper is constructed from a portion of a thesis presented by Edward W. Shand , June , 1930 , for the degree of Doctor of Philosophy at New York University .
# 	 paper constructed portion thesis presented Edward W. Shand June NUMBER degree Doctor Philosophy New York University
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 train, train 	 airport, airport
# Sentences:
# 	Line 3 ( blue ) completed part : from Egaleo to Doukissis Plakendias , where it connects with the new Suburban train from the airport .
# 	 Line NUMBER blue completed Egaleo Doukissis Plakendias connects new Suburban train airport
#
#
# Predicted Relation: 	 Product-Producer(e2,e1), Other
# Entities: 	 capuchins, capuchins 	 knives, knives
# Sentences:
# 	During experiments in captivity , capuchins have made flint knives after banging a piece of flint against the floor until it broke .
# 	 experiments captivity capuchins flint knives banging piece flint floor broke
#
#
# Predicted Relation: 	 Content-Container(e1,e2), Other
# Entities: 	 latte, latte 	 glass, glass
# Sentences:
# 	The coffees were all tasty , even though my latte was in a glass after we had discussed the size of the cup , I always find them hard to drink .
# 	 coffees tasty latte glass discussed size cup find hard drink
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Other
# Entities: 	 needs, needs 	 society, society
# Sentences:
# 	Urgent needs are approaching the society , which requires dynamic changes .
# 	 Urgent needs approaching society requires dynamic changes
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Other
# Entities: 	 belt, belt 	 asteroids, asteroids
# Sentences:
# 	Ceres is the largest known asteroid at approximately 950 km ( 590 miles ) in diameter , and it lies in the belt of asteroids between Mars and Jupiter .
# 	 Ceres largest known asteroid approximately NUMBER km NUMBER miles diameter lies belt asteroids Mars Jupiter
#
#
# Predicted Relation: 	 Content-Container(e1,e2), Component-Whole(e2,e1)
# Entities: 	 chabazite, chabazite 	 multiple U - tube, multiple U tube
# Sentences:
# 	The chabazite was contained in a multiple U - tube and was first thoroughly outgassed at 550 ' in a good vacuum .
# 	 chabazite contained multiple U tube thoroughly outgassed NUMBER good vacuum
#
#
# Predicted Relation: 	 Other, Member-Collection(e1,e2)
# Entities: 	 referee, referee 	 game, game
# Sentences:
# 	A referee , or on - ice official , is responsible for enforcing the rules during a game .
# 	 referee ice official responsible enforcing rules game
#
#
# Predicted Relation: 	 Product-Producer(e1,e2), Other
# Entities: 	 clauses, clauses 	 framers, framers
# Sentences:
# 	Although the clauses were invented by the framers to serve common values , there is some tension between the two .
# 	 clauses invented framers serve common values tension
#
#
# Predicted Relation: 	 Other, Component-Whole(e2,e1)
# Entities: 	 project, project 	 standard, standard
# Sentences:
# 	A project to regulate the standard of private rental properties in Dumfries and Galloway looks set to close .
# 	 project regulate standard private rental properties Dumfries Galloway looks set close
#
#
# Predicted Relation: 	 Member-Collection(e1,e2), Member-Collection(e2,e1)
# Entities: 	 ewes, ewes 	 flock, flock
# Sentences:
# 	A Suffolk ram was removed from the flock and test mated to unrelated Suffolk ewes in another flock ; 14 of the resulting 43 lambs born in 1984 had an identical congenital renal disease .
# 	 Suffolk ram removed flock test mated unrelated Suffolk ewes flock NUMBER resulting NUMBER lambs born NUMBER identical congenital renal disease
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Message-Topic(e2,e1)
# Entities: 	 formalism, formalism 	 literature, literature
# Sentences:
# 	He then maps the development of Anglo - American formalism from Modernist literature to the American and British academies .
# 	 maps development Anglo American formalism Modernist literature American British academies
#
#
# Predicted Relation: 	 Content-Container(e1,e2), Other
# Entities: 	 body, body 	 drum, drum
# Sentences:
# 	Her decomposed body was found in a drum in a Lake Elsinore field .
# 	 decomposed body found drum Lake Elsinore field
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Component-Whole(e1,e2)
# Entities: 	 setup, setup 	 chimney, chimney
# Sentences:
# 	The setup was put inside a chimney in order to enhance the natural convection cooling .
# 	 setup inside chimney order enhance natural convection cooling
#
#
# Predicted Relation: 	 Instrument-Agency(e2,e1), Other
# Entities: 	 managers, managers 	 spreadsheets, spreadsheets
# Sentences:
# 	Many times , the problem of keeping track of depreciation rates in you fixed assets is attempted by managers using spreadsheets which they program themselves .
# 	 times problem keeping track depreciation rates fixed assets attempted managers spreadsheets program
#
#
# Predicted Relation: 	 Message-Topic(e1,e2), Message-Topic(e2,e1)
# Entities: 	 talks, talks 	 contract, contract
# Sentences:
# 	Preliminary talks between the association and Nigel Worthington regarding a new contract took place last week and these talks are still ongoing .
# 	 Preliminary talks association Nigel Worthington new contract took place week talks ongoing
#
#
# Predicted Relation: 	 Component-Whole(e1,e2), Component-Whole(e2,e1)
# Entities: 	 jaws, jaws 	 handle, handle
# Sentences:
# 	The covered Clamp style handles hold mop firmly between the jaws of the mop handle .
# 	 covered Clamp style handles hold mop firmly jaws mop handle
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Content-Container(e1,e2)
# Entities: 	 amount,  	 cylinder, cylinder
# Sentences:
# 	At this moment , a certain amount of chlorine gas was placed inside a cylinder with a movable piston at one end .
# 	 moment certain chlorine gas placed inside cylinder movable piston end
#
#
# Predicted Relation: 	 Other, Entity-Origin(e1,e2)
# Entities: 	 game, game 	 television, television
# Sentences:
# 	While playing the labyrinth game through the television , I thought of a few ideas that I wanted to test out .
# 	 playing labyrinth game television thought ideas wanted test
#
#
# Predicted Relation: 	 Cause-Effect(e2,e1), Cause-Effect(e1,e2)
# Entities: 	 election, election 	 appointment, appointment
# Sentences:
# 	The election was caused by the appointment of Donald Sumner , formerly Conservative MP for Orpington , to be a county court judge .
# 	 election caused appointment Donald Sumner Conservative MP Orpington county court judge
#
#
# Predicted Relation: 	 Component-Whole(e1,e2), Other
# Entities: 	 bar, bar 	 injector, injector
# Sentences:
# 	When the loading time was completed , the sliding bar of the injector was displaced manually to the other resting position ( dashed area ) .
# 	 loading time completed sliding bar injector displaced manually resting position dashed area
#
#
# Predicted Relation: 	 Other, Entity-Destination(e1,e2)
# Entities: 	 people, people 	 hunger, hunger
# Sentences:
# 	Another 40 million people have been pushed into hunger this year .
# 	 NUMBER NUMBER people pushed hunger year
#
#
# Predicted Relation: 	 Cause-Effect(e2,e1), Cause-Effect(e1,e2)
# Entities: 	 tail, tail 	 solar wind, solar wind
# Sentences:
# 	The straight , blue ion tail is caused by the solar wind and the curved dust tail is caused by solar radiation pressure .
# 	 straight blue ion tail caused solar wind curved dust tail caused solar radiation pressure
#
#
# Predicted Relation: 	 Message-Topic(e2,e1), Message-Topic(e1,e2)
# Entities: 	 Proposals, Proposals 	 conference, conference
# Sentences:
# 	Proposals to simplify the university admissions process have been outlined at a conference of secondary school head teachers .
# 	 Proposals simplify university admissions process outlined conference secondary school head teachers
#
#
# Predicted Relation: 	 Product-Producer(e1,e2), Component-Whole(e1,e2)
# Entities: 	 roof, roof 	 carpenter, carpenter
# Sentences:
# 	During the reign of King Richard II , this was replaced by a hammerbeam roof by the royal carpenter Hugh Herland , " the greatest creation of medieval timber architecture " .
# 	 reign King Richard II replaced hammerbeam roof royal carpenter Hugh Herland greatest creation medieval timber architecture
#
#
# Predicted Relation: 	 Cause-Effect(e2,e1), Other
# Entities: 	 interaction, interaction 	 layers, layers
# Sentences:
# 	On this basis , the vibronically coupled CD bands of lutein diacetate are attributed to an excitonic interaction arose from the twisted nematic layers .
# 	 basis vibronically coupled CD bands lutein diacetate attributed excitonic interaction arose twisted nematic layers
#
#
# Predicted Relation: 	 Instrument-Agency(e2,e1), Other
# Entities: 	 waiters, waiters 	 mop, mop
# Sentences:
# 	The mess was rapidly cleaned by one of the waiters with a mop and disinfectant and the meal continued .
# 	 mess rapidly cleaned waiters mop disinfectant meal continued
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 think tank, think tank 	 issues, issues
# Sentences:
# 	The Boyd Group is a British based , independent think tank considering issues relating to animal testing .
# 	 Boyd Group British based independent think tank considering issues relating animal testing
#
#
# Predicted Relation: 	 Other, Product-Producer(e2,e1)
# Entities: 	 group, group 	 scholarships, scholarships
# Sentences:
# 	The Seattle women 's group distributes a number of small scholarships for single mothers who want to go to college .
# 	 Seattle women 's group distributes number small scholarships single mothers want college
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Other
# Entities: 	 citation, citation 	 books, books
# Sentences:
# 	And the citation from Whelpton 's books was listed first in the assortment of quotations specifically characterized as " comparatively modest " .
# 	 citation Whelpton 's books listed assortment quotations specifically characterized comparatively modest
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 Considerations, Considerations 	 cases, cases
# Sentences:
# 	Considerations have been concerned with cases where the forces between particles can be handled in a satisfactory manner .
# 	 Considerations concerned cases forces particles handled satisfactory manner
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 Seminars, Seminars 	 area, area
# Sentences:
# 	Seminars and conferences have been organised around the Asia - Pacific area in the most recent years by different organisations and institutions .
# 	 Seminars conferences organised Asia Pacific area recent years different organisations institutions
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 convention, convention 	 bills, bills
# Sentences:
# ...
# Sentences:
# 	I found , moreover , a body of trained and earnest school workers , whose wealth of experience , professional spirit , and loyal support of the new organization gave ample assurance of advancement in all departments of public school work .
# 	 found body trained earnest school workers wealth experience professional spirit loyal support new organization gave ample assurance advancement departments public school work
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Other
# Entities: 	 basin, basin 	 depression, depression
# Sentences:
# 	The basin has sunk into a deep depression .
# 	 basin sunk deep depression
#
#
# Predicted Relation: 	 Cause-Effect(e1,e2), Cause-Effect(e2,e1)
# Entities: 	 events, events 	 dissolution, dissolution
# Sentences:
# 	The events at the trial caused the dissolution of the Communist League , and a general dampening of revolutionary activity .
# 	 events trial caused dissolution Communist League general dampening revolutionary activity
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Product-Producer(e1,e2)
# Entities: 	 request, request 	 firm, firm
# Sentences:
# 	A month ago a request arrived from an American environmental consulting firm .
# 	 month ago request arrived American environmental consulting firm
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Component-Whole(e2,e1)
# Entities: 	 air, air 	 lungs, lungs
# Sentences:
# 	The air was pressed from his lungs ; it felt like millions of electrodes were attached to his neural system .
# 	 air pressed lungs felt like millions electrodes attached neural system
#
#
# Predicted Relation: 	 Cause-Effect(e2,e1), Cause-Effect(e1,e2)
# Entities: 	 incident, incident 	 entry, entry
# Sentences:
# 	The incident was caused by the entry of high pressure gas from a deep formation that got confined in the porthole of the well .
# 	 incident caused entry high pressure gas deep formation got confined porthole
#
#
# Predicted Relation: 	 Cause-Effect(e1,e2), Cause-Effect(e2,e1)
# Entities: 	 imbalance, imbalance 	 torque, torque
# Sentences:
# 	The imbalance caused a torque on the moon that acted to synchronize its rotation with its orbit , so that one side is always facing the earth .
# 	 imbalance caused torque moon acted synchronize rotation orbit facing earth
#
#
# Predicted Relation: 	 Other, Member-Collection(e1,e2)
# Entities: 	 officer, officer 	 college, college
# Sentences:
# 	The Dean of the Faculty is the chief academic officer of the college and has primary responsibility for matters of academic policy that affect the Faculty and for the educational consequences of the academic budget .
# 	 Dean Faculty chief academic officer college primary responsibility matters academic policy affect Faculty educational consequences academic budget
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 studies, studies 	 vegetation, vegetation
# Sentences:
# 	Those early studies were directed toward examining the spring vegetation green - up and subsequent summer and fall dry - down .
# 	 early studies directed examining spring vegetation green subsequent summer fall dry
#
#
# Predicted Relation: 	 Other, Instrument-Agency(e2,e1)
# Entities: 	 singer, singer 	 song, song
# Sentences:
# 	The singer demonstrates his sensitivity during the song by suggesting that he would bring flowers .
# 	 singer demonstrates sensitivity song suggesting bring flowers
#
#
# Predicted Relation: 	 Instrument-Agency(e2,e1), Component-Whole(e2,e1)
# Entities: 	 county, county 	 mailbox, mailbox
# Sentences:
# 	The county replaces the mailbox with a standard metal mailbox acceptable for delivery of mail by the United States .
# 	 county replaces mailbox standard metal mailbox acceptable delivery mail United States
#
#
# Predicted Relation: 	 Component-Whole(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 cells, cells 	 table, table
# Sentences:
# 	The cells inside a nested table are isolated from changes made to the outer table .
# 	 cells inside nested table isolated changes outer table
#
#
# Predicted Relation: 	 Message-Topic(e1,e2), Instrument-Agency(e2,e1)
# Entities: 	 rule, rule 	 use, use
# Sentences:
# 	The same rule governs the use of the reversed and the monochrome versions of the logo .
# 	 rule governs use reversed monochrome versions logo
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Other
# Entities: 	 animal, animal 	 bong, bong
# Sentences:
# 	A man who tried to cool out his hyper cat by stuffing the animal into a boxlike homemade bong faces cruelty charges .
# 	 man tried cool hyper cat stuffing animal boxlike homemade bong faces cruelty charges
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Other
# Entities: 	 Cavalry, Cavalry 	 cuirassiers, cuirassiers
# Sentences:
# 	Cavalry consisted of cuirassiers , dragoons and chevauxlegers .
# 	 Cavalry consisted cuirassiers dragoons chevauxlegers
#
#
# Predicted Relation: 	 Other, Member-Collection(e2,e1)
# Entities: 	 hookup, hookup 	 products, products
# Sentences:
# 	Donovan McNabb threw a 13-yard touchdown pass to Jason Avant , a hookup of two Chicago products , as the Philadelphia Eagles took a 10 - 0 lead over the Chicago Bears after one quarter Sunday night .
# 	 Donovan McNabb threw 13-yard touchdown pass Jason Avant hookup Chicago products Philadelphia Eagles took NUMBER NUMBER lead Chicago Bears quarter Sunday night
#
#
# Predicted Relation: 	 Message-Topic(e1,e2), Message-Topic(e2,e1)
# Entities: 	 show,  	 discussion, discussion
# Sentences:
# 	The show offers a constructive discussion of a hot - button topic with leading M&A experts .
# 	 offers constructive discussion hot button topic leading M&A experts
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Other
# Entities: 	 timestamp, timestamp 	 date, date
# Sentences:
# 	Below is a code snippet for creating a timestamp from formatted date date .
# 	 code snippet creating timestamp formatted date date
#
#
# Predicted Relation: 	 Product-Producer(e1,e2), Content-Container(e2,e1)
# Entities: 	 block, block 	 fishermen, fishermen
# Sentences:
# 	Policemen were seen breaking up a road block put up by fishermen .
# 	 Policemen seen breaking road block fishermen
#
#
# Predicted Relation: 	 Content-Container(e2,e1), Component-Whole(e2,e1)
# Entities: 	 pan, pan 	 spaghetti, spaghetti
# Sentences:
# 	Part of the seam had been opened up and a roasting pan filled with wet spaghetti , cherry pie filling and jello was put inside .
# 	 seam opened roasting pan filled wet spaghetti cherry pie filling jello inside
#
#
# Predicted Relation: 	 Cause-Effect(e1,e2), Other
# Entities: 	 announcement, announcement 	 stir, stir
# Sentences:
# 	The announcement of the game caused a stir on the web yesterday , with the Weekly Standard launching a protest campaign encouraging readers to e - mail Microsoft and T - Enterprise , the out - of - its - depth company that had hired actual Gitmo detainee Moazzam Begg as a consultant on the game .
# 	 announcement game caused stir web yesterday Weekly Standard launching protest campaign encouraging readers e mail Microsoft T Enterprise depth company hired actual Gitmo detainee Moazzam Begg consultant game
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Entity-Origin(e1,e2)
# Entities: 	 images, images 	 web page, web page
# Sentences:
# 	I have put these images into my web page .
# 	 images web page
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Content-Container(e1,e2)
# Entities: 	 electrode, electrode 	 top,
# Sentences:
# 	The second gold electrode was pressed from the top onto the pellet by a screw in order to ensure optimum contact .
# 	 second gold electrode pressed pellet screw order ensure optimum contact
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Message-Topic(e1,e2)
# Entities: 	 remark, remark 	 person, person
# Sentences:
# 	Instead of sounding self - centered , the remark came from a person who is confused and unaccustomed to anything but personal success .
# 	 Instead sounding self centered remark came person confused unaccustomed personal success
#
#
# Predicted Relation: 	 Product-Producer(e2,e1), Other
# Entities: 	 craftsperson, craftsperson 	 representation, representation
# Sentences:
# 	A model maker is a professional craftsperson who creates a 3-dimensional representation of a design or concept .
# 	 model maker professional craftsperson creates 3-dimensional representation design concept
#
#
# Predicted Relation: 	 Product-Producer(e1,e2), Entity-Origin(e1,e2)
# Entities: 	 products, products 	 defendant, defendant
# Sentences:
# 	All of the products grown by the defendant are grown either under glass or in special plots of ground .
# 	 products grown defendant grown glass special plots ground
#
#
# Predicted Relation: 	 Product-Producer(e2,e1), Other
# Entities: 	 person, person 	 couverture, couverture
# Sentences:
# 	A chocolate maker , on the other hand , is the person who physically creates the couverture from cacao beans and other ingredients .
# 	 chocolate maker hand person physically creates couverture cacao beans ingredients
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Other
# Entities: 	 help, help 	 quarter, quarter
# Sentences:
# 	Strangely , today 's help for the crown - jewels enthusiasts has arrived from an unexpected quarter .
# 	 Strangely today 's help crown jewels enthusiasts arrived unexpected quarter
#
#
# Predicted Relation: 	 Cause-Effect(e1,e2), Cause-Effect(e2,e1)
# Entities: 	 clot, clot 	 seizure, seizure
# Sentences:
# 	The clot later caused a seizure , leaving Nathan completely paralyzed on the right side of his body .
# 	 clot later caused seizure leaving Nathan completely paralyzed right body
#
#
# Predicted Relation: 	 Other, Instrument-Agency(e2,e1)
# Entities: 	 wainwright, wainwright 	 shapes, shapes
# Sentences:
# 	The wainwright worked by whittling or lathing pieces of wood into shapes necessary for end products , notably wagon wheels .
# 	 wainwright worked whittling lathing pieces wood shapes necessary end products notably wagon wheels
#
#
# Predicted Relation: 	 Component-Whole(e2,e1), Other
# Entities: 	 patient, patient 	 nostrils, nostrils
# Sentences:
# 	At birth , the patient has bilateral supernumerary nostrils , which were situated above the normal nostrils and opened into the ipsilateral nasal cavities .
# 	 birth patient bilateral supernumerary nostrils situated normal nostrils opened ipsilateral nasal cavities
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 thugs, thugs 	 behaviour, behaviour
# Sentences:
# 	I just looked at how people in fact protected even the thugs from mob behaviour today in Tehran .
# 	 looked people fact protected thugs mob behaviour today Tehran
#
#
# Predicted Relation: 	 Product-Producer(e2,e1), Other
# Entities: 	 women, women 	 style, style
# Sentences:
# 	Along the way the women developed a distinctive style , noted for its lively improvisations and geometric simplicity .
# 	 way women developed distinctive style noted lively improvisations geometric simplicity
#
#
# Predicted Relation: 	 Other, Entity-Destination(e1,e2)
# Entities: 	 name,  	 chatrooms, chatrooms
# Sentences:
# 	The name was leaked in chatrooms as people gave clues as to who it is and some also said his name .
# 	 leaked chatrooms people gave clues said
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 investigations, investigations 	 violations, violations
# Sentences:
# 	The DS Criminal Investigative Division conducts criminal investigations into violations of passport and visa fraud .
# 	 DS Criminal Investigative Division conducts criminal investigations violations passport visa fraud
#
#
# Predicted Relation: 	 Cause-Effect(e2,e1), Cause-Effect(e1,e2)
# Entities: 	 winds, winds 	 moisture, moisture
# Sentences:
# 	The winds are caused by moisture , originating off the Pacific coast , cooling as they climb the western slopes , and then rapidly warming as they drop down the eastern side of the mountains .
# 	 winds caused moisture originating Pacific coast cooling climb western slopes rapidly warming drop eastern mountains
#
#
# Predicted Relation: 	 Cause-Effect(e2,e1), Other
# Entities: 	 vacancy, vacancy 	 retirement, retirement
# Sentences:
# 	The JNC also is currently accepting applications for the vacancy created by the retirement of Judge Edwin B. Browning , Jr.
# 	 JNC currently accepting applications vacancy created retirement Judge Edwin B. Browning Jr.
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Cause-Effect(e2,e1)
# Entities: 	 fragment, fragment 	 gene, gene
# Sentences:
# 	Sequence analysis showed that the fragment was generated from an intron - containing thymosin B15 gene .
# 	 Sequence analysis showed fragment generated intron containing thymosin B15 gene
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Other
# Entities: 	 game, game 	 conies, conies
# Sentences:
# 	The survey further refers to a ' game of conies , ' and a lodge and coney warren , in the tenure of Richard Hopgood by lease from Richard Gifford .
# 	 survey refers game conies lodge coney warren tenure Richard Hopgood lease Richard Gifford
#
#
# Predicted Relation: 	 Content-Container(e2,e1), Content-Container(e1,e2)
# Entities: 	 suitcase, suitcase 	 suitcase, suitcase
# Sentences:
# 	They went into a big walk - in closet where there was a suitcase with another locked suitcase in it .
# 	 went big walk closet suitcase locked suitcase
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 compilation, compilation 	 considerations, considerations
# Sentences:
# 	Instead , their compilation was governed by didactic considerations .
# 	 Instead compilation governed didactic considerations
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Entity-Origin(e1,e2)
# Entities: 	 couple, couple 	 weeks, weeks
# Sentences:
# 	The first couple of weeks at Palm have been a whirlwind .
# 	 couple weeks Palm whirlwind
#
#
# Predicted Relation: 	 Other, Message-Topic(e1,e2)
# Entities: 	 References, References 	 numbers, numbers
# Sentences:
# 	References to the hearing transcript are denoted by volume and page numbers .
# 	 References hearing transcript denoted volume page numbers
#
#
# Predicted Relation: 	 Component-Whole(e1,e2), Message-Topic(e2,e1)
# Entities: 	 site, site 	 network, network
# Sentences:
# 	This site is part of Newsquest 's audited local newspaper network .
# 	 site Newsquest 's audited local newspaper network
#
#
# Predicted Relation: 	 Entity-Origin(e1,e2), Component-Whole(e2,e1)
# Entities: 	 wine, wine 	 skins, skins
# Sentences:
# 	The fermenting musts were plunged twice per day and the wine was pressed from the skins at a TSS level of 3.6 Brix .
# 	 fermenting musts plunged twice day wine pressed skins TSS level NUMBER Brix
#
#
# Predicted Relation: 	 Entity-Destination(e1,e2), Other
# Entities: 	 money, money 	 custody, custody
# Sentences:
# 	The money was handed over into notarial custody for the purpose of securing an obligation .
# 	 money handed notarial custody purpose securing obligation
#
#
# Predicted Relation: 	 Other, Cause-Effect(e1,e2)
# Entities: 	 lioness, lioness 	 grief, grief
# Sentences:
# 	The lioness drank the poisoned water out of grief for the loss of her daughter .
# 	 lioness drank poisoned water grief loss daughter
#
#
# Predicted Relation: 	 Instrument-Agency(e2,e1), Product-Producer(e2,e1)
# Entities: 	 group, group 	 shovels, shovels
# Sentences:
# 	The group dug into the ground with their ceremonial shovels .
# 	 group dug ground ceremonial shovels
#
#
# Predicted Relation: 	 Member-Collection(e2,e1), Other
# Entities: 	 bloat, bloat 	 hippopotamuses, hippopotamuses
# Sentences:
# 	Then there 's a bloat of hippopotamuses , which is really quite insulting to full - figured hippopotami , who can look quite nice if they put flowers in their ears and become ( old joke alert ) hippypotamuses .
# 	 's bloat hippopotamuses insulting figured hippopotami look nice flowers ears old joke alert hippypotamuses
#
#
# Predicted Relation: 	 Product-Producer(e1,e2), Entity-Destination(e1,e2)
# Entities: 	 materials, materials 	 industries, industries
# Sentences:
# 	The minister attributed the slow production of the materials by the local industries to their limited capacities .
# 	 minister attributed slow production materials local industries limited capacities

# %%
print(cw_e2e1,  ia_e2e1,  mc_e1e2,  ce_e2e1,  ed_e1e2,  cc_e1e2,  mt_e1e2,  
pp_e2e1,  mc_e2e1,  eo_e1e2,  ce_e1e2,  cw_e1e2,  mt_e2e1,  pp_e1e2,  
eo_e2e1, cc_e2e1,  ia_e1e2,  ed_e2e1, other)
# Out:
# 20 28 3 19 38 16 16 18 25 49 15 18 9 15 0 5 2 0 68

# %%
cw_e2e1 + ia_e2e1 + mc_e1e2 + ce_e2e1 + ed_e1e2 + cc_e1e2 + mt_e1e2 + \
pp_e2e1 + mc_e2e1 + eo_e1e2 + ce_e1e2 + cw_e1e2 + mt_e2e1 + pp_e1e2 + \
eo_e2e1 + cc_e2e1 + ia_e1e2 + ed_e2e1 + other
# Out:
# 364
