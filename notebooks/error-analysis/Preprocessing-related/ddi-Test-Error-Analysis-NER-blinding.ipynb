# %% [markdown]
# # Error analysis for the type of examples that NER blinding get wrong compared to the baseline

# %%
# %load_ext autoreload

# %%
# %autoreload
import os
from sys import path
import re
import pandas as pd
path.append('../../..')
import numpy as np
from scipy.stats import ttest_rel
from relation_extraction.data.converters.converter_ddi import relation_dict
output_path = '/scratch/geeticka/relation-extraction-result/ddi-analyze/'
def res(path): return os.path.join(output_path, path)
original_sentences_path = os.path.join('/scratch/geeticka/relation-extraction-result/ddi-analyze/test_original.txt')
ner_blinding_sentences_path = os.path.join('/crimea/geeticka/data/relation_extraction/ddi/pre-processed/ner_blinding/test_ner_blinding.txt')

# %%
relation_dict
# Out:
# {0: 'advise', 1: 'effect', 2: 'mechanism', 3: 'int', 4: 'none'}

# %%
def read_answers_line(line):
    linenum, relation = line.strip().split()
    return linenum, relation

# %%
def asstring(list_of_strings):
    return " ".join(list_of_strings)

# %%
def read_sentence_and_entities(line):
    line = line.strip().split()
    sentence = line[5:]
    relation = relation_dict[int(line[0])]
    entity1_idx = (int(line[1]), int(line[2]))
    entity2_idx = (int(line[3]), int(line[4]))
    entity1 = sentence[entity1_idx[0] : entity1_idx[1] + 1]
    entity2 = sentence[entity2_idx[0] : entity2_idx[1] + 1]
    
    return relation, asstring(entity1), asstring(entity2), asstring(sentence)

# %%
needed_linenum_and_relation = {}

# %%
with open(res("answers_for_dev-ner-blinding.txt")) as textfile1, open(res('answers_for_dev-baseline.txt')) as textfile2, \
open(res('answers_for_dev-baseline_gold.txt')) as textfile3: 
    for x, y, z in zip(textfile1, textfile2, textfile3):
        linenum, ner_blinding_relation = read_answers_line(x)
        _, baseline_relation = read_answers_line(y)
        _, gold_relation = read_answers_line(z)
        if baseline_relation == gold_relation and ner_blinding_relation != gold_relation: # punct digit making mistakes
            needed_linenum_and_relation[int(linenum) - 1] = (baseline_relation, ner_blinding_relation)

# %%
len(list(needed_linenum_and_relation.keys()))
# Out:
# 311

# %%
len(list(needed_linenum_and_relation.keys()))/len(open(res('answers_for_dev-baseline_gold.txt')).readlines()) * 100
# Out:
# 6.622657580919931

# %% [markdown]
# Remember that baseline is correct here so the first relation listed is the correct one, unlike in the i2b2 notebook where the order is reversed because baseline is the incorrect one there

# %%
entities_blinded_per_sentence = []
interaction = 0; mechanism = 0; advice = 0; effect = 0; none = 0

# %%
print('We print the baseline first and then the ner blinded version. Gold relation corresponds to baseline\n\n')
curr_linenum = 0
with open(original_sentences_path) as original_sentences, open(ner_blinding_sentences_path) as ner_blinding_sentences:
    for x, y in zip(original_sentences, ner_blinding_sentences):
        needed_linenums = list(needed_linenum_and_relation.keys())
        if curr_linenum in needed_linenums:
            _, e1_b, e2_b, s_b = read_sentence_and_entities(x.strip())
            _, e1_c, e2_c, s_c = read_sentence_and_entities(y.strip())
            r_b, r_c = needed_linenum_and_relation[curr_linenum]
            entities_blinded_per_sentence.append(s_c.split().count('ENTITY'))
            if r_b == 'int': interaction += 1
            elif r_b == 'mechanism': mechanism += 1
            elif r_b == 'advise': advice += 1
            elif r_b == 'effect': effect += 1
            elif r_b == 'none': none += 1
            print('Predicted Relation: \t {0}, {1} \nEntities: \t {2}, {3} \t {4}, {5} \nSentences: \n\t{6} \n\t {7}'.format(
                    r_b, r_c, e1_b, e1_c, e2_b, e2_c, s_b, s_c))
            print('\n')
        curr_linenum += 1
# Out:
# We print the baseline first and then the ner blinded version. Gold relation corresponds to baseline
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 Terbinafine, ENTITY 	 cimetidine, ENTITY
# Sentences:
# 	Terbinafine clearance is increased 100 % by rifampin , a CyP450 enzyme inducer , and decreased 33 % by cimetidine , a CyP450 enzyme inhibitor .
# 	 ENTITY ENTITY is ENTITY 100 % by ENTITY , a ENTITY ENTITY , and ENTITY 33 % by ENTITY , a ENTITY .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 gemfibrozil, ENTITY 	 rifampin, ENTITY
# Sentences:
# 	An inhibitor of CYP2C8 ( such as gemfibrozil ) may increase the AUC of rosiglitazone and an inducer of CYP2C8 ( such as rifampin ) may decrease the AUC of rosiglitazone .
# 	 An ENTITY of ENTITY ( such as ENTITY ) may ENTITY the ENTITY of ENTITY and an ENTITY of ENTITY ( such as ENTITY ) may ENTITY the ENTITY of ENTITY .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 gemfibrozil, ENTITY 	 rosiglitazone, ENTITY
# Sentences:
# 	An inhibitor of CYP2C8 ( such as gemfibrozil ) may increase the AUC of rosiglitazone and an inducer of CYP2C8 ( such as rifampin ) may decrease the AUC of rosiglitazone .
# 	 An ENTITY of ENTITY ( such as ENTITY ) may ENTITY the ENTITY of ENTITY and an ENTITY of ENTITY ( such as ENTITY ) may ENTITY the ENTITY of ENTITY
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 rosiglitazone, ENTITY 	 rosiglitazone, ENTITY
# Sentences:
# 	An inhibitor of CYP2C8 ( such as gemfibrozil ) may increase the AUC of rosiglitazone and an inducer of CYP2C8 ( such as rifampin ) may decrease the AUC of rosiglitazone .
# 	 An ENTITY of ENTITY ( such as ENTITY ) may ENTITY the ENTITY of ENTITY and an ENTITY of ENTITY ( such as ENTITY ) may ENTITY the ENTITY of ENTITY
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 rifampin, ENTITY 	 rosiglitazone, ENTITY
# Sentences:
# 	An inhibitor of CYP2C8 ( such as gemfibrozil ) may increase the AUC of rosiglitazone and an inducer of CYP2C8 ( such as rifampin ) may decrease the AUC of rosiglitazone .
# 	 An ENTITY of ENTITY ( such as ENTITY ) may ENTITY the ENTITY of ENTITY and an ENTITY of ENTITY ( such as ENTITY ) may ENTITY the ENTITY of ENTITY
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Ritalin, ENTITY 	 coumarin anticoagulants, ENTITY
# Sentences:
# 	Human pharmacologic studies have shown that Ritalin may inhibit the metabolism of coumarin anticoagulants , anticonvulsants ( phenobarbital , diphenylhydantoin , primidone ) , phenylbutazone , and tricyclic drugs ( imipramine , clomipramine , desipramine ) .
# 	 ENTITY ENTITY have shown that ENTITY may ENTITY the ENTITY of ENTITY , ENTITY ( ENTITY , ENTITY , ENTITY ) , ENTITY , and ENTITY ( ENTITY , ENTITY , ENTITY ) .
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Ritalin, ENTITY 	 anticonvulsants, ENTITY
# Sentences:
# 	Human pharmacologic studies have shown that Ritalin may inhibit the metabolism of coumarin anticoagulants , anticonvulsants ( phenobarbital , diphenylhydantoin , primidone ) , phenylbutazone , and tricyclic drugs ( imipramine , clomipramine , desipramine ) .
# 	 ENTITY ENTITY have shown that ENTITY may ENTITY the ENTITY of ENTITY , ENTITY ( ENTITY , ENTITY , ENTITY ) , ENTITY , and ENTITY ( ENTITY , ENTITY , ENTITY ) .
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Ritalin, ENTITY 	 phenobarbital, ENTITY
# Sentences:
# 	Human pharmacologic studies have shown that Ritalin may inhibit the metabolism of coumarin anticoagulants , anticonvulsants ( phenobarbital , diphenylhydantoin , primidone ) , phenylbutazone , and tricyclic drugs ( imipramine , clomipramine , desipramine ) .
# 	 ENTITY ENTITY have shown that ENTITY may ENTITY the ENTITY of ENTITY , ENTITY ( ENTITY , ENTITY , ENTITY ) , ENTITY , and ENTITY ( ENTITY , ENTITY , ENTITY ) .
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Ritalin, ENTITY 	 diphenylhydantoin, ENTITY
# Sentences:
# 	Human pharmacologic studies have shown that Ritalin may inhibit the metabolism of coumarin anticoagulants , anticonvulsants ( phenobarbital , diphenylhydantoin , primidone ) , phenylbutazone , and tricyclic drugs ( imipramine , clomipramine , desipramine ) .
# 	 ENTITY ENTITY have shown that ENTITY may ENTITY the ENTITY of ENTITY , ENTITY ( ENTITY , ENTITY , ENTITY ) , ENTITY , and ENTITY ( ENTITY , ENTITY , ENTITY ) .
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Ritalin, ENTITY 	 primidone, ENTITY
# Sentences:
# 	Human pharmacologic studies have shown that Ritalin may inhibit the metabolism of coumarin anticoagulants , anticonvulsants ( phenobarbital , diphenylhydantoin , primidone ) , phenylbutazone , and tricyclic drugs ( imipramine , clomipramine , desipramine ) .
# 	 ENTITY ENTITY have shown that ENTITY may ENTITY the ENTITY of ENTITY , ENTITY ( ENTITY , ENTITY , ENTITY ) , ENTITY , and ENTITY ( ENTITY , ENTITY , ENTITY ) .
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Ritalin, ENTITY 	 phenylbutazone, ENTITY
# Sentences:
# 	Human pharmacologic studies have shown that Ritalin may inhibit the metabolism of coumarin anticoagulants , anticonvulsants ( phenobarbital , diphenylhydantoin , primidone ) , phenylbutazone , and tricyclic drugs ( imipramine , clomipramine , desipramine ) .
# 	 ENTITY ENTITY have shown that ENTITY may ENTITY the ENTITY of ENTITY , ENTITY ( ENTITY , ENTITY , ENTITY ) , ENTITY , and ENTITY ( ENTITY , ENTITY , ENTITY ) .
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Ritalin, ENTITY 	 tricyclic drugs, ENTITY
# Sentences:
# 	Human pharmacologic studies have shown that Ritalin may inhibit the metabolism of coumarin anticoagulants , anticonvulsants ( phenobarbital , diphenylhydantoin , primidone ) , phenylbutazone , and tricyclic drugs ( imipramine , clomipramine , desipramine ) .
# 	 ENTITY ENTITY have shown that ENTITY may ENTITY the ENTITY of ENTITY , ENTITY ( ENTITY , ENTITY , ENTITY ) , ENTITY , and ENTITY ( ENTITY , ENTITY , ENTITY ) .
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Ritalin, ENTITY 	 imipramine, ENTITY
# Sentences:
# 	Human pharmacologic studies have shown that Ritalin may inhibit the metabolism of coumarin anticoagulants , anticonvulsants ( phenobarbital , diphenylhydantoin , primidone ) , phenylbutazone , and tricyclic drugs ( imipramine , clomipramine , desipramine ) .
# 	 ENTITY ENTITY have shown that ENTITY may ENTITY the ENTITY of ENTITY , ENTITY ( ENTITY , ENTITY , ENTITY ) , ENTITY , and ENTITY ( ENTITY , ENTITY , ENTITY ) .
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Ritalin, ENTITY 	 clomipramine, ENTITY
# Sentences:
# 	Human pharmacologic studies have shown that Ritalin may inhibit the metabolism of coumarin anticoagulants , anticonvulsants ( phenobarbital , diphenylhydantoin , primidone ) , phenylbutazone , and tricyclic drugs ( imipramine , clomipramine , desipramine ) .
# 	 ENTITY ENTITY have shown that ENTITY may ENTITY the ENTITY of ENTITY , ENTITY ( ENTITY , ENTITY , ENTITY ) , ENTITY , and ENTITY ( ENTITY , ENTITY , ENTITY ) .
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Ritalin, ENTITY 	 desipramine, ENTITY
# Sentences:
# 	Human pharmacologic studies have shown that Ritalin may inhibit the metabolism of coumarin anticoagulants , anticonvulsants ( phenobarbital , diphenylhydantoin , primidone ) , phenylbutazone , and tricyclic drugs ( imipramine , clomipramine , desipramine ) .
# 	 ENTITY ENTITY have shown that ENTITY may ENTITY the ENTITY of ENTITY , ENTITY ( ENTITY , ENTITY , ENTITY ) , ENTITY , and ENTITY ( ENTITY , ENTITY , ENTITY ) .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 methylphenidate, ENTITY 	 clonidine, ENTITY
# Sentences:
# 	The safety of using methylphenidate in combination with clonidine or other centrally acting alpha-2 agonists has not been systemically evaluated .
# 	 The ENTITY of using ENTITY in ENTITY with ENTITY or other ENTITY alpha-2 ENTITY has not been ENTITY ENTITY .
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Trimethoprim, ENTITY 	 phenytoin, ENTITY
# Sentences:
# 	Trimethoprim may inhibit the hepatic metabolism of phenytoin .
# 	 ENTITY may ENTITY the ENTITY of ENTITY
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 Trimethoprim, ENTITY 	 phenytoin, ENTITY
# Sentences:
# 	Trimethoprim , given at a common clinical dosage , increased the phenytoin half - life by 51 % and decreased the phenytoin metabolic clearance rate by 30 % .
# 	 ENTITY , given at a common ENTITY , ENTITY the ENTITY ENTITY - ENTITY by 51 % and ENTITY the ENTITY ENTITY ENTITY ENTITY by 30 % .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 phenytoin, ENTITY 	 phenytoin, ENTITY
# Sentences:
# 	Trimethoprim , given at a common clinical dosage , increased the phenytoin half - life by 51 % and decreased the phenytoin metabolic clearance rate by 30 % .
# 	 ENTITY , given at a common ENTITY , ENTITY the ENTITY ENTITY - ENTITY by 51 % and ENTITY the ENTITY ENTITY ENTITY ENTITY by 30 % .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 aspirin, ENTITY 	 heparin, ENTITY
# Sentences:
# 	AGGRASTAT has been studied on a background of aspirin and heparin .
# 	 ENTITY has been studied on a ENTITY of ENTITY and ENTITY
#
#
# Predicted Relation: 	 effect, none
# Entities: 	 AGGRASTAT, ENTITY 	 aspirin, ENTITY
# Sentences:
# 	The use of AGGRASTAT , in combination with heparin and aspirin , has been associated with an increase in bleeding compared to heparin and aspirin alone ( see
# 	 The use of ENTITY , in ENTITY with ENTITY and ENTITY , has been ENTITY an ENTITY in ENTITY compared to ENTITY and ENTITY alone ( see
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 phenytoin, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	When phenytoin or other hepatic enzyme inducers such as rifampin and phenobarbital have been taken concurrently with Mexitil , lowered Mexitil plasma levels have been reported .
# 	 When ENTITY or other ENTITY ENTITY such as ENTITY and ENTITY have been taken concurrently with ENTITY , ENTITY ENTITY levels have been reported .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 rifampin, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	When phenytoin or other hepatic enzyme inducers such as rifampin and phenobarbital have been taken concurrently with Mexitil , lowered Mexitil plasma levels have been reported .
# 	 When ENTITY or other ENTITY ENTITY such as ENTITY and ENTITY have been taken concurrently with ENTITY , ENTITY ENTITY levels have been reported .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 phenobarbital, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	When phenytoin or other hepatic enzyme inducers such as rifampin and phenobarbital have been taken concurrently with Mexitil , lowered Mexitil plasma levels have been reported .
# 	 When ENTITY or other ENTITY ENTITY such as ENTITY and ENTITY have been taken concurrently with ENTITY , ENTITY ENTITY levels have been reported .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 Mexitil, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	Concurrent administration of cimetidine and Mexitil has been reported to increase , decrease , or leave unchanged Mexitil plasma levels ;
# 	 ENTITY ENTITY of ENTITY and ENTITY has been reported to ENTITY , ENTITY , or leave ENTITY ENTITY
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Mexitil, ENTITY 	 theophylline, ENTITY
# Sentences:
# 	Concurrent use of Mexitil and theophylline may lead to increased plasma theophylline levels .
# 	 ENTITY ENTITY ENTITY and ENTITY may lead to ENTITY ENTITY ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 Mexitil, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 Mexitil, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 Theophylline, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 Theophylline, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 Theophylline, ENTITY 	 theophylline, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 Mexitil, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 Mexitil, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 Mexitil, ENTITY 	 theophylline, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 Mexitil, ENTITY 	 theophylline, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 Mexitil, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 Mexitil, ENTITY 	 theophylline, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 Mexitil, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 theophylline, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	This increase was observed at the first test point which was the second day after starting Mexitil . Theophylline plasma levels returned to pre- Mexitil values within 48 hours after discontinuing Mexitil . If Mexitil and theophylline are to be used concurrently , theophylline blood levels should be monitored , particularly when the Mexitil dose is changed .
# 	 This ENTITY was observed at the first test point which was the second ENTITY after starting ENTITY . ENTITY ENTITY levels returned to pre- ENTITY within 48 hours after ENTITY ENTITY . If ENTITY and ENTITY are to be used concurrently , ENTITY ENTITY should be ENTITY , particularly when the ENTITY is changed .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 caffeine, ENTITY 	 Mexitil, ENTITY
# Sentences:
# 	Additionally , in one controlled study in five normal subjects and seven patients , the clearance of caffeine was decreased 50 % following the administration of Mexitil .
# 	 Additionally , in one ENTITY in five ENTITY and seven ENTITY , the ENTITY of ENTITY was ENTITY 50 % following the ENTITY of ENTITY
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 GH, ENTITY 	 corticosteroids, ENTITY
# Sentences:
# 	These data suggest that GH administration may alter the clearance of compounds known to be metabolized by CP450 liver enzymes ( e.g. , corticosteroids , sex steroids , anticonvulsants , cyclosporin ) .
# 	 These ENTITY suggest that ENTITY may alter the ENTITY of ENTITY known to be ENTITY by ENTITY ENTITY ( e.g. , ENTITY , ENTITY , ENTITY , ENTITY ) .
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 GH, ENTITY 	 cyclosporin, ENTITY
# Sentences:
# 	These data suggest that GH administration may alter the clearance of compounds known to be metabolized by CP450 liver enzymes ( e.g. , corticosteroids , sex steroids , anticonvulsants , cyclosporin ) .
# 	 These ENTITY suggest that ENTITY may alter the ENTITY of ENTITY known to be ENTITY by ENTITY ENTITY ( e.g. , ENTITY , ENTITY , ENTITY , ENTITY ) .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 Anticoagulants, ENTITY 	 methimazole, ENTITY
# Sentences:
# 	Anticoagulants ( oral ) : The activity of oral anticoagulants may be potentiated by anti - vitamin - K activity attributed to methimazole .
# 	 ENTITY ( ENTITY ) : The ENTITY of ENTITY may be ENTITY by ENTITY - ENTITY - ENTITY ENTITY attributed to ENTITY
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 Theophylline, ENTITY 	 theophylline, ENTITY
# Sentences:
# 	Theophylline : Theophylline clearance may decrease when hyperthyroid patients on a stable theophylline regimen become euthyroid ;
# 	 ENTITY : ENTITY ENTITY may ENTITY when ENTITY ENTITY on a stable ENTITY ENTITY become ENTITY ;
#
#
# Predicted Relation: 	 none, int
# Entities: 	 opioids, ENTITY 	 droperidol, ENTITY
# Sentences:
# 	and combinations of opioids and sedatives ( eg , benzodiazepines , barbiturates , chloral hydrate , droperidol , etc . ) .
# 	 and ENTITY of ENTITY and ENTITY ( eg , ENTITY , ENTITY , ENTITY , ENTITY , etc . ) .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 anticoagulant, ENTITY 	 warfarin, ENTITY
# Sentences:
# 	It has been reported that sulfamethoxazole may prolong the prothrombin time in patients who are receiving the anticoagulant warfarin .
# 	 It has been reported that ENTITY may ENTITY the ENTITY in ENTITY who are receiving the ENTITY
#
#
# Predicted Relation: 	 mechanism, effect
# Entities: 	 Sulfamethoxazole, ENTITY 	 phenytoin, ENTITY
# Sentences:
# 	Sulfamethoxazole may inhibit the hepatic metabolism of phenytoin .
# 	 ENTITY may ENTITY the ENTITY of ENTITY
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 Sulfonamides, ENTITY 	 methotrexate, ENTITY
# Sentences:
# 	Sulfonamides can also displace methotrexate from plasma protein - binding sites , thus increasing free methotrexate concentrations .
# 	 ENTITY can also displace ENTITY from ENTITY - ENTITY , thus increasing ENTITY ENTITY ENTITY .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 Posicor, ENTITY 	 astemizole, ENTITY
# Sentences:
# 	Posicor inhibits some of the liver 's ability to metabolize some other drugs - terfenadine , astemizole , cisapride , cyclosporine , and tricyclic antidepressants .
# 	 ENTITY ENTITY some of the ENTITY ability to ENTITY some other ENTITY - ENTITY , ENTITY , ENTITY , ENTITY , and ENTITY .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 Posicor, ENTITY 	 cisapride, ENTITY
# Sentences:
# 	Posicor inhibits some of the liver 's ability to metabolize some other drugs - terfenadine , astemizole , cisapride , cyclosporine , and tricyclic antidepressants .
# 	 ENTITY ENTITY some of the ENTITY ability to ENTITY some other ENTITY - ENTITY , ENTITY , ENTITY , ENTITY , and ENTITY .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 Posicor, ENTITY 	 cyclosporine, ENTITY
# Sentences:
# 	Posicor inhibits some of the liver 's ability to metabolize some other drugs - terfenadine , astemizole , cisapride , cyclosporine , and tricyclic antidepressants .
# 	 ENTITY ENTITY some of the ENTITY ability to ENTITY some other ENTITY - ENTITY , ENTITY , ENTITY , ENTITY , and ENTITY .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 Posicor, ENTITY 	 tricyclic antidepressants, ENTITY
# Sentences:
# 	Posicor inhibits some of the liver 's ability to metabolize some other drugs - terfenadine , astemizole , cisapride , cyclosporine , and tricyclic antidepressants .
# 	 ENTITY ENTITY some of the ENTITY ability to ENTITY some other ENTITY - ENTITY , ENTITY , ENTITY , ENTITY , and ENTITY
#
#
# Predicted Relation: 	 effect, advise
# Entities: 	 Sanctura, ENTITY 	 anticholinergic agents, ENTITY
# Sentences:
# 	The concomitant use of Sanctura with other anticholinergic agents that produce dry mouth , constipation , and other anticholinergic pharmacological effects may increase the frequency and/or severity of such effects .
# 	 The ENTITY use of ENTITY with other ENTITY that produce ENTITY , ENTITY , and other ENTITY ENTITY may ENTITY the ENTITY and/or ENTITY of such ENTITY .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 Sanctura, ENTITY 	 digoxin, ENTITY
# Sentences:
# 	Drugs Eliminated by Active Tubular Secretion : Although studies to assess drug - drug interactions with Sanctura have not been conducted , Sanctura has the potential for pharmacokinetic interactions with other drugs that are eliminated by active tubular secretion ( e.g. digoxin , procainamide , pancuronium , morphine , vancomycin , metformin and tenofovir ) .
# 	 ENTITY ENTITY by ENTITY ENTITY : Although ENTITY to ENTITY ENTITY - ENTITY with ENTITY have not been conducted , ENTITY has the ENTITY for ENTITY with other ENTITY that are eliminated by ENTITY ( e.g. ENTITY , ENTITY , ENTITY , ENTITY , ENTITY , ENTITY and ENTITY ) .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 Sanctura, ENTITY 	 tenofovir, ENTITY
# Sentences:
# 	Drugs Eliminated by Active Tubular Secretion : Although studies to assess drug - drug interactions with Sanctura have not been conducted , Sanctura has the potential for pharmacokinetic interactions with other drugs that are eliminated by active tubular secretion ( e.g. digoxin , procainamide , pancuronium , morphine , vancomycin , metformin and tenofovir ) .
# 	 ENTITY ENTITY by ENTITY ENTITY : Although ENTITY to ENTITY ENTITY - ENTITY with ENTITY have not been conducted , ENTITY has the ENTITY for ENTITY with other ENTITY that are eliminated by ENTITY ( e.g. ENTITY , ENTITY , ENTITY , ENTITY , ENTITY , ENTITY and ENTITY ) .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 corticosteroids, ENTITY 	 bacitracin, ENTITY
# Sentences:
# 	Some drug interactions are : - birth control pills - corticosteroids - medicines for angina or high blood pressure - medicines for pain - medicines to control seizures such as phenytoin or carbamazepine - certain antibiotics given by injection - cisplatin - edrophonium - neostigmine - polymyxin B or bacitracin - local anesthetics such as procaine - general anesthetics - succinylcholine or other muscle relaxants
# 	 Some ENTITY are : - ENTITY ENTITY - ENTITY - ENTITY for ENTITY or ENTITY - ENTITY for ENTITY - ENTITY to ENTITY such as ENTITY or ENTITY - ENTITY ENTITY given by ENTITY - ENTITY - ENTITY - ENTITY - ENTITY or ENTITY - ENTITY ENTITY such as ENTITY - ENTITY ENTITY - ENTITY or other ENTITY
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 corticosteroids, ENTITY 	 anesthetics, ENTITY
# Sentences:
# 	Some drug interactions are : - birth control pills - corticosteroids - medicines for angina or high blood pressure - medicines for pain - medicines to control seizures such as phenytoin or carbamazepine - certain antibiotics given by injection - cisplatin - edrophonium - neostigmine - polymyxin B or bacitracin - local anesthetics such as procaine - general anesthetics - succinylcholine or other muscle relaxants
# 	 Some ENTITY are : - ENTITY ENTITY - ENTITY - ENTITY for ENTITY or ENTITY - ENTITY for ENTITY - ENTITY to ENTITY such as ENTITY or ENTITY - ENTITY ENTITY given by ENTITY - ENTITY - ENTITY - ENTITY - ENTITY or ENTITY - ENTITY ENTITY such as ENTITY - ENTITY ENTITY - ENTITY or other ENTITY
#
#
# Predicted Relation: 	 effect, mechanism
# Entities: 	 Metopirone, ENTITY 	 acetaminophen, ENTITY
# Sentences:
# 	Metopirone inhibits the glucuronidation of acetaminophen and could possibly potentiate acetaminophen toxicity .
# 	 ENTITY ENTITY the ENTITY of ENTITY and could possibly ENTITY ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 Pyrimethamine, ENTITY 	 quinine, ENTITY
# Sentences:
# 	Pyrimethamine may be used with sulfonamides , quinine and other antimalarials , and with other antibiotics .
# 	 ENTITY may be used with ENTITY , ENTITY and other ENTITY , and with other ENTITY .
#
#
# Predicted Relation: 	 none, int
# Entities: 	 Pyrimethamine, ENTITY 	 antimalarials, ENTITY
# Sentences:
# 	Pyrimethamine may be used with sulfonamides , quinine and other antimalarials , and with other antibiotics .
# 	 ENTITY may be used with ENTITY , ENTITY and other ENTITY , and with other ENTITY .
#
#
# Predicted Relation: 	 effect, none
# Entities: 	 Streptase, ENTITY 	 antiplatelet agents, ENTITY
# Sentences:
# 	Use of Anticoagulants and Antiplatelet Agents -- Streptase , Streptokinase , alone or in combination with antiplatelet agents and anticoagulants , may cause bleeding complications .
# 	 Use of ENTITY and ENTITY -- ENTITY , ENTITY , alone or in ENTITY with ENTITY and ENTITY , may cause ENTITY ENTITY .
#
#
# Predicted Relation: 	 effect, none
# Entities: 	 Streptase, ENTITY 	 anticoagulants, ENTITY
# Sentences:
# 	Use of Anticoagulants and Antiplatelet Agents -- Streptase , Streptokinase , alone or in combination with antiplatelet agents and anticoagulants , may cause bleeding complications .
# 	 Use of ENTITY and ENTITY -- ENTITY , ENTITY , alone or in ENTITY with ENTITY and ENTITY , may cause ENTITY ENTITY .
#
#
# Predicted Relation: 	 effect, none
# Entities: 	 Streptokinase, ENTITY 	 antiplatelet agents, ENTITY
# Sentences:
# 	Use of Anticoagulants and Antiplatelet Agents -- Streptase , Streptokinase , alone or in combination with antiplatelet agents and anticoagulants , may cause bleeding complications .
# 	 Use of ENTITY and ENTITY -- ENTITY , ENTITY , alone or in ENTITY with ENTITY and ENTITY , may cause ENTITY ENTITY .
#
#
# Predicted Relation: 	 effect, mechanism
# Entities: 	 aspirin, ENTITY 	 Streptokinase, ENTITY
# Sentences:
# 	The addition of aspirin to Streptokinase causes a minimal increase in the risk of minor bleeding ( 3.9 % vs. 3.1 % ) , but does not appear to increase the incidence of major bleeding ( see
# 	 The addition of ENTITY to ENTITY causes a minimal ENTITY in the ENTITY of ENTITY ( 3.9 % vs. 3.1 % ) , but does not appear to ENTITY the ENTITY of ENTITY ( see
#
#
# Predicted Relation: 	 effect, none
# Entities: 	 Nalidixic acid, ENTITY 	 melphalan, ENTITY
# Sentences:
# 	DRUG INTERACTIONS There are no known drug / drug interactions with oral ALKERAN Vaccinations with live organism vaccines are not recommended in immunocompromised individuals Nalidixic acid together with high - dose intravenous melphalan has caused deaths in children due to haemorrhagic enterocolitis .
# 	 ENTITY ENTITY There are no known ENTITY / ENTITY with ENTITY ENTITY with ENTITY ENTITY are not recommended in ENTITY ENTITY ENTITY together with ENTITY - ENTITY ENTITY has caused ENTITY in ENTITY due to ENTITY .
#
#
# Predicted Relation: 	 effect, none
# Entities: 	 melphalan, ENTITY 	 cyclosporin, ENTITY
# Sentences:
# 	Impaired renal function has been described in bone marrow transplant patients who were conditioned with high - dose intravenous melphalan and who subsequently received cyclosporin to prevent graft - versus - host disease
# 	 ENTITY ENTITY has been described in ENTITY ENTITY who were ENTITY with ENTITY - ENTITY ENTITY and who subsequently received ENTITY to ENTITY ENTITY - ENTITY - ENTITY
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 cyclosporine, ENTITY 	 cyclosporine, ENTITY
# Sentences:
# 	Cyclosporine : Preliminary data from a XENICAL and cyclosporine drug interaction study indicate a reduction in cyclosporine plasma levels when XENICAL was coadministered with cyclosporine .
# 	 ENTITY : ENTITY from a ENTITY and ENTITY indicate a ENTITY in ENTITY ENTITY levels when ENTITY was ENTITY with ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 cyclosporine, ENTITY 	 cyclosporine, ENTITY
# Sentences:
# 	Cyclosporine : Preliminary data from a XENICAL and cyclosporine drug interaction study indicate a reduction in cyclosporine plasma levels when XENICAL was coadministered with cyclosporine .
# 	 ENTITY : ENTITY from a ENTITY and ENTITY indicate a ENTITY in ENTITY ENTITY levels when ENTITY was ENTITY with ENTITY
#
#
# Predicted Relation: 	 int, none
# Entities: 	 Trilostane, ENTITY 	 aminoglutethimide, ENTITY
# Sentences:
# 	Trilostane may interact with aminoglutethimide or mitotane ( causing too great a decrease in adrenal function ) .
# 	 ENTITY may ENTITY with ENTITY or ENTITY ( causing too great a ENTITY in ENTITY ) .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 Ropivacaine, ENTITY 	 ropivacaine, ENTITY
# Sentences:
# 	Thus strong inhibitors of cytochrome P4501A2 , such as fluvoxamine , given concomitantly during administration of Ropivacaine , can interact with Ropivacaine leading to increased ropivacaine plasma levels .
# 	 Thus strong ENTITY of ENTITY , such as ENTITY , given concomitantly during ENTITY of ENTITY , can ENTITY with ENTITY leading to ENTITY ENTITY ENTITY levels .
#
#
# Predicted Relation: 	 effect, mechanism
# Entities: 	 Zidovudine, ENTITY 	 stavudine, ENTITY
# Sentences:
# 	Zidovudine competitively inhibits the intracellular phosphorylation of stavudine .
# 	 ENTITY ENTITY ENTITY the ENTITY ENTITY of ENTITY
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 paclitaxel, ENTITY 	 HERCEPTIN, ENTITY
# Sentences:
# 	Administration of paclitaxel in combination with HERCEPTIN resulted in a two - fold decrease in HERCEPTIN clearance in a non - human primate study and in a 1.5-fold increase in HERCEPTIN serum levels in clinical studies .
# 	 ENTITY of ENTITY in ENTITY with ENTITY resulted in a two - ENTITY ENTITY in ENTITY ENTITY in a ENTITY - ENTITY ENTITY ENTITY and in a 1.5-fold ENTITY in ENTITY ENTITY in ENTITY .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 vigabatrin, ENTITY 	 phenytoin, ENTITY
# Sentences:
# 	In 1984 , Drs Rimmer and Richens at the University of Wales reported that administering vigabatrin with phenytoin lowered the serum phenytoin concentration in patients with treatment - resistant epilepsy .
# 	 In 1984 , ENTITY and ENTITY at the ENTITY reported that ENTITY ENTITY with ENTITY ENTITY the ENTITY ENTITY ENTITY in ENTITY with ENTITY - ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 ZEMURON, ENTITY 	 succinylcholine, ENTITY
# Sentences:
# 	The median duration of action of ZEMURON 0.6 mg / kg administered after a 1 mg / kg dose of succinylcholine when T 1 returned to 75 % of control was 36 minutes ( range 14 - 57 , n=12 ) vs.
# 	 The ENTITY ENTITY of ENTITY of ENTITY 0.6 mg / kg ENTITY after a 1 mg / kg ENTITY of ENTITY when ENTITY returned to 75 % of ENTITY was 36 ENTITY ( range 14 - 57 , n=12 ) vs.
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 ZEMURON, ENTITY 	 nondepolarizing muscle relaxants, ENTITY ENTITY
# Sentences:
# 	There are no controlled studies documenting the use of ZEMURON before or after other nondepolarizing muscle relaxants .
# 	 There are ENTITY documenting the use of ENTITY before or after other ENTITY ENTITY
#
#
# Predicted Relation: 	 advise, none
# Entities: 	 FELDENE, ENTITY 	 coumarin - type anticoagulants, ENTITY - ENTITY ENTITY
# Sentences:
# 	Although this has not occurred in in vitro studies with coumarin - type anticoagulants , interactions with coumarin - type anticoagulants have been reported with FELDENE since marketing , therefore , physicians should closely monitor patients for a change in dosage requirements when administering FELDENE to patients on coumarin - type anticoagulants and other highly protein - bound drugs .
# 	 Although this has not occurred in ENTITY with ENTITY - ENTITY , ENTITY with ENTITY - ENTITY have been reported with ENTITY since ENTITY , therefore , ENTITY should closely monitor ENTITY for a ENTITY in ENTITY ENTITY when ENTITY ENTITY to ENTITY on ENTITY - ENTITY ENTITY and other highly ENTITY - ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 piroxicam, ENTITY 	 FELDENE, ENTITY
# Sentences:
# 	Plasma levels of piroxicam are depressed to approximately 80 % of their normal values when FELDENE is administered in conjunction with aspirin ( 3900 mg / day ) , but concomitant administration of antacids has no effect on piroxicam plasma levels . Nonsteroidal anti - inflammatory agents , including FELDENE , have been reported to increase steady state plasma lithium levels .
# 	 ENTITY ENTITY of ENTITY are ENTITY to ENTITY 80 % of their ENTITY when ENTITY is ENTITY in ENTITY with ENTITY ( 3900 mg / ENTITY ) , but ENTITY ENTITY of ENTITY has ENTITY on ENTITY ENTITY levels . ENTITY - ENTITY , including ENTITY , have been reported to ENTITY ENTITY ENTITY ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 piroxicam, ENTITY 	 antacids, ENTITY
# Sentences:
# 	Plasma levels of piroxicam are depressed to approximately 80 % of their normal values when FELDENE is administered in conjunction with aspirin ( 3900 mg / day ) , but concomitant administration of antacids has no effect on piroxicam plasma levels . Nonsteroidal anti - inflammatory agents , including FELDENE , have been reported to increase steady state plasma lithium levels .
# 	 ENTITY ENTITY of ENTITY are ENTITY to ENTITY 80 % of their ENTITY when ENTITY is ENTITY in ENTITY with ENTITY ( 3900 mg / ENTITY ) , but ENTITY ENTITY of ENTITY has ENTITY on ENTITY ENTITY levels . ENTITY - ENTITY , including ENTITY , have been reported to ENTITY ENTITY ENTITY ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 piroxicam, ENTITY 	 lithium, ENTITY
# Sentences:
# 	Plasma levels of piroxicam are depressed to approximately 80 % of their normal values when FELDENE is administered in conjunction with aspirin ( 3900 mg / day ) , but concomitant administration of antacids has no effect on piroxicam plasma levels . Nonsteroidal anti - inflammatory agents , including FELDENE , have been reported to increase steady state plasma lithium levels .
# 	 ENTITY ENTITY of ENTITY are ENTITY to ENTITY 80 % of their ENTITY when ENTITY is ENTITY in ENTITY with ENTITY ( 3900 mg / ENTITY ) , but ENTITY ENTITY of ENTITY has ENTITY on ENTITY ENTITY levels . ENTITY - ENTITY , including ENTITY , have been reported to ENTITY ENTITY ENTITY ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 FELDENE, ENTITY 	 antacids, ENTITY
# Sentences:
# 	Plasma levels of piroxicam are depressed to approximately 80 % of their normal values when FELDENE is administered in conjunction with aspirin ( 3900 mg / day ) , but concomitant administration of antacids has no effect on piroxicam plasma levels . Nonsteroidal anti - inflammatory agents , including FELDENE , have been reported to increase steady state plasma lithium levels .
# 	 ENTITY ENTITY of ENTITY are ENTITY to ENTITY 80 % of their ENTITY when ENTITY is ENTITY in ENTITY with ENTITY ( 3900 mg / ENTITY ) , but ENTITY ENTITY of ENTITY has ENTITY on ENTITY ENTITY levels . ENTITY - ENTITY , including ENTITY , have been reported to ENTITY ENTITY ENTITY ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 FELDENE, ENTITY 	 FELDENE, ENTITY
# Sentences:
# 	Plasma levels of piroxicam are depressed to approximately 80 % of their normal values when FELDENE is administered in conjunction with aspirin ( 3900 mg / day ) , but concomitant administration of antacids has no effect on piroxicam plasma levels . Nonsteroidal anti - inflammatory agents , including FELDENE , have been reported to increase steady state plasma lithium levels .
# 	 ENTITY ENTITY of ENTITY are ENTITY to ENTITY 80 % of their ENTITY when ENTITY is ENTITY in ENTITY with ENTITY ( 3900 mg / ENTITY ) , but ENTITY ENTITY of ENTITY has ENTITY on ENTITY ENTITY levels . ENTITY - ENTITY , including ENTITY , have been reported to ENTITY ENTITY ENTITY ENTITY ENTITY .
#
#
# Predicted Relation: 	 advise, none
# Entities: 	 paliperidone, ENTITY 	 centrally acting drugs, ENTITY
# Sentences:
# 	Given the primary CNS effects of paliperidone , INVEGA should be used with caution in combination with other centrally acting drugs and alcohol .
# 	 Given the ENTITY ENTITY ENTITY of ENTITY , ENTITY should be used with caution in ENTITY with other ENTITY and ENTITY .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 centrally acting drugs, ENTITY 	 alcohol, ENTITY
# Sentences:
# 	Given the primary CNS effects of paliperidone , INVEGA should be used with caution in combination with other centrally acting drugs and alcohol .
# 	 Given the ENTITY ENTITY ENTITY of ENTITY , ENTITY should be used with caution in ENTITY with other ENTITY and ENTITY
#
#
# Predicted Relation: 	 effect, mechanism
# Entities: 	 metronidazole, ENTITY 	 coumarin, ENTITY
# Sentences:
# 	Oral metronidazole has been reported to potentiate the anticoagulant effect of coumarin and warfarin , resulting in a prolongation of prothrombin time .
# 	 ENTITY has been reported to ENTITY the ENTITY of ENTITY and ENTITY , resulting in a ENTITY of ENTITY .
#
#
# Predicted Relation: 	 effect, mechanism
# Entities: 	 metronidazole, ENTITY 	 warfarin, ENTITY
# Sentences:
# 	Oral metronidazole has been reported to potentiate the anticoagulant effect of coumarin and warfarin , resulting in a prolongation of prothrombin time .
# 	 ENTITY has been reported to ENTITY the ENTITY of ENTITY and ENTITY , resulting in a ENTITY of ENTITY .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 aspirin, ENTITY 	 meloxicam, ENTITY
# Sentences:
# 	Aspirin : Concomitant administration of aspirin ( 1000 mg TID ) to healthy volunteers tended to increase the AUC ( 10 % ) and Cmax ( 24 % ) of meloxicam .
# 	 ENTITY : ENTITY ENTITY of ENTITY ( 1000 mg ENTITY ) to ENTITY tended to ENTITY the ENTITY ( 10 % ) and ENTITY ( 24 % ) of ENTITY
#
#
# Predicted Relation: 	 none, int
# Entities: 	 furosemide, ENTITY 	 meloxicam, ENTITY
# Sentences:
# 	Studies with furosemide agents and meloxicam have not demonstrated a reduction in natriuretic effect .
# 	 ENTITY with ENTITY and ENTITY have not demonstrated a ENTITY in ENTITY .
#
#
# Predicted Relation: 	 advise, effect
# Entities: 	 furosemide, ENTITY 	 MOBIC, ENTITY
# Sentences:
# 	Nevertheless , during concomitant therapy with furosemide and MOBIC , patients should be observed closely for signs of declining renal function , as well as to assure diuretic efficacy .
# 	 Nevertheless , during ENTITY ENTITY with ENTITY and ENTITY , ENTITY should be observed closely for signs of ENTITY ENTITY , as well as to assure ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 NSAIDs, ENTITY 	 lithium, ENTITY
# Sentences:
# 	Lithium : In clinical trials , NSAIDs have produced an elevation of plasma lithium levels and a reduction in renal lithium clearance .
# 	 ENTITY : In ENTITY , ENTITY have produced an ENTITY of ENTITY ENTITY levels and a ENTITY in ENTITY ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 warfarin, ENTITY 	 warfarin, ENTITY
# Sentences:
# 	The effect of meloxicam on the anticoagulant effect of warfarin was studied in a group of healthy subjects receiving daily doses of warfarin that produced an INR ( International Normalized Ratio ) between 1.2 and 1.8 .
# 	 The ENTITY of ENTITY on the ENTITY of ENTITY was studied in a ENTITY of ENTITY receiving ENTITY of ENTITY that produced an ENTITY ( ENTITY ) between 1.2 and 1.8 .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 NEXAVAR, ENTITY 	 doxorubicin, ENTITY
# Sentences:
# 	Concomitant treatment with NEXAVAR resulted in a 21 % increase in the AUC of doxorubicin .
# 	 ENTITY ENTITY with ENTITY resulted in a 21 % ENTITY in the ENTITY of ENTITY
#
#
# Predicted Relation: 	 advise, effect
# Entities: 	 doxorubicin, ENTITY 	 NEXAVAR, ENTITY
# Sentences:
# 	Caution is recommended when administering doxorubicin with NEXAVAR .
# 	 ENTITY is ENTITY when ENTITY ENTITY with ENTITY
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 ketoconazole, ENTITY 	 azole antifungals, ENTITY
# Sentences:
# 	For patients receiving ketoconazole or other potent CYP3A4 inhibitors such as other azole antifungals ( eg , itraconazole , miconazole ) or macrolide antibiotics ( eg , erythromycin , clarithromycin ) or cyclosporine or vinblastine , the recommended dose of DETROL LA is 2 mg daily .
# 	 For ENTITY receiving ENTITY or other potent ENTITY ENTITY such as other ENTITY ( eg , ENTITY , ENTITY ) or ENTITY ( eg , ENTITY , ENTITY ) or ENTITY or ENTITY , the ENTITY of ENTITY ENTITY is 2 mg ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 ketoconazole, ENTITY 	 itraconazole, ENTITY
# Sentences:
# 	For patients receiving ketoconazole or other potent CYP3A4 inhibitors such as other azole antifungals ( eg , itraconazole , miconazole ) or macrolide antibiotics ( eg , erythromycin , clarithromycin ) or cyclosporine or vinblastine , the recommended dose of DETROL LA is 2 mg daily .
# 	 For ENTITY receiving ENTITY or other potent ENTITY ENTITY such as other ENTITY ( eg , ENTITY , ENTITY ) or ENTITY ( eg , ENTITY , ENTITY ) or ENTITY or ENTITY , the ENTITY of ENTITY ENTITY is 2 mg ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 ketoconazole, ENTITY 	 miconazole, ENTITY
# Sentences:
# 	For patients receiving ketoconazole or other potent CYP3A4 inhibitors such as other azole antifungals ( eg , itraconazole , miconazole ) or macrolide antibiotics ( eg , erythromycin , clarithromycin ) or cyclosporine or vinblastine , the recommended dose of DETROL LA is 2 mg daily .
# 	 For ENTITY receiving ENTITY or other potent ENTITY ENTITY such as other ENTITY ( eg , ENTITY , ENTITY ) or ENTITY ( eg , ENTITY , ENTITY ) or ENTITY or ENTITY , the ENTITY of ENTITY ENTITY is 2 mg ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 ketoconazole, ENTITY 	 macrolide antibiotics, ENTITY
# Sentences:
# ...
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 amphetamine, ENTITY 	 amphetamine, ENTITY
# Sentences:
# 	Rats treated with neonatal quinpirole enhanced time spent in the amphetamine -paired context compared with quinpirole -free controls conditioned with amphetamine , but only female controls conditioned with amphetamine spent more time in the drug - paired context compared with saline - treated controls .
# 	 ENTITY ENTITY ENTITY ENTITY enhanced time spent in the ENTITY -paired ENTITY compared with ENTITY -free ENTITY ENTITY with ENTITY , but only ENTITY ENTITY with ENTITY spent more time in the ENTITY - ENTITY ENTITY ENTITY with ENTITY - ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 quinpirole, ENTITY 	 amphetamine, ENTITY
# Sentences:
# 	Rats treated with neonatal quinpirole enhanced time spent in the amphetamine -paired context compared with quinpirole -free controls conditioned with amphetamine , but only female controls conditioned with amphetamine spent more time in the drug - paired context compared with saline - treated controls .
# 	 ENTITY ENTITY ENTITY ENTITY enhanced time spent in the ENTITY -paired ENTITY compared with ENTITY -free ENTITY ENTITY with ENTITY , but only ENTITY ENTITY with ENTITY spent more time in the ENTITY - ENTITY ENTITY ENTITY with ENTITY - ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 quinpirole, ENTITY 	 amphetamine, ENTITY
# Sentences:
# 	Rats treated with neonatal quinpirole enhanced time spent in the amphetamine -paired context compared with quinpirole -free controls conditioned with amphetamine , but only female controls conditioned with amphetamine spent more time in the drug - paired context compared with saline - treated controls .
# 	 ENTITY ENTITY ENTITY ENTITY enhanced time spent in the ENTITY -paired ENTITY compared with ENTITY -free ENTITY ENTITY with ENTITY , but only ENTITY ENTITY with ENTITY spent more time in the ENTITY - ENTITY ENTITY ENTITY with ENTITY - ENTITY ENTITY .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 Moxifloxacin, ENTITY 	 sucralfate, ENTITY
# Sentences:
# 	Moxifloxacin and Lomefloxacin reacts faster with sucralfate and gelusil in acidic media whereas with erythromycin in basic media and multi - minerals in neutral media .
# 	 ENTITY and ENTITY reacts faster with ENTITY and ENTITY in ENTITY whereas with ENTITY in basic media and ENTITY - ENTITY in ENTITY .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 Lomefloxacin, ENTITY 	 sucralfate, ENTITY
# Sentences:
# 	Moxifloxacin and Lomefloxacin reacts faster with sucralfate and gelusil in acidic media whereas with erythromycin in basic media and multi - minerals in neutral media .
# 	 ENTITY and ENTITY reacts faster with ENTITY and ENTITY in ENTITY whereas with ENTITY in basic media and ENTITY - ENTITY in ENTITY .
#
#
# Predicted Relation: 	 effect, mechanism
# Entities: 	 Implanon, ENTITY 	 antiretroviral, ENTITY
# Sentences:
# 	Implanon failure in an HIV - positive woman on antiretroviral therapy resulting in two ectopic pregnancies .
# 	 ENTITY in an ENTITY - ENTITY ENTITY on ENTITY resulting in two ENTITY .
#
#
# Predicted Relation: 	 effect, advise
# Entities: 	 antiretroviral, ENTITY 	 Implanon, ENTITY
# Sentences:
# 	We present an interesting case of an HIV - positive woman on antiretroviral therapy having tubal pregnancies on two separate occasions with Implanon in place .
# 	 We present an interesting ENTITY of an ENTITY - ENTITY ENTITY on ENTITY having ENTITY on two separate ENTITY with ENTITY in place .
#
#
# Predicted Relation: 	 effect, mechanism
# Entities: 	 CRM197, ENTITY 	 doxorubicin, ENTITY
# Sentences:
# 	CRM197 induced apoptosis , and furthermore , the combination of CRM197 plus doxorubicin enhanced cytotoxicity in a T - ALL cell line .
# 	 ENTITY ENTITY ENTITY , and furthermore , the combination of ENTITY plus ENTITY enhanced ENTITY in a ENTITY - ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 Furafylline, ENTITY 	 sulfaphenazole, ENTITY
# Sentences:
# 	Furafylline and sulfaphenazole had no effect , while quinidine appeared to augment precocene I toxicity .
# 	 ENTITY and ENTITY had ENTITY , while ENTITY appeared to augment ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 Furafylline, ENTITY 	 precocene I, ENTITY
# Sentences:
# 	Furafylline and sulfaphenazole had no effect , while quinidine appeared to augment precocene I toxicity .
# 	 ENTITY and ENTITY had ENTITY , while ENTITY appeared to augment ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 sulfaphenazole, ENTITY 	 precocene I, ENTITY
# Sentences:
# 	Furafylline and sulfaphenazole had no effect , while quinidine appeared to augment precocene I toxicity .
# 	 ENTITY and ENTITY had ENTITY , while ENTITY appeared to augment ENTITY ENTITY .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 omeprazole, ENTITY 	 clopidogrel, ENTITY
# Sentences:
# 	Concomitant use of omeprazole and clopidogrel was found to decrease the exposure ( AUC ) to clopidogrel 's active metabolite by 50 % and to sharply increase platelet reactivity , as a result of inhibition by omeprazole of CYP2C19 , a cytochrome P450 ( CYP ) enzyme .
# 	 ENTITY ENTITY ENTITY and ENTITY was found to ENTITY the ENTITY ( ENTITY ) to ENTITY ENTITY by 50 % and to sharply ENTITY ENTITY , as a result of ENTITY by ENTITY of ENTITY , a ENTITY .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 Pantoprazole, ENTITY 	 clopidogrel, ENTITY
# Sentences:
# 	Pantoprazole has a much weaker effect on clopidogrel 's pharmacokinetics and on platelet reactivity during concomitant use .
# 	 ENTITY has a much weaker ENTITY on ENTITY ENTITY and on ENTITY during ENTITY use .
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 omeprazole, ENTITY 	 esomeprazole, ENTITY
# Sentences:
# 	Regulatory agencies state that the combination of clopidogrel and the CYP2C19 inhibitors omeprazole and esomeprazole should be avoided .
# 	 ENTITY that the ENTITY of ENTITY and the ENTITY ENTITY and ENTITY should be avoided .
#
#
# Predicted Relation: 	 effect, none
# Entities: 	 docetaxel, ENTITY 	 sunitinib, ENTITY
# Sentences:
# 	Sunitinib as a single agent exhibits anti - proliferative effects in vitro in NSCLC cell lines with EGFR T790 M and K - ras mutations but the sequential administration of docetaxel followed by sunitinib is superior to sunitinib followed by docetaxel and concurrent administration .
# 	 ENTITY as a ENTITY exhibits ENTITY - ENTITY ENTITY ENTITY in ENTITY ENTITY with ENTITY ENTITY and ENTITY - ENTITY ENTITY but the sequential ENTITY of ENTITY followed by ENTITY is superior to ENTITY followed by ENTITY and ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 celecoxib, ENTITY 	 celecoxib, ENTITY
# Sentences:
# 	We found antagonism between celecoxib and the four drugs in the breast cancer cells MCF7 following all incubation schedules and between celecoxib and doxorubicin in all cell lines except for two combinations in HCT116 cells .
# 	 We found ENTITY between ENTITY and the four ENTITY in the ENTITY ENTITY following all ENTITY and between ENTITY and ENTITY in all ENTITY except for two ENTITY in ENTITY .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 celecoxib, ENTITY 	 doxorubicin, ENTITY
# Sentences:
# 	We found antagonism between celecoxib and the four drugs in the breast cancer cells MCF7 following all incubation schedules and between celecoxib and doxorubicin in all cell lines except for two combinations in HCT116 cells .
# 	 We found ENTITY between ENTITY and the four ENTITY in the ENTITY ENTITY following all ENTITY and between ENTITY and ENTITY in all ENTITY except for two ENTITY in ENTITY .
#
#
# Predicted Relation: 	 effect, none
# Entities: 	 acetyl - l - carnitine, ENTITY - ENTITY - ENTITY 	 alpha - lipoic acid, ENTITY - ENTITY
# Sentences:
# 	( ii ) acetyl - l - carnitine elicits a significant protective effect on DEB induced toxicity , which was potentiated by alpha - lipoic acid .
# 	 ( ii ) ENTITY - ENTITY - ENTITY elicits a significant ENTITY on ENTITY ENTITY ENTITY , which was ENTITY by ENTITY - ENTITY
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 ketamine, ENTITY 	 propofol, ENTITY
# Sentences:
# 	We retrospectively reviewed the records of 7 pediatric oncology patients who received low - dose ketamine in conjunction with propofol for total intravenous anesthesia ( TIVA ) repeatedly for radiation therapy .
# 	 We ENTITY ENTITY the ENTITY of 7 ENTITY ENTITY who received ENTITY - ENTITY ENTITY in ENTITY with ENTITY for ENTITY ( ENTITY ) repeatedly for ENTITY .
#
#
# Predicted Relation: 	 none, effect
# Entities: 	 ketamine, ENTITY 	 propofol, ENTITY
# Sentences:
# 	Based on this experience , we suggest that low - dose ketamine added to propofol may be associated with prevention of EA in children with a history of EA with propofol TIVA .
# 	 Based on this ENTITY , we suggest that ENTITY - ENTITY ENTITY added to ENTITY may be ENTITY ENTITY of ENTITY in ENTITY with a ENTITY of ENTITY with ENTITY ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 S - ketamine, ENTITY - ENTITY 	 ticlopidine, ENTITY
# Sentences:
# 	In this randomized , blinded , crossover study , 11 healthy volunteers ingested 0.2 mg / kg S - ketamine after pretreatments with oral ticlopidine ( 250 mg twice daily ) , itraconazole ( 200 mg once daily ) , or placebo in 6-day treatment periods at intervals of 4 weeks .
# 	 In this ENTITY , ENTITY , ENTITY , 11 ENTITY ENTITY 0.2 mg / kg ENTITY - ENTITY after ENTITY with ENTITY ( 250 mg twice daily ) , ENTITY ( 200 mg once ENTITY ) , or ENTITY in 6-day ENTITY periods at ENTITY of 4 ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 S - ketamine, ENTITY - ENTITY 	 itraconazole, ENTITY
# Sentences:
# 	In this randomized , blinded , crossover study , 11 healthy volunteers ingested 0.2 mg / kg S - ketamine after pretreatments with oral ticlopidine ( 250 mg twice daily ) , itraconazole ( 200 mg once daily ) , or placebo in 6-day treatment periods at intervals of 4 weeks .
# 	 In this ENTITY , ENTITY , ENTITY , 11 ENTITY ENTITY 0.2 mg / kg ENTITY - ENTITY after ENTITY with ENTITY ( 250 mg twice daily ) , ENTITY ( 200 mg once ENTITY ) , or ENTITY in 6-day ENTITY periods at ENTITY of 4 ENTITY .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 Ticlopidine, ENTITY 	 ketamine, ENTITY
# Sentences:
# 	Ticlopidine treatment increased the mean area under the plasma concentration - time curve extrapolated to infinity ( AUC(0- ) ) of oral ketamine by 2.4-fold , whereas itraconazole treatment did not increase the exposure to S - ketamine .
# 	 ENTITY ENTITY ENTITY the ENTITY under the ENTITY ENTITY - ENTITY extrapolated to ENTITY ( AUC(0- ) ) of ENTITY ENTITY by 2.4-fold , whereas ENTITY ENTITY did not ENTITY the ENTITY ENTITY - ENTITY .
#
#
# Predicted Relation: 	 none, mechanism
# Entities: 	 ticlopidine, ENTITY 	 itraconazole, ENTITY
# Sentences:
# 	In the ticlopidine and itraconazole phases , the areas under the effect - time curves ( self - reported drowsiness and performance ) were significantly higher than those in the placebo phase ( P < 0.05 ) .
# 	 In the ENTITY and ENTITY ENTITY , the areas under the ENTITY - ENTITY ( ENTITY - ENTITY ENTITY and ENTITY ) were ENTITY than those in the ENTITY ( P < 0.05 ) .
#
#
# Predicted Relation: 	 effect, none
# Entities: 	 ABT-737, ENTITY 	 DZNep, ENTITY
# Sentences:
# 	In addition , DZNep insensitivity might be associated with overexpression of Bcl-2 , and the combination of ABT-737 and DZNep could synergistically induced apoptosis .
# 	 In addition , ENTITY ENTITY might be ENTITY ENTITY of ENTITY , and the ENTITY of ENTITY and ENTITY could ENTITY ENTITY ENTITY .
#
#
# Predicted Relation: 	 effect, none
# Entities: 	 methylglyoxal, ENTITY 	 piperacillin, ENTITY
# Sentences:
# 	Distinct and statistically significant synergism was observed between methylglyoxal and piperacillin by disc diffusion tests when compared with their individual effects .
# 	 ENTITY and ENTITY ENTITY was observed between ENTITY and ENTITY by ENTITY when compared with their ENTITY .
#
#
# Predicted Relation: 	 effect, none
# Entities: 	 dasatinib, ENTITY 	 paclitaxel, ENTITY
# Sentences:
# 	HEY cells treated with dasatinib plus paclitaxel formed fewer colonies than did cells treated with either agent alone .
# 	 ENTITY ENTITY ENTITY plus ENTITY formed fewer ENTITY than did ENTITY ENTITY either ENTITY alone .
#
#
# Predicted Relation: 	 effect, none
# Entities: 	 dasatinib, ENTITY 	 paclitaxel, ENTITY
# Sentences:
# 	Studies with forced expression and siRNA knockdown of Bcl-2 and Cdk1 suggest that dasatinib -mediated induction of p27(Kip1 ) enhanced paclitaxel -induced apoptosis by negatively regulating Bcl-2 and Cdk1 expression .
# 	 ENTITY with ENTITY and ENTITY ENTITY of ENTITY and ENTITY suggest that ENTITY -mediated ENTITY of ENTITY ) ENTITY ENTITY -induced ENTITY by negatively regulating ENTITY and ENTITY ENTITY .
#
#
# Predicted Relation: 	 advise, none
# Entities: 	 tamoxifen, ENTITY 	 SSRI antidepressants, ENTITY ENTITY
# Sentences:
# 	It is better to avoid prescribing isoenzyme CYP 2D6 inhibitors to women treated with tamoxifen for breast cancer , especially SSRI antidepressants such as paroxetine and fluoxetine .
# 	 It is better to avoid ENTITY ENTITY to ENTITY ENTITY ENTITY for ENTITY , especially ENTITY ENTITY such as ENTITY and ENTITY .
#
#
# Predicted Relation: 	 advise, none
# Entities: 	 tamoxifen, ENTITY 	 paroxetine, ENTITY
# Sentences:
# 	It is better to avoid prescribing isoenzyme CYP 2D6 inhibitors to women treated with tamoxifen for breast cancer , especially SSRI antidepressants such as paroxetine and fluoxetine .
# 	 It is better to avoid ENTITY ENTITY to ENTITY ENTITY ENTITY for ENTITY , especially ENTITY ENTITY such as ENTITY and ENTITY .
#
#
# Predicted Relation: 	 advise, none
# Entities: 	 tamoxifen, ENTITY 	 fluoxetine, ENTITY
# Sentences:
# 	It is better to avoid prescribing isoenzyme CYP 2D6 inhibitors to women treated with tamoxifen for breast cancer , especially SSRI antidepressants such as paroxetine and fluoxetine .
# 	 It is better to avoid ENTITY ENTITY to ENTITY ENTITY ENTITY for ENTITY , especially ENTITY ENTITY such as ENTITY and ENTITY
#
#
# Predicted Relation: 	 advise, none
# Entities: 	 antidepressant, ENTITY 	 tamoxifen, ENTITY
# Sentences:
# 	If in certain cases , an antidepressant is considered necessary , it may be advisable to replace tamoxifen with anastrozole .
# 	 If in certain ENTITY , an ENTITY is considered necessary , it may be advisable to replace ENTITY with ENTITY .
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 calcium, ENTITY 	 nonheme ( as sulfate ) and heme ( as CRBC ) iron, ENTITY ( as ENTITY ) and ENTITY ( as ENTITY ) ENTITY
# Sentences:
# 	In conclusion , we demonstrated an isolated effect of calcium ( as chloride ) on absorption of 5 mg of iron provided as nonheme ( as sulfate ) and heme ( as CRBC ) iron .
# 	 In conclusion , we demonstrated an ENTITY ENTITY of ENTITY ( as ENTITY ) on ENTITY of 5 mg of ENTITY provided as ENTITY ( as ENTITY ) and ENTITY ( as ENTITY ) ENTITY
#
#
# Predicted Relation: 	 mechanism, none
# Entities: 	 calcium, ENTITY 	 heme ( as CRBC ) iron, ENTITY ( as ENTITY ) ENTITY
# Sentences:
# 	In conclusion , we demonstrated an isolated effect of calcium ( as chloride ) on absorption of 5 mg of iron provided as nonheme ( as sulfate ) and heme ( as CRBC ) iron .
# 	 In conclusion , we demonstrated an ENTITY ENTITY of ENTITY ( as ENTITY ) on ENTITY of 5 mg of ENTITY provided as ENTITY ( as ENTITY ) and ENTITY ( as ENTITY ) ENTITY
#
#
# Predicted Relation: 	 none, advise
# Entities: 	 nonheme ( as sulfate ) and heme ( as CRBC ) iron, ENTITY ( as ENTITY ) and ENTITY ( as ENTITY ) ENTITY 	 heme ( as CRBC ) iron, ENTITY ( as ENTITY ) ENTITY
# Sentences:
# 	In conclusion , we demonstrated an isolated effect of calcium ( as chloride ) on absorption of 5 mg of iron provided as nonheme ( as sulfate ) and heme ( as CRBC ) iron .
# 	 In conclusion , we demonstrated an ENTITY ENTITY of ENTITY ( as ENTITY ) on ENTITY of 5 mg of ENTITY provided as ENTITY ( as ENTITY ) and ENTITY ( as ENTITY ) ENTITY

# %%
print(interaction, mechanism, advice, effect, none)
# Out:
# 2 73 19 62 155

# %%
interaction + mechanism + advice + effect + none
# Out:
# 311

# %%
(np.mean(entities_blinded_per_sentence), np.max(entities_blinded_per_sentence), np.min(entities_blinded_per_sentence),
np.std(entities_blinded_per_sentence), np.median(entities_blinded_per_sentence))
# Out:
# (14.237942122186496, 41, 4, 8.165568107458933, 12.0)

# %%
num_sentences_where_entities_blinded = 0 # count the number of sentences where the numbers were blinded
for numbers in entities_blinded_per_sentence:
    if numbers > 0:
        num_sentences_where_entities_blinded += 1

# %%
num_sentences_where_entities_blinded
# Out:
# 311
