# %%
# %load_ext autoreload

# %%
# %autoreload
import os
from sys import path
import re
import pandas as pd
path.append('../..')
import numpy as np
from scipy.stats import ttest_rel
from relation_extraction.data.summarize_semeval2010 import *
output_path = '/scratch/geeticka/relation-extraction/output/semeval2010/CrossValidation'
def res(path): return os.path.join(output_path, path)

relation_full_form_dictionary = {'C-E': 'Cause-Effect', 'C-W': 'Component-Whole', 'C-C': 'Content-Container',
                                 'E-D': 'Entity-Destination', 'E-O': 'Entity-Origin', 'I-A': 'Instrument-Agency',
                                 'M-C': 'Member-Collection', 'M-T': 'Message-Topic', 'P-P': 'Product-Producer',
                                 '_O': 'Other'}
relation_as_short_list = ['C-E', 'C-W', 'C-C', 'E-D', 'E-O', 'I-A', 'M-C', 'M-T', 'P-P', '_O']

# %% [markdown]
# # Fold0

# %% [markdown]
# We want to print indiv metrics both with and without the other class

# %%
summary_cm_baseline, summary_cm_piecewise = print_full_summary(
    'error-analysis/baseline/Fold0', 'error-analysis/piecewise-pool/Fold0', 
    'Baseline','Piecewise-Pool', res, relation_full_form_dictionary, relation_as_short_list, 2)
# Out:
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, excluding 'Other'
# Metric: Precision 	 statistic -0.46 	 p_value 0.6562784444426755
# Metric: Recall 	 statistic 0.09 	 p_value 0.9267797736150227
# Metric: F1 	 statistic -0.61 	 p_value 0.559847810389105
#
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, including 'Other'
# Metric: Precision 	 statistic -0.39 	 p_value 0.7025790358814328
# Metric: Recall 	 statistic -0.15 	 p_value 0.8843613333646354
# Metric: F1 	 statistic -0.96 	 p_value 0.36177060656445936
#
# All the macro and micro metrics are calculated, excluding the 'Other' class
# Macro - Micro for the Baseline model
# Metric: Precision 	 Macro-Micro 0.37
# Metric: Recall 	 Macro-Micro -0.77
# Metric: F1 	 Macro-Micro -0.47
#
# Macro - Micro for the Piecewise-Pool model
# Metric: Precision 	 Macro-Micro 0.08
# ...

# %%
summary_cm_baseline
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                               E-O(6) M-T(1) P-P(1) _O(2)
# 1                       C-C(1) E-O(2) M-C(1) M-T(2) _O(12)
# 2                                      C-W(2) E-D(4) _O(1)
# 3                                                   C-C(1)
# 4                                             C-W(1) _O(4)
# 5                        C-W(5) E-O(1) M-T(2) P-P(2) _O(6)
# 6                                      C-W(2) C-C(2) _O(2)
# 7                               C-W(1) E-D(1) P-P(2) _O(8)
# 8                 C-E(1) E-D(1) E-O(3) I-A(1) M-C(1) _O(9)
# ...

# %%
summary_cm_piecewise
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                               E-O(4) M-T(1) P-P(1) _O(3)
# 1                       C-C(2) I-A(1) M-C(2) M-T(3) _O(12)
# 2                                      C-W(1) E-D(4) _O(4)
# 3                                                   C-C(2)
# 4                                      C-E(2) P-P(2) _O(5)
# 5                               C-W(4) M-T(2) P-P(2) _O(4)
# 6                                      C-W(2) C-C(1) _O(4)
# 7                                      C-W(1) P-P(1) _O(8)
# 8                 C-W(1) E-D(1) E-O(2) I-A(2) M-T(1) _O(8)
# ...

# %% [markdown]
# # Fold1

# %%
summary_cm_baseline, summary_cm_piecewise = print_full_summary(
    'error-analysis/baseline/Fold1', 'error-analysis/piecewise-pool/Fold1', 
    'Baseline','Piecewise-Pool', res, relation_full_form_dictionary, relation_as_short_list, 2)
# Out:
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, excluding 'Other'
# Metric: Precision 	 statistic 0.55 	 p_value 0.595666085917252
# Metric: Recall 	 statistic -0.67 	 p_value 0.5246269745913417
# Metric: F1 	 statistic -0.07 	 p_value 0.9467399091351281
#
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, including 'Other'
# Metric: Precision 	 statistic -0.01 	 p_value 0.9946292700927752
# Metric: Recall 	 statistic -0.62 	 p_value 0.5527787635864978
# Metric: F1 	 statistic -0.27 	 p_value 0.7908246195982223
#
# All the macro and micro metrics are calculated, excluding the 'Other' class
# Macro - Micro for the Baseline model
# Metric: Precision 	 Macro-Micro -0.64
# Metric: Recall 	 Macro-Micro -0.16
# Metric: F1 	 Macro-Micro -0.51
#
# Macro - Micro for the Piecewise-Pool model
# Metric: Precision 	 Macro-Micro -0.62
# ...

# %%
summary_cm_baseline
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                        C-W(1) E-O(2) I-A(1) P-P(2) _O(5)
# 1                C-C(2) I-A(2) M-C(2) M-T(3) P-P(1) _O(13)
# 2                                      E-D(1) M-C(2) _O(1)
# 3                                             C-C(7) _O(3)
# 4                        C-E(1) C-W(1) I-A(1) P-P(2) _O(3)
# 5                                     C-W(2) P-P(3) _O(10)
# 6                        C-W(2) C-C(1) E-O(1) M-T(1) _O(5)
# 7                               C-E(1) C-W(1) E-D(2) _O(6)
# 8                 C-E(1) C-C(1) E-D(1) E-O(6) I-A(2) _O(8)
# ...

# %%
summary_cm_piecewise
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                        E-O(2) I-A(1) M-T(1) P-P(1) _O(6)
# 1        C-E(1) C-C(3) E-D(1) I-A(2) M-C(2) M-T(5) P-P(...
# 2                                      E-D(1) M-C(3) _O(3)
# 3                                             C-C(5) _O(2)
# 4                        C-E(1) C-W(1) M-T(1) P-P(5) _O(3)
# 5                               C-W(1) E-O(1) P-P(3) _O(5)
# 6                               C-W(1) E-O(1) M-T(2) _O(3)
# 7                               C-E(1) C-W(1) E-D(2) _O(3)
# 8          C-E(2) E-D(3) E-O(5) I-A(2) M-C(1) M-T(1) _O(7)
# ...

# %% [markdown]
# # Fold2

# %%
summary_cm_baseline, summary_cm_piecewise = print_full_summary(
    'error-analysis/baseline/Fold2', 'error-analysis/piecewise-pool/Fold2', 
    'Baseline','Piecewise-Pool', res, relation_full_form_dictionary, relation_as_short_list, 2)
# Out:
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, excluding 'Other'
# Metric: Precision 	 statistic 1.24 	 p_value 0.24875146569640855
# Metric: Recall 	 statistic -0.25 	 p_value 0.8106306202357357
# Metric: F1 	 statistic 1.01 	 p_value 0.3410477012807563
#
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, including 'Other'
# Metric: Precision 	 statistic 0.40 	 p_value 0.7019053739630096
# Metric: Recall 	 statistic 0.02 	 p_value 0.9858975973046158
# Metric: F1 	 statistic 1.11 	 p_value 0.29404482867833526
#
# All the macro and micro metrics are calculated, excluding the 'Other' class
# Macro - Micro for the Baseline model
# Metric: Precision 	 Macro-Micro 0.03
# Metric: Recall 	 Macro-Micro -0.21
# Metric: F1 	 Macro-Micro -0.21
#
# Macro - Micro for the Piecewise-Pool model
# Metric: Precision 	 Macro-Micro 0.36
# ...

# %%
summary_cm_baseline
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                                      E-O(2) M-T(2) _O(5)
# 1          C-E(2) C-C(3) E-O(2) I-A(4) M-C(3) M-T(6) _O(5)
# 2                               C-W(3) E-D(1) M-C(1) _O(2)
# 3                                             C-C(2) _O(4)
# 4                        C-E(3) C-W(1) M-T(1) P-P(2) _O(5)
# 5                                      C-W(4) P-P(2) _O(9)
# 6                                             C-W(2) _O(5)
# 7                               C-E(1) C-W(1) P-P(1) _O(3)
# 8                 C-E(2) C-W(1) E-D(1) E-O(4) I-A(3) _O(7)
# ...

# %%
summary_cm_piecewise
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                        C-W(3) C-C(1) E-O(3) M-T(2) _O(2)
# 1          C-E(1) C-C(2) E-O(1) I-A(2) M-C(5) M-T(7) _O(6)
# 2                                      C-W(2) M-C(1) _O(2)
# 3                                             C-C(2) _O(3)
# 4                        C-E(4) C-W(1) M-T(1) P-P(3) _O(4)
# 5                 C-E(2) C-W(5) M-C(1) M-T(2) P-P(2) _O(4)
# 6                                             C-W(1) _O(3)
# 7                                      C-E(2) P-P(1) _O(3)
# 8          C-E(4) C-W(3) E-D(1) E-O(6) I-A(3) M-T(1) _O(5)
# ...

# %% [markdown]
# # Fold3

# %%
summary_cm_baseline, summary_cm_piecewise = print_full_summary(
    'error-analysis/baseline/Fold3', 'error-analysis/piecewise-pool/Fold3', 
    'Baseline','Piecewise-Pool', res, relation_full_form_dictionary, relation_as_short_list, 2)
# Out:
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, excluding 'Other'
# Metric: Precision 	 statistic 0.08 	 p_value 0.9351839343831326
# Metric: Recall 	 statistic 0.75 	 p_value 0.47375187998545387
# Metric: F1 	 statistic 0.74 	 p_value 0.4783796467274599
#
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, including 'Other'
# Metric: Precision 	 statistic -0.29 	 p_value 0.7752756183362655
# Metric: Recall 	 statistic 0.38 	 p_value 0.7113680183315421
# Metric: F1 	 statistic 0.08 	 p_value 0.9359298414868621
#
# All the macro and micro metrics are calculated, excluding the 'Other' class
# Macro - Micro for the Baseline model
# Metric: Precision 	 Macro-Micro -0.21
# Metric: Recall 	 Macro-Micro 0.04
# Metric: F1 	 Macro-Micro -0.21
#
# Macro - Micro for the Piecewise-Pool model
# Metric: Precision 	 Macro-Micro -0.11
# ...

# %%
summary_cm_baseline
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                        C-W(1) E-O(4) M-T(1) P-P(1) _O(6)
# 1                C-C(5) E-O(1) I-A(5) M-T(2) P-P(1) _O(12)
# 2                                      C-W(3) E-D(3) _O(3)
# 3                                      C-C(2) M-T(1) _O(2)
# 4                                      C-E(6) M-C(1) _O(1)
# 5                               C-W(1) E-O(1) M-T(1) _O(6)
# 6                                             P-P(1) _O(5)
# 7                        C-W(4) E-D(1) E-O(1) P-P(2) _O(6)
# 8                 C-E(2) C-W(1) E-D(2) E-O(1) I-A(2) _O(6)
# ...

# %%
summary_cm_piecewise
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                               C-W(2) E-O(5) M-T(1) _O(5)
# 1                              C-C(6) I-A(2) M-T(4) _O(12)
# 2                               C-W(3) E-D(2) M-T(1) _O(3)
# 3                                     C-W(1) C-C(2) M-T(1)
# 4                               C-E(7) M-C(1) M-T(1) _O(3)
# 5                        C-W(1) E-O(1) M-T(1) P-P(1) _O(5)
# 6                                             P-P(1) _O(4)
# 7                                      C-W(5) E-O(1) _O(6)
# 8          C-E(2) C-W(1) E-D(3) E-O(1) I-A(3) M-T(2) _O(9)
# ...

# %% [markdown]
# # Fold4

# %%
summary_cm_baseline, summary_cm_piecewise = print_full_summary(
    'error-analysis/baseline/Fold4', 'error-analysis/piecewise-pool/Fold4', 
    'Baseline','Piecewise-Pool', res, relation_full_form_dictionary, relation_as_short_list, 2)
# Out:
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, excluding 'Other'
# Metric: Precision 	 statistic 0.83 	 p_value 0.43327875044338016
# Metric: Recall 	 statistic 0.28 	 p_value 0.7874804546528433
# Metric: F1 	 statistic 0.57 	 p_value 0.5811434378392968
#
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, including 'Other'
# Metric: Precision 	 statistic 1.07 	 p_value 0.31337862498281344
# Metric: Recall 	 statistic 0.53 	 p_value 0.6058050544282914
# Metric: F1 	 statistic 0.91 	 p_value 0.3863326581411086
#
# All the macro and micro metrics are calculated, excluding the 'Other' class
# Macro - Micro for the Baseline model
# Metric: Precision 	 Macro-Micro -0.20
# Metric: Recall 	 Macro-Micro 0.00
# Metric: F1 	 Macro-Micro -0.23
#
# Macro - Micro for the Piecewise-Pool model
# Metric: Precision 	 Macro-Micro -0.06
# ...

# %%
summary_cm_baseline
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                                             E-O(2) _O(9)
# 1                 C-C(1) E-O(1) I-A(3) M-C(1) M-T(5) _O(8)
# 2                                             C-W(1) _O(2)
# 3                                      C-C(3) E-O(1) _O(2)
# 4                               C-E(2) M-T(1) P-P(2) _O(2)
# 5                        C-W(2) E-D(2) M-T(1) P-P(2) _O(4)
# 6                               C-W(4) C-C(1) E-D(1) _O(6)
# 7                                      C-E(1) C-W(3) _O(4)
# 8                 C-E(1) C-W(3) E-D(2) E-O(4) I-A(3) _O(6)
# ...

# %%
summary_cm_piecewise
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                                      E-O(1) P-P(1) _O(9)
# 1        C-E(1) C-C(1) E-O(1) I-A(3) M-C(1) M-T(4) P-P(...
# 2                                      C-W(3) E-D(1) _O(3)
# 3                                      C-C(3) E-O(1) _O(1)
# 4                                            C-E(2) P-P(2)
# 5                        C-W(2) E-D(2) E-O(2) P-P(2) _O(3)
# 6                               C-W(1) E-D(1) P-P(1) _O(4)
# 7                                      C-E(2) C-W(3) _O(5)
# 8          C-E(1) C-W(1) C-C(1) E-D(2) E-O(2) I-A(4) _O(8)
# ...

# %% [markdown]
# # Fold5

# %%
summary_cm_baseline, summary_cm_piecewise = print_full_summary(
    'error-analysis/baseline/Fold5', 'error-analysis/piecewise-pool/Fold5', 
    'Baseline','Piecewise-Pool', res, relation_full_form_dictionary, relation_as_short_list, 2)
# Out:
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, excluding 'Other'
# Metric: Precision 	 statistic -0.98 	 p_value 0.3558856495481102
# Metric: Recall 	 statistic -0.29 	 p_value 0.7815515769792953
# Metric: F1 	 statistic -1.22 	 p_value 0.25737094372857666
#
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, including 'Other'
# Metric: Precision 	 statistic -0.75 	 p_value 0.4717780959469837
# Metric: Recall 	 statistic -0.68 	 p_value 0.5143280298106065
# Metric: F1 	 statistic -1.63 	 p_value 0.13717016113141045
#
# All the macro and micro metrics are calculated, excluding the 'Other' class
# Macro - Micro for the Baseline model
# Metric: Precision 	 Macro-Micro 0.17
# Metric: Recall 	 Macro-Micro -0.59
# Metric: F1 	 Macro-Micro -0.26
#
# Macro - Micro for the Piecewise-Pool model
# Metric: Precision 	 Macro-Micro -0.26
# ...

# %%
summary_cm_baseline
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                               C-W(4) E-O(2) P-P(1) _O(5)
# 1                 C-C(3) E-D(1) E-O(1) M-C(1) M-T(3) _O(9)
# 2                               C-W(5) E-D(3) I-A(1) _O(1)
# 3                                             C-C(3) _O(1)
# 4                               C-E(6) C-W(3) I-A(2) _O(2)
# 5                        C-W(5) C-C(1) E-O(1) P-P(3) _O(5)
# 6                               C-W(4) M-T(1) P-P(1) _O(4)
# 7                               C-W(1) E-D(2) I-A(1) _O(4)
# 8          C-E(1) C-W(2) C-C(1) E-D(1) E-O(3) I-A(1) _O(6)
# ...

# %%
summary_cm_piecewise
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                               C-W(1) E-O(1) P-P(1) _O(7)
# 1         C-C(3) E-D(1) I-A(1) M-C(1) M-T(3) P-P(1) _O(11)
# 2                               C-W(5) E-D(3) I-A(1) _O(1)
# 3                                             C-C(4) _O(1)
# 4                 C-E(4) C-W(2) I-A(2) M-T(1) P-P(1) _O(4)
# 5                        C-W(4) E-O(1) M-T(1) P-P(2) _O(4)
# 6                               C-W(2) C-C(1) P-P(2) _O(4)
# 7                               C-W(1) E-D(1) P-P(1) _O(4)
# 8                        C-E(1) E-D(1) E-O(3) I-A(2) _O(8)
# ...

# %% [markdown]
# # Fold6

# %%
summary_cm_baseline, summary_cm_piecewise = print_full_summary(
    'error-analysis/baseline/Fold6', 'error-analysis/piecewise-pool/Fold6', 
    'Baseline','Piecewise-Pool', res, relation_full_form_dictionary, relation_as_short_list, 2)
# Out:
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, excluding 'Other'
# Metric: Precision 	 statistic -1.07 	 p_value 0.3162231214711385
# Metric: Recall 	 statistic 0.02 	 p_value 0.9811040435781746
# Metric: F1 	 statistic -0.47 	 p_value 0.6538409718927575
#
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, including 'Other'
# Metric: Precision 	 statistic -0.29 	 p_value 0.7805411292795922
# Metric: Recall 	 statistic 0.12 	 p_value 0.9063228996946217
# Metric: F1 	 statistic -0.08 	 p_value 0.9373875216073168
#
# All the macro and micro metrics are calculated, excluding the 'Other' class
# Macro - Micro for the Baseline model
# Metric: Precision 	 Macro-Micro -0.70
# Metric: Recall 	 Macro-Micro -0.29
# Metric: F1 	 Macro-Micro -0.67
#
# Macro - Micro for the Piecewise-Pool model
# Metric: Precision 	 Macro-Micro -0.74
# ...

# %%
summary_cm_baseline
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                               C-W(1) E-O(2) M-T(2) _O(3)
# 1                 C-C(4) E-D(1) E-O(1) I-A(5) M-C(2) _O(9)
# 2                                      C-W(1) M-C(1) _O(3)
# 3                                             C-C(5) _O(1)
# 4                               C-E(1) M-T(1) P-P(1) _O(2)
# 5                               C-W(6) E-O(1) P-P(1) _O(5)
# 6                                             C-W(2) _O(5)
# 7                               C-W(2) E-D(1) E-O(1) _O(4)
# 8          C-E(1) C-W(4) E-D(1) E-O(3) I-A(6) M-C(1) _O(6)
# ...

# %%
summary_cm_piecewise
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                               C-W(1) E-O(1) M-T(3) _O(3)
# 1                C-C(3) E-O(1) I-A(2) M-C(2) P-P(1) _O(12)
# 2                                      C-W(1) E-D(1) _O(1)
# 3                                             C-C(4) _O(1)
# 4                                      C-E(1) M-T(1) _O(3)
# 5                               C-W(8) E-O(1) P-P(1) _O(8)
# 6                                             C-W(1) _O(2)
# 7                               C-W(2) E-D(1) E-O(1) _O(4)
# 8                C-E(1) E-D(1) E-O(4) I-A(5) M-C(1) _O(14)
# ...

# %% [markdown]
# # Fold7

# %%
summary_cm_baseline, summary_cm_piecewise = print_full_summary(
    'error-analysis/baseline/Fold7', 'error-analysis/piecewise-pool/Fold7', 
    'Baseline','Piecewise-Pool', res, relation_full_form_dictionary, relation_as_short_list, 2)
# Out:
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, excluding 'Other'
# Metric: Precision 	 statistic -2.57 	 p_value 0.033353170812238764
# Metric: Recall 	 statistic -0.06 	 p_value 0.9525360743136506
# Metric: F1 	 statistic -1.34 	 p_value 0.21586149564218549
#
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, including 'Other'
# Metric: Precision 	 statistic -2.24 	 p_value 0.05202776542070175
# Metric: Recall 	 statistic -0.54 	 p_value 0.600500694444232
# Metric: F1 	 statistic -1.80 	 p_value 0.10464631225291239
#
# All the macro and micro metrics are calculated, excluding the 'Other' class
# Macro - Micro for the Baseline model
# Metric: Precision 	 Macro-Micro -0.25
# Metric: Recall 	 Macro-Micro -0.04
# Metric: F1 	 Macro-Micro -0.29
#
# Macro - Micro for the Piecewise-Pool model
# Metric: Precision 	 Macro-Micro -0.67
# ...

# %%
summary_cm_baseline
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                               E-O(1) M-T(3) P-P(1) _O(8)
# 1                 C-C(5) E-O(2) I-A(3) M-T(2) P-P(1) _O(1)
# 2                                            C-W(2) E-D(1)
# 3                              C-W(1) C-C(4) E-O(1) M-T(3)
# 4          C-E(1) C-W(2) C-C(1) E-D(1) I-A(1) M-T(1) _O(6)
# 5                               C-W(3) E-D(1) P-P(2) _O(1)
# 6                        C-E(1) C-W(2) C-C(1) M-T(1) _O(2)
# 7                                            C-W(4) _O(10)
# 8                        C-W(1) E-O(3) I-A(1) M-T(2) _O(5)
# ...

# %%
summary_cm_piecewise
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                                      E-O(1) M-T(1) _O(7)
# 1                 C-C(5) E-O(1) I-A(4) M-T(3) P-P(1) _O(7)
# 2                                            C-W(2) E-D(1)
# 3                               C-W(1) C-C(4) M-T(2) _O(3)
# 4                 C-E(2) C-W(1) C-C(1) E-D(1) M-T(1) _O(5)
# 5                                      C-W(1) P-P(2) _O(3)
# 6                                      C-C(1) P-P(1) _O(3)
# 7                                      C-W(1) E-O(1) _O(6)
# 8                C-W(2) E-O(3) I-A(2) M-C(1) M-T(1) _O(11)
# ...

# %% [markdown]
# # Fold8

# %%
summary_cm_baseline, summary_cm_piecewise = print_full_summary(
    'error-analysis/baseline/Fold8', 'error-analysis/piecewise-pool/Fold8', 
    'Baseline','Piecewise-Pool', res, relation_full_form_dictionary, relation_as_short_list, 2)
# Out:
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, excluding 'Other'
# Metric: Precision 	 statistic 0.56 	 p_value 0.5905362172538382
# Metric: Recall 	 statistic 0.20 	 p_value 0.8479838439363054
# Metric: F1 	 statistic 0.49 	 p_value 0.6373705462770953
#
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, including 'Other'
# Metric: Precision 	 statistic 0.70 	 p_value 0.5002826383195611
# Metric: Recall 	 statistic 0.57 	 p_value 0.5814215560455976
# Metric: F1 	 statistic 0.81 	 p_value 0.43706021492621494
#
# All the macro and micro metrics are calculated, excluding the 'Other' class
# Macro - Micro for the Baseline model
# Metric: Precision 	 Macro-Micro -0.51
# Metric: Recall 	 Macro-Micro 0.22
# Metric: F1 	 Macro-Micro -0.40
#
# Macro - Micro for the Piecewise-Pool model
# Metric: Precision 	 Macro-Micro -0.60
# ...

# %%
summary_cm_baseline
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                               C-W(2) E-O(5) P-P(3) _O(6)
# 1          C-E(1) C-C(2) E-D(1) I-A(5) M-C(4) M-T(3) _O(4)
# 2                                      C-W(1) E-D(2) _O(3)
# 3                                     C-C(1) E-O(1) P-P(1)
# 4                 C-E(1) C-C(1) E-D(1) M-C(1) P-P(2) _O(1)
# 5                               C-W(2) M-T(2) P-P(1) _O(2)
# 6                                      E-O(1) P-P(1) _O(2)
# 7                                      C-W(3) I-A(1) _O(6)
# 8         C-W(1) E-D(3) E-O(4) I-A(2) M-C(1) M-T(1) _O(12)
# ...

# %%
summary_cm_piecewise
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                 C-W(2) E-D(1) E-O(4) M-T(1) P-P(3) _O(4)
# 1          C-E(1) C-C(4) E-D(1) I-A(3) M-C(4) M-T(3) _O(4)
# 2                                      C-W(1) E-D(1) _O(2)
# 3                                     C-C(2) E-O(1) P-P(1)
# 4                        C-E(2) C-C(1) M-C(1) M-T(1) _O(1)
# 5                        C-W(3) C-C(1) M-T(1) P-P(2) _O(3)
# 6                                      C-W(1) E-O(1) _O(2)
# 7                                             E-D(1) _O(9)
# 8                 E-D(1) E-O(6) I-A(1) M-C(1) M-T(1) _O(9)
# ...

# %% [markdown]
# # Fold9

# %%
summary_cm_baseline, summary_cm_piecewise = print_full_summary(
    'error-analysis/baseline/Fold9', 'error-analysis/piecewise-pool/Fold9', 
    'Baseline','Piecewise-Pool', res, relation_full_form_dictionary, relation_as_short_list, 2)
# Out:
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, excluding 'Other'
# Metric: Precision 	 statistic 0.79 	 p_value 0.45503526971118247
# Metric: Recall 	 statistic 0.40 	 p_value 0.7004032103941142
# Metric: F1 	 statistic 0.83 	 p_value 0.42942162036056675
#
# TTest from Baseline to Piecewise-Pool
# Below is the metric comparsion across the two models considering individual relations, including 'Other'
# Metric: Precision 	 statistic 0.63 	 p_value 0.5443624363273211
# Metric: Recall 	 statistic 0.50 	 p_value 0.6301355004860415
# Metric: F1 	 statistic 1.00 	 p_value 0.34336296537388805
#
# All the macro and micro metrics are calculated, excluding the 'Other' class
# Macro - Micro for the Baseline model
# Metric: Precision 	 Macro-Micro -0.22
# Metric: Recall 	 Macro-Micro 0.23
# Metric: F1 	 Macro-Micro -0.12
#
# Macro - Micro for the Piecewise-Pool model
# Metric: Precision 	 Macro-Micro -0.26
# ...

# %%
summary_cm_baseline
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                                      E-O(5) P-P(2) _O(2)
# 1        C-C(4) E-D(1) E-O(4) I-A(4) M-C(1) M-T(3) P-P(...
# 2                                      C-W(1) E-D(3) _O(2)
# 3                               C-W(1) C-C(1) M-T(1) _O(1)
# 4                 C-E(4) C-W(1) I-A(1) M-T(1) P-P(3) _O(5)
# 5                               C-W(1) E-O(1) P-P(1) _O(2)
# 6                        C-W(1) C-C(1) E-O(1) P-P(3) _O(2)
# 7                               C-E(1) C-W(1) E-O(1) _O(4)
# 8                 C-W(3) C-C(1) E-O(3) M-C(1) M-T(1) _O(2)
# ...

# %%
summary_cm_piecewise
# Out:
# summary       Gold Relation  \
# 0              Cause-Effect
# 1           Component-Whole
# 2         Content-Container
# 3        Entity-Destination
# 4             Entity-Origin
# 5         Instrument-Agency
# 6         Member-Collection
# 7             Message-Topic
# 8          Product-Producer
# 9                     Other
#
# summary                        Confused With(num_examples)  \
# 0                               C-W(1) E-O(5) P-P(2) _O(1)
# 1        C-E(1) C-C(4) E-O(4) I-A(3) M-C(1) M-T(4) P-P(...
# 2                                             E-D(3) _O(3)
# 3                                     C-W(1) C-C(1) M-C(1)
# 4          C-E(3) C-W(1) E-D(1) I-A(1) M-T(1) P-P(3) _O(3)
# 5                        C-W(2) E-O(1) M-C(1) P-P(2) _O(5)
# 6                               C-C(1) M-T(1) P-P(2) _O(2)
# 7                 C-E(1) C-W(2) E-D(2) E-O(1) P-P(1) _O(2)
# 8                               C-W(3) E-O(3) M-C(1) _O(3)
# ...
